# %%
import os

import numpy as np
import torch
import torchvision.datasets as dset
import torch.nn as nn
import torchvision.transforms as transforms

import pyro
import pyro.distributions as dist
import pyro.contrib.examples.util  # patches torchvision
from pyro.infer import SVI, Trace_ELBO
from pyro.optim import Adam

# %%
#assert pyro.__version__.startswith('1.3.0')
pyro.enable_validation(True)
pyro.distributions.enable_validation(False)
pyro.set_rng_seed(0)
# Enable smoke test - run the notebook cells on CI.
#smoke_test = 'CI' in os.environ

# %%
def setup_data_loaders(batch_size=128, use_cuda=False):
    root = './data'
    download = True
    trans = transforms.ToTensor()
    train_set = dset.MNIST(root=root, train=True, transform=trans,
                           download=download)
    test_set = dset.MNIST(root=root, train=False, transform=trans)

    kwargs = {'num_workers': 1, 'pin_memory': use_cuda}
    train_loader = torch.utils.data.DataLoader(dataset=train_set,
        batch_size=batch_size, shuffle=True, **kwargs)
    test_loader = torch.utils.data.DataLoader(dataset=test_set,
        batch_size=batch_size, shuffle=False, **kwargs)
    return train_loader, test_loader

# %%
class Decoder(nn.Module):
    def __init__(self, z_dim, hidden_dim):
        super().__init__()
        # setup the two linear transformations used
        self.fc1 = nn.Linear(z_dim, hidden_dim)
        self.fc21 = nn.Linear(hidden_dim, 784)
        # setup the non-linearities
        self.softplus = nn.Softplus()
        self.sigmoid = nn.Sigmoid()

    def forward(self, z):
        # define the forward computation on the latent z
        # first compute the hidden units
        hidden = self.softplus(self.fc1(z))
        # return the parameter for the output Bernoulli
        # each is of size batch_size x 784
        loc_img = self.sigmoid(self.fc21(hidden))
        return loc_img

# %%
class Encoder(nn.Module):
    def __init__(self, z_dim, hidden_dim):
        super().__init__()
        # setup the three linear transformations used
        self.fc1 = nn.Linear(784, hidden_dim)
        self.fc21 = nn.Linear(hidden_dim, z_dim)
        self.fc22 = nn.Linear(hidden_dim, z_dim)
        # setup the non-linearities
        self.softplus = nn.Softplus()

    def forward(self, x):
        # define the forward computation on the image x
        # first shape the mini-batch to have pixels in the rightmost dimension
        x = x.reshape(-1, 784)
        # then compute the hidden units
        hidden = self.softplus(self.fc1(x))
        # then return a mean vector and a (positive) square root covariance
        # each of size batch_size x z_dim
        z_loc = self.fc21(hidden)
        z_scale = torch.exp(self.fc22(hidden))
        return z_loc, z_scale

# %%
# define the model p(x|z)p(z)
def model(self, x):
    # register PyTorch module `decoder` with Pyro
    pyro.module("decoder", self.decoder)
    with pyro.plate("data", x.shape[0]):
        # setup hyperparameters for prior p(z)
        z_loc = x.new_zeros(torch.Size((x.shape[0], self.z_dim)))
        # z loc torch.Size([256, 50])
        z_scale = x.new_ones(torch.Size((x.shape[0], self.z_dim)))
        # sample from prior (value will be sampled by guide when computing the ELBO)
        z = pyro.sample("latent", dist.Normal(z_loc, z_scale).to_event(1))
        # we sample a Z from a (0, I) normal distribution
        # then we pass it though a nn
        # mu = nn(z)
        # then this mu is used in another dist
        # p(x|z) where z is samples
        # then we sample an x from this
        # the idea is, this nn function learns a distribution
        # that is, what would it be like to sample z from P(z|X)
        # 
        # z shape torch.Size([256, 50])
        # decode the latent code z
        loc_img = self.decoder.forward(z)
        #loc img torch.Size([256, 784])
        # score against actual images
        # bern shape Independent(Bernoulli(probs: torch.Size([256, 784])), 1)
        # 784 is the batch size
        # 256 is the image size
        pyro.sample("obs", dist.Bernoulli(loc_img).to_event(1), obs=x.reshape(-1, 784))

# %%
# define the guide (i.e. variational distribution) q(z|x)
def guide(self, x):
    # register PyTorch module `encoder` with Pyro
    pyro.module("encoder", self.encoder)
    with pyro.plate("data", x.shape[0]):
        # use the encoder to get the parameters used to define q(z|x)
        z_loc, z_scale = self.encoder.forward(x)
        # p(z,b) = q(b)mult(i=1 to i=N)q(zi|f(xi))
        
        # given an image, we output a distribution for z
        # then we sample a z. because the guide always gives the
        # approximate posterior, the variational inference
        # sample the latent code z
        pyro.sample("latent", dist.Normal(z_loc, z_scale).to_event(1))

# %%
class VAE(nn.Module):
    # by default our latent space is 50-dimensional
    # and we use 400 hidden units
    def __init__(self, z_dim=50, hidden_dim=400, use_cuda=False):
        super().__init__()
        # create the encoder and decoder networks
        self.encoder = Encoder(z_dim, hidden_dim)
        self.decoder = Decoder(z_dim, hidden_dim)

        if use_cuda:
            # calling cuda() here will put all the parameters of
            # the encoder and decoder networks into gpu memory
            self.cuda()
        self.use_cuda = use_cuda
        self.z_dim = z_dim

    # define the model p(x|z)p(z)
    
    
    def model(self, x):
        # register PyTorch module `decoder` with Pyro
        pyro.module("decoder", self.decoder)
        with pyro.plate("data", x.shape[0]):
            # setup hyperparameters for prior p(z)
            z_loc = x.new_zeros(torch.Size((x.shape[0], self.z_dim)))
            z_scale = x.new_ones(torch.Size((x.shape[0], self.z_dim)))
            # sample from prior (value will be sampled by guide when computing the ELBO)
            z = pyro.sample("latent", dist.Normal(z_loc, z_scale).to_event(1))
            # decode the latent code z
            loc_img = self.decoder.forward(z)
            # score against actual images
            # decoder is where the image goes 
            pyro.sample("obs", dist.Bernoulli(loc_img).to_event(1), obs=x.reshape(-1, 784))

    # define the guide (i.e. variational distribution) q(z|x)
    def guide(self, x):
        # register PyTorch module `encoder` with Pyro
        pyro.module("encoder", self.encoder)
        with pyro.plate("data", x.shape[0]):
            # use the encoder to get the parameters used to define q(z|x)
            z_loc, z_scale = self.encoder.forward(x)
            # sample the latent code z
            pyro.sample("latent", dist.Normal(z_loc, z_scale).to_event(1))

    # define a helper function for reconstructing images
    def reconstruct_img(self, x):
        # encode image x
        z_loc, z_scale = self.encoder(x)
        # sample in latent space
        z = dist.Normal(z_loc, z_scale).sample()
        # decode the image (note we don't sample in image space)
        loc_img = self.decoder(z)
        return loc_img

# %%
vae = VAE()

optimizer = Adam({"lr": 1.0e-3})

svi = SVI(vae.model, vae.guide, optimizer, loss=Trace_ELBO())

def train(svi, train_loader, use_cuda=False):
    # initialize loss accumulator
    epoch_loss = 0.
    # do a training epoch over each mini-batch x returned
    # by the data loader
    for x, _ in train_loader:
        # if on GPU put mini-batch into CUDA memory
        if use_cuda:
            x = x.cuda()
        # do ELBO gradient and accumulate loss
        epoch_loss += svi.step(x)

    # return epoch loss
    normalizer_train = len(train_loader.dataset)
    total_epoch_loss_train = epoch_loss / normalizer_train
    return total_epoch_loss_train

def evaluate(svi, test_loader, use_cuda=False):
    # initialize loss accumulator
    test_loss = 0.
    # compute the loss over the entire test set
    for x, _ in test_loader:
        # if on GPU put mini-batch into CUDA memory
        if use_cuda:
            x = x.cuda()
        # compute ELBO estimate and accumulate loss
        test_loss += svi.evaluate_loss(x)
    normalizer_test = len(test_loader.dataset)
    total_epoch_loss_test = test_loss / normalizer_test
    return total_epoch_loss_test

# %%
LEARNING_RATE = 1.0e-3
USE_CUDA = False
smoke_test = False

# Run only for a single iteration for testing
NUM_EPOCHS = 100 if smoke_test else 100
TEST_FREQUENCY = 5
train_loader, test_loader = setup_data_loaders(batch_size=256, use_cuda=USE_CUDA)

# clear param store
pyro.clear_param_store()

# setup the VAE
vae = VAE(use_cuda=USE_CUDA)

# setup the optimizer
adam_args = {"lr": LEARNING_RATE}
optimizer = Adam(adam_args)

# setup the inference algorithm
svi = SVI(vae.model, vae.guide, optimizer, loss=Trace_ELBO())

train_elbo = []
test_elbo = []
# training loop
for epoch in range(NUM_EPOCHS):
    total_epoch_loss_train = train(svi, train_loader, use_cuda=USE_CUDA)
    train_elbo.append(-total_epoch_loss_train)
    print("[epoch %03d]  average training loss: %.4f" % (epoch, total_epoch_loss_train))

    if epoch % TEST_FREQUENCY == 0:
        # report test diagnostics
        total_epoch_loss_test = evaluate(svi, test_loader, use_cuda=USE_CUDA)
        test_elbo.append(-total_epoch_loss_test)
        print("[epoch %03d] average test loss: %.4f" % (epoch, total_epoch_loss_test))
# Out:
# [epoch 000]  average training loss: 191.0216
# [epoch 000] average test loss: 156.0872
# [epoch 001]  average training loss: 146.8141
# [epoch 002]  average training loss: 133.2540
# [epoch 003]  average training loss: 124.6775
# [epoch 004]  average training loss: 119.5152
# [epoch 005]  average training loss: 116.1240
# [epoch 005] average test loss: 113.7908
# [epoch 006]  average training loss: 113.7285
# [epoch 007]  average training loss: 112.0445
# [epoch 008]  average training loss: 110.7292
# [epoch 009]  average training loss: 109.7455
# [epoch 010]  average training loss: 108.9070
# [epoch 010] average test loss: 107.7720
# [epoch 011]  average training loss: 108.2513
# [epoch 012]  average training loss: 107.6953
# [epoch 013]  average training loss: 107.2849
# [epoch 014]  average training loss: 106.8870
# [epoch 015]  average training loss: 106.4983
# [epoch 015] average test loss: 105.9786
# [epoch 016]  average training loss: 106.1872
# [epoch 017]  average training loss: 105.9363
# [epoch 018]  average training loss: 105.7087
# [epoch 019]  average training loss: 105.4600
# [epoch 020]  average training loss: 105.2648
# [epoch 020] average test loss: 104.7753
# [epoch 021]  average training loss: 105.0442
# [epoch 022]  average training loss: 104.9031
# [epoch 023]  average training loss: 104.7304
# [epoch 024]  average training loss: 104.6027
# [epoch 025]  average training loss: 104.4586
# [epoch 025] average test loss: 104.2971
# [epoch 026]  average training loss: 104.3756
# [epoch 027]  average training loss: 104.2278
# [epoch 028]  average training loss: 104.1049
# [epoch 029]  average training loss: 104.0565
# [epoch 030]  average training loss: 103.8851
# [epoch 030] average test loss: 103.5858
# [epoch 031]  average training loss: 103.7705
# [epoch 032]  average training loss: 103.7331
# [epoch 033]  average training loss: 103.6272
# [epoch 034]  average training loss: 103.5645
# [epoch 035]  average training loss: 103.4693
# [epoch 035] average test loss: 103.1316
# [epoch 036]  average training loss: 103.3898
# [epoch 037]  average training loss: 103.3199
# [epoch 038]  average training loss: 103.2840
# [epoch 039]  average training loss: 103.1866
# [epoch 040]  average training loss: 103.1108
# [epoch 040] average test loss: 103.0911
# [epoch 041]  average training loss: 103.0730
# [epoch 042]  average training loss: 103.0086
# [epoch 043]  average training loss: 102.9338
# [epoch 044]  average training loss: 102.8886
# [epoch 045]  average training loss: 102.8416
# [epoch 045] average test loss: 102.8022
# [epoch 046]  average training loss: 102.7832
# [epoch 047]  average training loss: 102.7389
# [epoch 048]  average training loss: 102.6800
# [epoch 049]  average training loss: 102.6738
# [epoch 050]  average training loss: 102.5855
# [epoch 050] average test loss: 102.5790
# [epoch 051]  average training loss: 102.5615
# [epoch 052]  average training loss: 102.4934
# [epoch 053]  average training loss: 102.4610
# [epoch 054]  average training loss: 102.4274
# [epoch 055]  average training loss: 102.3712
# [epoch 055] average test loss: 102.3923
# [epoch 056]  average training loss: 102.3328
# [epoch 057]  average training loss: 102.2912
# [epoch 058]  average training loss: 102.1891
# [epoch 059]  average training loss: 102.2194
# [epoch 060]  average training loss: 102.1762
# [epoch 060] average test loss: 102.1223
# [epoch 061]  average training loss: 102.1585
# [epoch 062]  average training loss: 102.0887
# [epoch 063]  average training loss: 102.0703
# [epoch 064]  average training loss: 102.0091
# [epoch 065]  average training loss: 101.9924
# [epoch 065] average test loss: 102.0361
# [epoch 066]  average training loss: 101.9461
# [epoch 067]  average training loss: 101.8985
# [epoch 068]  average training loss: 101.8809
# [epoch 069]  average training loss: 101.8587
# [epoch 070]  average training loss: 101.8102
# [epoch 070] average test loss: 102.1124
# [epoch 071]  average training loss: 101.7739
# [epoch 072]  average training loss: 101.7548
# [epoch 073]  average training loss: 101.7252
# [epoch 074]  average training loss: 101.7424
# [epoch 075]  average training loss: 101.6693
# [epoch 075] average test loss: 101.8703
# [epoch 076]  average training loss: 101.6238
# [epoch 077]  average training loss: 101.5941
# [epoch 078]  average training loss: 101.5562
# [epoch 079]  average training loss: 101.5380
# [epoch 080]  average training loss: 101.4967
# [epoch 080] average test loss: 101.6312
# [epoch 081]  average training loss: 101.4572
# [epoch 082]  average training loss: 101.4549
# [epoch 083]  average training loss: 101.3729
# [epoch 084]  average training loss: 101.3880
# [epoch 085]  average training loss: 101.3953
# [epoch 085] average test loss: 101.5520
# [epoch 086]  average training loss: 101.3212
# [epoch 087]  average training loss: 101.3289
# [epoch 088]  average training loss: 101.3108
# [epoch 089]  average training loss: 101.2534
# [epoch 090]  average training loss: 101.2607
# [epoch 090] average test loss: 101.2997
# [epoch 091]  average training loss: 101.2435
# [epoch 092]  average training loss: 101.1965
# [epoch 093]  average training loss: 101.1350
# [epoch 094]  average training loss: 101.1215
# [epoch 095]  average training loss: 101.0969
# [epoch 095] average test loss: 101.2543
# [epoch 096]  average training loss: 101.1045
# [epoch 097]  average training loss: 101.0621
# [epoch 098]  average training loss: 101.0410
# [epoch 099]  average training loss: 101.0019

# %%
from pyro.nn import PyroSample, PyroModule
from pyro.distributions import Normal, Categorical

class ClassifierBnn(PyroModule):
    
    def __init__(self, num_in = 100, num_hidden = 200, num_out = 10, prior_std = 1.):
        
        # call to father constructor
        super().__init__()
        
        # define prior
        prior = Normal(0, prior_std)
        
        # Define layers
        
        # linear layer 1
        self.linear_layer = PyroModule[torch.nn.Linear](num_in, num_hidden)
        
        # linear alyer parameters as random variables
        self.linear_layer.weights = PyroSample(prior.expand([num_hidden, num_in]).to_event(2))
        self.linear_layer.bias = PyroSample(prior.expand([num_hidden]).to_event(1))
        
        # linear layer 2
        # output dimension is 3 because of the number of classes
        self.output_layer = PyroModule[torch.nn.Linear](num_hidden, num_out)
        
        # linear alyer parameters as random variables
        self.output_layer.weights = PyroSample(prior.expand([num_out, num_hidden]).to_event(2))
        self.output_layer.bias = PyroSample(prior.expand([num_out]).to_event(1))
        
        # activation function
        #self.activation = torch.nn.functional.softmax()
        
    def forward(self, x, y = None):
            
        # latent variable
        z = self.linear_layer(x)
        z = self.output_layer(z)
        z = torch.nn.functional.log_softmax(z, dim=1)
        # likelihood
        with pyro.plate("data",size = x.shape[0], dim = -1):
            # I think this means each batch is independent            
            # z is the input to the distribution (categorical)
            obs = pyro.sample("obs", Categorical(logits = z), obs=y)
        # return latent variable
        return z

# %%
# validate NN

pyro.enable_validation(True)

model = ClassifierBnn()
x, y = next(iter(train_loader))
z_loc, z_scale = vae.encoder(x)
combined_z = torch.cat((z_loc, z_scale), 1)


print(pyro.poutine.trace(model).get_trace(combined_z, y).format_shapes())
# Out:
#          Trace Shapes:
#           Param Sites:
#    linear_layer.weight  10 100
#    output_layer.weight  10  10
#          Sample Sites:
# linear_layer.bias dist       | 200
#                  value       | 200
# output_layer.bias dist       |  10
#                  value       |  10
#              data dist       |
#                  value 256   |
#               obs dist 256   |
#                  value 256   |

# %%
pyro.enable_validation(True)
pyro.clear_param_store()
model = ClassifierBnn(num_hidden = 10, prior_std = 1.)

# define guide
from pyro.infer.autoguide import AutoDiagonalNormal
guide = AutoDiagonalNormal(model, init_scale=1e-1)

# define SVI (model for training)
svi = pyro.infer.SVI(model,
                    guide,
                    optim=pyro.optim.ClippedAdam({'lr':1e-2}),
                    # Define conventional ELBO
                     loss=pyro.infer.Trace_ELBO())

# %%
from pyro.infer import Predictive
predictive = Predictive(model, guide=guide, num_samples=20)

def predict(x):
    # for a single image, output a mean and sd for category
    yhats = predictive(x)["obs"].double()
    # yhats[0] seems to be integers 0 to 9, len 256
    # prediction for one model, for all items in batch
    # 20, 256
    mean = torch.mean(yhats, axis=0)
    std = torch.std(yhats.float(), 0).numpy()
    # yhats outputs a batch size number of predictions for 20 models
    # yhats seem to be a dictionary of weights
    return mean, std

# %%
# Training

num_epochs = 1000

# Define number of epochs
epoch_loss = np.zeros(shape=(num_epochs,))

# training
for epoch in range(10):
    i = 0
    for x, y in train_loader:
        # batches of size 256 are being fed in 
        z_loc, z_scale = vae.encoder(x)
        combined_z = torch.cat((z_loc, z_scale), 1)
        loss = svi.step(combined_z, y)
        mean, std = predict(combined_z)
        accuracy_per_batch = torch.sum(torch.sub(mean,y))/len(y)
        print("loss", loss)
        print("mean", mean[0], "y is", y[0])
        print(accuracy_per_batch)
# Out:
# loss 637.1355237960815
# mean tensor(4.2000, dtype=torch.float64) y is tensor(5)
# tensor(0.3443, dtype=torch.float64)
# loss 626.6906805038452
# mean tensor(5.3000, dtype=torch.float64) y is tensor(0)
# tensor(0.3221, dtype=torch.float64)
# loss 607.4282379150391
# mean tensor(4.6500, dtype=torch.float64) y is tensor(4)
# tensor(-0.0379, dtype=torch.float64)
# loss 588.279972076416
# mean tensor(4.1500, dtype=torch.float64) y is tensor(1)
# tensor(-0.1799, dtype=torch.float64)
# loss 580.9760131835938
# mean tensor(4.6000, dtype=torch.float64) y is tensor(0)
# tensor(-0.1559, dtype=torch.float64)
# loss 576.6481323242188
# mean tensor(3.2000, dtype=torch.float64) y is tensor(3)
# tensor(-0.3453, dtype=torch.float64)
# loss 557.9143877029419
# mean tensor(4.5000, dtype=torch.float64) y is tensor(3)
# tensor(-0.2748, dtype=torch.float64)
# loss 555.7110233306885
# mean tensor(4.9500, dtype=torch.float64) y is tensor(4)
# tensor(0.2373, dtype=torch.float64)
# loss 536.5982828140259
# mean tensor(5., dtype=torch.float64) y is tensor(3)
# tensor(0.0789, dtype=torch.float64)
# loss 524.4714908599854
# mean tensor(5.3000, dtype=torch.float64) y is tensor(7)
# tensor(0.3533, dtype=torch.float64)
# loss 506.057409286499
# mean tensor(5.4500, dtype=torch.float64) y is tensor(9)
# tensor(0.1174, dtype=torch.float64)
# loss 492.4761915206909
# mean tensor(5.5000, dtype=torch.float64) y is tensor(0)
# tensor(-0.1670, dtype=torch.float64)
# loss 485.00113010406494
# mean tensor(4.0500, dtype=torch.float64) y is tensor(1)
# tensor(0.1734, dtype=torch.float64)
# loss 477.17313957214355
# mean tensor(3.5500, dtype=torch.float64) y is tensor(1)
# tensor(0.0863, dtype=torch.float64)
# loss 482.6644067764282
# mean tensor(3.6500, dtype=torch.float64) y is tensor(7)
# tensor(-0.6283, dtype=torch.float64)
# loss 455.690655708313
# mean tensor(3.6500, dtype=torch.float64) y is tensor(7)
# tensor(-0.7336, dtype=torch.float64)
# loss 425.5538339614868
# mean tensor(4.8500, dtype=torch.float64) y is tensor(7)
# tensor(-0.0141, dtype=torch.float64)
# loss 422.12606716156006
# mean tensor(5., dtype=torch.float64) y is tensor(4)
# tensor(0.2008, dtype=torch.float64)
# loss 403.2646360397339
# mean tensor(4., dtype=torch.float64) y is tensor(1)
# tensor(-0.0326, dtype=torch.float64)
# loss 381.1544179916382
# mean tensor(5.7500, dtype=torch.float64) y is tensor(6)
# tensor(-0.1020, dtype=torch.float64)
# loss 361.841290473938
# mean tensor(2.7000, dtype=torch.float64) y is tensor(1)
# tensor(0.2658, dtype=torch.float64)
# loss 348.3463888168335
# mean tensor(5.9500, dtype=torch.float64) y is tensor(7)
# tensor(-0.2826, dtype=torch.float64)
# loss 360.06635189056396
# mean tensor(5.5500, dtype=torch.float64) y is tensor(4)
# tensor(-0.0934, dtype=torch.float64)
# loss 336.3243284225464
# mean tensor(4.1000, dtype=torch.float64) y is tensor(5)
# tensor(-0.0893, dtype=torch.float64)
# loss 323.8287000656128
# mean tensor(4.1500, dtype=torch.float64) y is tensor(2)
# tensor(-0.2516, dtype=torch.float64)
# loss 308.48216342926025
# mean tensor(4.2000, dtype=torch.float64) y is tensor(5)
# tensor(0.0311, dtype=torch.float64)
# loss 293.14797163009644
# mean tensor(5.1500, dtype=torch.float64) y is tensor(6)
# tensor(-0.0367, dtype=torch.float64)
# loss 274.1100163459778
# mean tensor(3.6500, dtype=torch.float64) y is tensor(3)
# tensor(-0.3627, dtype=torch.float64)
# loss 280.2491340637207
# mean tensor(5.9500, dtype=torch.float64) y is tensor(0)
# tensor(-0.1242, dtype=torch.float64)
# loss 277.9751319885254
# mean tensor(3.5000, dtype=torch.float64) y is tensor(3)
# tensor(0.0535, dtype=torch.float64)
# loss 248.74919319152832
# mean tensor(5.5000, dtype=torch.float64) y is tensor(6)
# tensor(-0.1693, dtype=torch.float64)
# loss 268.54027557373047
# mean tensor(2.9000, dtype=torch.float64) y is tensor(5)
# tensor(-0.2523, dtype=torch.float64)
# loss 236.31852960586548
# mean tensor(6.2000, dtype=torch.float64) y is tensor(9)
# tensor(-0.1240, dtype=torch.float64)
# loss 234.88978385925293
# mean tensor(5.8000, dtype=torch.float64) y is tensor(7)
# tensor(-0.1572, dtype=torch.float64)
# loss 241.2816505432129
# mean tensor(8.1000, dtype=torch.float64) y is tensor(8)
# tensor(-0.4113, dtype=torch.float64)
# loss 234.86301803588867
# mean tensor(2.7500, dtype=torch.float64) y is tensor(3)
# tensor(-0.4418, dtype=torch.float64)
# loss 220.10462856292725
# mean tensor(6.9500, dtype=torch.float64) y is tensor(8)
# tensor(-0.2801, dtype=torch.float64)
# loss 238.37615966796875
# mean tensor(3.0500, dtype=torch.float64) y is tensor(3)
# tensor(-0.1268, dtype=torch.float64)
# loss 203.45413208007812
# mean tensor(7.4500, dtype=torch.float64) y is tensor(7)
# tensor(0.2709, dtype=torch.float64)
# loss 209.9754810333252
# mean tensor(7., dtype=torch.float64) y is tensor(5)
# tensor(0.2057, dtype=torch.float64)
# loss 214.7141695022583
# mean tensor(4.7500, dtype=torch.float64) y is tensor(5)
# tensor(0.3055, dtype=torch.float64)
# loss 206.8516445159912
# mean tensor(1.2500, dtype=torch.float64) y is tensor(1)
# tensor(0.2221, dtype=torch.float64)
# loss 201.2895736694336
# mean tensor(8.4000, dtype=torch.float64) y is tensor(9)
# tensor(0.2609, dtype=torch.float64)
# loss 187.58410453796387
# mean tensor(3.9500, dtype=torch.float64) y is tensor(3)
# tensor(0.2361, dtype=torch.float64)
# loss 192.98307991027832
# mean tensor(7.3000, dtype=torch.float64) y is tensor(7)
# tensor(0.0332, dtype=torch.float64)
# loss 209.27264499664307
# mean tensor(5.9000, dtype=torch.float64) y is tensor(6)
# tensor(-0.0961, dtype=torch.float64)
# loss 165.63560676574707
# mean tensor(5.7500, dtype=torch.float64) y is tensor(6)
# tensor(-0.1271, dtype=torch.float64)
# loss 213.8699722290039
# mean tensor(5.7000, dtype=torch.float64) y is tensor(9)
# tensor(-0.2297, dtype=torch.float64)
# loss 189.1746644973755
# mean tensor(6.7000, dtype=torch.float64) y is tensor(9)
# tensor(-0.1529, dtype=torch.float64)
# loss 153.25189685821533
# mean tensor(7., dtype=torch.float64) y is tensor(7)
# tensor(-0.0672, dtype=torch.float64)
# loss 182.46591472625732
# mean tensor(2.4000, dtype=torch.float64) y is tensor(3)
# tensor(0.0574, dtype=torch.float64)
# loss 168.84781646728516
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# tensor(0.0459, dtype=torch.float64)
# loss 150.126877784729
# mean tensor(8.4000, dtype=torch.float64) y is tensor(4)
# tensor(0.1012, dtype=torch.float64)
# loss 167.20890045166016
# mean tensor(2.6500, dtype=torch.float64) y is tensor(8)
# tensor(0.0705, dtype=torch.float64)
# loss 170.62764358520508
# mean tensor(8., dtype=torch.float64) y is tensor(8)
# tensor(0.2289, dtype=torch.float64)
# loss 161.205979347229
# mean tensor(3.3000, dtype=torch.float64) y is tensor(3)
# tensor(0.1373, dtype=torch.float64)
# loss 157.0379343032837
# mean tensor(8., dtype=torch.float64) y is tensor(8)
# tensor(0.0789, dtype=torch.float64)
# loss 141.82208633422852
# mean tensor(0.1000, dtype=torch.float64) y is tensor(0)
# tensor(0.1201, dtype=torch.float64)
# loss 134.36484050750732
# mean tensor(5.7000, dtype=torch.float64) y is tensor(6)
# tensor(0.0467, dtype=torch.float64)
# loss 162.35429573059082
# mean tensor(7.1000, dtype=torch.float64) y is tensor(7)
# tensor(0.2033, dtype=torch.float64)
# loss 128.04353141784668
# mean tensor(6.1500, dtype=torch.float64) y is tensor(6)
# tensor(-0.0469, dtype=torch.float64)
# loss 151.94450855255127
# mean tensor(0.3500, dtype=torch.float64) y is tensor(0)
# tensor(-0.2510, dtype=torch.float64)
# loss 143.46634769439697
# mean tensor(7.4500, dtype=torch.float64) y is tensor(9)
# tensor(-0.1160, dtype=torch.float64)
# loss 145.31996250152588
# mean tensor(7.3000, dtype=torch.float64) y is tensor(8)
# tensor(-0.1539, dtype=torch.float64)
# loss 171.40684986114502
# mean tensor(0.1500, dtype=torch.float64) y is tensor(0)
# tensor(-0.2088, dtype=torch.float64)
# loss 141.81252336502075
# mean tensor(6.8000, dtype=torch.float64) y is tensor(7)
# tensor(-0.2977, dtype=torch.float64)
# loss 147.45494556427002
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# tensor(-0.0207, dtype=torch.float64)
# loss 123.54848957061768
# mean tensor(4.7500, dtype=torch.float64) y is tensor(4)
# tensor(-0.0627, dtype=torch.float64)
# loss 134.85482931137085
# mean tensor(7.5000, dtype=torch.float64) y is tensor(7)
# tensor(0.1244, dtype=torch.float64)
# loss 124.87424755096436
# mean tensor(8.1000, dtype=torch.float64) y is tensor(9)
# tensor(0.0543, dtype=torch.float64)
# loss 104.89948177337646
# mean tensor(1.2500, dtype=torch.float64) y is tensor(1)
# tensor(0.0398, dtype=torch.float64)
# loss 144.5504961013794
# mean tensor(3.1000, dtype=torch.float64) y is tensor(3)
# tensor(0.1932, dtype=torch.float64)
# loss 150.53664875030518
# mean tensor(3.2500, dtype=torch.float64) y is tensor(3)
# tensor(0.0191, dtype=torch.float64)
# loss 126.39814686775208
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# tensor(-0.0117, dtype=torch.float64)
# loss 149.61079025268555
# mean tensor(2.9500, dtype=torch.float64) y is tensor(3)
# tensor(-0.0482, dtype=torch.float64)
# loss 102.30500411987305
# mean tensor(2.5000, dtype=torch.float64) y is tensor(3)
# tensor(0.0664, dtype=torch.float64)
# loss 127.4996976852417
# mean tensor(4.4000, dtype=torch.float64) y is tensor(5)
# tensor(0.0199, dtype=torch.float64)
# loss 130.95302963256836
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# tensor(-0.0143, dtype=torch.float64)
# loss 140.86411476135254
# mean tensor(7., dtype=torch.float64) y is tensor(7)
# tensor(-0.0340, dtype=torch.float64)
# loss 123.00174140930176
# mean tensor(8., dtype=torch.float64) y is tensor(8)
# tensor(0.1174, dtype=torch.float64)
# loss 135.42404079437256
# mean tensor(2.2500, dtype=torch.float64) y is tensor(2)
# tensor(-0.0115, dtype=torch.float64)
# loss 126.87454462051392
# mean tensor(7.7500, dtype=torch.float64) y is tensor(8)
# tensor(-0.1021, dtype=torch.float64)
# loss 144.8237533569336
# mean tensor(4.6500, dtype=torch.float64) y is tensor(5)
# tensor(-0.1639, dtype=torch.float64)
# loss 117.84591293334961
# mean tensor(4., dtype=torch.float64) y is tensor(4)
# tensor(0.0361, dtype=torch.float64)
# loss 159.23596668243408
# mean tensor(2.9000, dtype=torch.float64) y is tensor(2)
# tensor(-0.1057, dtype=torch.float64)
# loss 119.58213520050049
# mean tensor(2., dtype=torch.float64) y is tensor(2)
# tensor(-0.0141, dtype=torch.float64)
# loss 144.28987884521484
# mean tensor(6.3000, dtype=torch.float64) y is tensor(4)
# tensor(-0.0543, dtype=torch.float64)
# loss 118.40651512145996
# mean tensor(0., dtype=torch.float64) y is tensor(0)
# tensor(0.1369, dtype=torch.float64)
# loss 147.88357734680176
# mean tensor(7., dtype=torch.float64) y is tensor(7)
# tensor(-0.0145, dtype=torch.float64)
# loss 154.01033878326416
# mean tensor(5.1500, dtype=torch.float64) y is tensor(5)
# tensor(0.2637, dtype=torch.float64)
# loss 113.32680797576904
# mean tensor(3.2500, dtype=torch.float64) y is tensor(3)
# tensor(0.2027, dtype=torch.float64)
# loss 136.70476055145264
# mean tensor(2.9000, dtype=torch.float64) y is tensor(3)
# tensor(0.0145, dtype=torch.float64)
# loss 111.40647101402283
# mean tensor(5.6000, dtype=torch.float64) y is tensor(6)
# tensor(0.0598, dtype=torch.float64)
# loss 120.3379316329956
# mean tensor(1.9000, dtype=torch.float64) y is tensor(0)
# tensor(-0.0088, dtype=torch.float64)
# loss 101.6742730140686
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# tensor(-0.1879, dtype=torch.float64)
# loss 124.33234882354736
# mean tensor(8.7500, dtype=torch.float64) y is tensor(9)
# tensor(-0.2193, dtype=torch.float64)
# loss 129.64862442016602
# mean tensor(5.1500, dtype=torch.float64) y is tensor(5)
# tensor(-0.1736, dtype=torch.float64)
# loss 150.79013299942017
# mean tensor(9., dtype=torch.float64) y is tensor(9)
# tensor(-0.1355, dtype=torch.float64)
# loss 121.71508884429932
# mean tensor(1., dtype=torch.float64) y is tensor(3)
# tensor(-0.1037, dtype=torch.float64)
# loss 95.87364101409912
# mean tensor(1.7000, dtype=torch.float64) y is tensor(1)
# tensor(-0.0740, dtype=torch.float64)
# loss 118.46537494659424
# mean tensor(0., dtype=torch.float64) y is tensor(0)
# tensor(0.0822, dtype=torch.float64)
# loss 123.38380336761475
# mean tensor(8., dtype=torch.float64) y is tensor(8)
# tensor(0.0439, dtype=torch.float64)
# loss 130.18605947494507
# mean tensor(4.2500, dtype=torch.float64) y is tensor(4)
# tensor(0.0844, dtype=torch.float64)
# loss 127.34046268463135
# mean tensor(4.8000, dtype=torch.float64) y is tensor(4)
# tensor(0.1973, dtype=torch.float64)
# loss 111.29167079925537
# mean tensor(8.3000, dtype=torch.float64) y is tensor(9)
# tensor(0.0477, dtype=torch.float64)
# loss 121.95286226272583
# mean tensor(4.9500, dtype=torch.float64) y is tensor(2)
# tensor(0.0023, dtype=torch.float64)
# loss 116.17976331710815
# mean tensor(4.5000, dtype=torch.float64) y is tensor(4)
# tensor(-0.0648, dtype=torch.float64)
# loss 105.5290732383728
# mean tensor(7., dtype=torch.float64) y is tensor(7)
# tensor(0.0121, dtype=torch.float64)
# loss 115.34912478923798
# mean tensor(5.5000, dtype=torch.float64) y is tensor(5)
# tensor(-0.0350, dtype=torch.float64)
# loss 127.12147521972656
# mean tensor(7., dtype=torch.float64) y is tensor(7)
# tensor(-0.0098, dtype=torch.float64)
# loss 112.30356884002686
# mean tensor(3., dtype=torch.float64) y is tensor(3)
# tensor(-0.1311, dtype=torch.float64)
# loss 108.1437668800354
# mean tensor(0.5000, dtype=torch.float64) y is tensor(0)
# tensor(-0.1375, dtype=torch.float64)
# loss 134.61281156539917
# mean tensor(4., dtype=torch.float64) y is tensor(4)
# tensor(-0.0488, dtype=torch.float64)
# loss 111.87328672409058
# mean tensor(1.3500, dtype=torch.float64) y is tensor(1)
# tensor(0.1148, dtype=torch.float64)
# loss 138.64811420440674
# mean tensor(5.6000, dtype=torch.float64) y is tensor(5)
# tensor(0.0736, dtype=torch.float64)
# loss 112.7808792591095
# mean tensor(8.6500, dtype=torch.float64) y is tensor(9)
# tensor(0.0189, dtype=torch.float64)
# loss 117.59932518005371
# mean tensor(7.8500, dtype=torch.float64) y is tensor(1)
# tensor(0.2164, dtype=torch.float64)
# loss 111.74859428405762
# mean tensor(2.0500, dtype=torch.float64) y is tensor(2)
# tensor(0.1234, dtype=torch.float64)
# loss 114.35740089416504
# mean tensor(3.1000, dtype=torch.float64) y is tensor(3)
# tensor(0.1244, dtype=torch.float64)
# loss 114.55367851257324
# mean tensor(8., dtype=torch.float64) y is tensor(8)
# tensor(0.1723, dtype=torch.float64)
# loss 120.15341854095459
# mean tensor(2.1500, dtype=torch.float64) y is tensor(2)
# tensor(0.0008, dtype=torch.float64)
# loss 93.03761613368988
# mean tensor(3., dtype=torch.float64) y is tensor(3)
# tensor(0.1566, dtype=torch.float64)
# loss 112.80900347232819
# mean tensor(3., dtype=torch.float64) y is tensor(3)
# tensor(-0.0311, dtype=torch.float64)
# loss 114.1395173072815
# mean tensor(7.1000, dtype=torch.float64) y is tensor(9)
# tensor(-0.1023, dtype=torch.float64)
# loss 100.62401485443115
# mean tensor(4.5000, dtype=torch.float64) y is tensor(5)
# tensor(-0.0594, dtype=torch.float64)
# loss 120.00632774829865
# mean tensor(4., dtype=torch.float64) y is tensor(4)
# tensor(-0.1402, dtype=torch.float64)
# loss 118.18630957603455
# mean tensor(9., dtype=torch.float64) y is tensor(9)
# tensor(0.0291, dtype=torch.float64)
# loss 120.28369343280792
# mean tensor(8.0500, dtype=torch.float64) y is tensor(8)
# tensor(0.0191, dtype=torch.float64)
# loss 97.85758876800537
# mean tensor(4.9500, dtype=torch.float64) y is tensor(5)
# tensor(-0.0693, dtype=torch.float64)
# loss 109.74537253379822
# mean tensor(6.9000, dtype=torch.float64) y is tensor(9)
# tensor(-0.2543, dtype=torch.float64)
# loss 103.23466289043427
# mean tensor(3., dtype=torch.float64) y is tensor(3)
# tensor(-0.0273, dtype=torch.float64)
# loss 114.62169981002808
# mean tensor(6., dtype=torch.float64) y is tensor(6)
# tensor(-0.0238, dtype=torch.float64)
# loss 108.05803537368774
# mean tensor(7.0500, dtype=torch.float64) y is tensor(8)
# tensor(-0.0508, dtype=torch.float64)
# loss 128.64072227478027
# mean tensor(6., dtype=torch.float64) y is tensor(6)
# tensor(0.1303, dtype=torch.float64)
# loss 113.35539674758911
# mean tensor(7.2000, dtype=torch.float64) y is tensor(7)
# tensor(-0.0637, dtype=torch.float64)
# loss 127.21392440795898
# mean tensor(8.1500, dtype=torch.float64) y is tensor(8)
# tensor(-0.0709, dtype=torch.float64)
# loss 140.24478006362915
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# tensor(0.1443, dtype=torch.float64)
# loss 120.86422276496887
# mean tensor(4.4000, dtype=torch.float64) y is tensor(6)
# tensor(-0.1193, dtype=torch.float64)
# loss 124.34565472602844
# mean tensor(5.7000, dtype=torch.float64) y is tensor(6)
# tensor(-0.1053, dtype=torch.float64)
# loss 102.27740097045898
# mean tensor(5.3000, dtype=torch.float64) y is tensor(6)
# tensor(-0.0246, dtype=torch.float64)
# loss 109.29285526275635
# mean tensor(3., dtype=torch.float64) y is tensor(3)
# tensor(-0.1057, dtype=torch.float64)
# loss 127.10812211036682
# mean tensor(4., dtype=torch.float64) y is tensor(4)
# tensor(0.0830, dtype=torch.float64)
# loss 122.38366532325745
# mean tensor(5.0500, dtype=torch.float64) y is tensor(5)
# tensor(-0.0176, dtype=torch.float64)
# loss 109.10559511184692
# mean tensor(2.0500, dtype=torch.float64) y is tensor(2)
# tensor(0.0248, dtype=torch.float64)
# loss 123.87192487716675
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# tensor(-0.0682, dtype=torch.float64)
# loss 97.45253252983093
# mean tensor(1.1000, dtype=torch.float64) y is tensor(1)
# tensor(-0.1191, dtype=torch.float64)
# loss 113.89771890640259
# mean tensor(8., dtype=torch.float64) y is tensor(8)
# tensor(0.0318, dtype=torch.float64)
# loss 117.80908286571503
# mean tensor(5.2500, dtype=torch.float64) y is tensor(5)
# tensor(-0.0557, dtype=torch.float64)
# loss 110.97034645080566
# mean tensor(5.7500, dtype=torch.float64) y is tensor(6)
# tensor(-0.0205, dtype=torch.float64)
# loss 102.0224871635437
# mean tensor(5., dtype=torch.float64) y is tensor(5)
# tensor(-0.0574, dtype=torch.float64)
# loss 120.07359743118286
# mean tensor(9., dtype=torch.float64) y is tensor(9)
# tensor(0.0018, dtype=torch.float64)
# loss 129.5422134399414
# mean tensor(8.6500, dtype=torch.float64) y is tensor(9)
# tensor(0.1012, dtype=torch.float64)
# loss 124.79998874664307
# mean tensor(3., dtype=torch.float64) y is tensor(3)
# tensor(0.0328, dtype=torch.float64)
# loss 117.32144260406494
# mean tensor(6., dtype=torch.float64) y is tensor(6)
# tensor(0.1664, dtype=torch.float64)
# loss 113.98421096801758
# mean tensor(4.7500, dtype=torch.float64) y is tensor(5)
# tensor(0.1709, dtype=torch.float64)
# loss 103.40064585208893
# mean tensor(4., dtype=torch.float64) y is tensor(4)
# tensor(0.0684, dtype=torch.float64)
# loss 97.31800591945648
# mean tensor(6.5500, dtype=torch.float64) y is tensor(7)
# tensor(0.0535, dtype=torch.float64)
# loss 91.1493546962738
# mean tensor(6., dtype=torch.float64) y is tensor(6)
# tensor(0.0482, dtype=torch.float64)
# loss 85.51445007324219
# mean tensor(4., dtype=torch.float64) y is tensor(4)
# tensor(0.1125, dtype=torch.float64)
# loss 149.9344013929367
# mean tensor(3.8500, dtype=torch.float64) y is tensor(3)
# tensor(0.0223, dtype=torch.float64)
# loss 137.76820588111877
# mean tensor(5.7000, dtype=torch.float64) y is tensor(6)
# tensor(-0.0563, dtype=torch.float64)
# loss 112.59709548950195
# mean tensor(4.7000, dtype=torch.float64) y is tensor(5)
# tensor(-0.0648, dtype=torch.float64)
# loss 121.63701558113098
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# tensor(-0.0076, dtype=torch.float64)
# loss 102.54758018255234
# mean tensor(7.3500, dtype=torch.float64) y is tensor(2)
# tensor(-0.1391, dtype=torch.float64)
# loss 119.12720263004303
# mean tensor(2.9000, dtype=torch.float64) y is tensor(3)
# tensor(-0.0236, dtype=torch.float64)
# loss 99.19321584701538
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# tensor(-0.1229, dtype=torch.float64)
# loss 117.005788564682
# mean tensor(3.5000, dtype=torch.float64) y is tensor(8)
# tensor(0.0033, dtype=torch.float64)
# loss 93.87175512313843
# mean tensor(0., dtype=torch.float64) y is tensor(0)
# tensor(0.0105, dtype=torch.float64)
# loss 101.30041456222534
# mean tensor(5.7000, dtype=torch.float64) y is tensor(3)
# tensor(0.0533, dtype=torch.float64)
# loss 84.86881828308105
# mean tensor(1., dtype=torch.float64) y is tensor(9)
# tensor(-0.0125, dtype=torch.float64)
# loss 98.9395751953125
# mean tensor(1.4500, dtype=torch.float64) y is tensor(3)
# tensor(0.0121, dtype=torch.float64)
# loss 130.51351070404053
# mean tensor(0., dtype=torch.float64) y is tensor(0)
# tensor(0.1908, dtype=torch.float64)
# loss 104.35821962356567
# mean tensor(7.6500, dtype=torch.float64) y is tensor(8)
# tensor(0.0693, dtype=torch.float64)
# loss 97.40216827392578
# mean tensor(3., dtype=torch.float64) y is tensor(3)
# tensor(0.1098, dtype=torch.float64)
# loss 83.82257652282715
# mean tensor(2.9500, dtype=torch.float64) y is tensor(3)
# tensor(-0.0109, dtype=torch.float64)
# loss 96.69665455818176
# mean tensor(4.7000, dtype=torch.float64) y is tensor(6)
# tensor(-0.0498, dtype=torch.float64)
# loss 109.69911241531372
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# tensor(-0.1566, dtype=torch.float64)
# loss 95.92588233947754
# mean tensor(7., dtype=torch.float64) y is tensor(7)
# tensor(-0.1412, dtype=torch.float64)
# loss 112.28128206729889
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# tensor(-0.1494, dtype=torch.float64)
# loss 150.81302976608276
# mean tensor(6.3500, dtype=torch.float64) y is tensor(8)
# tensor(-0.2855, dtype=torch.float64)
# loss 99.76620197296143
# mean tensor(6., dtype=torch.float64) y is tensor(6)
# tensor(-0.2324, dtype=torch.float64)
# loss 110.07011616230011
# mean tensor(3., dtype=torch.float64) y is tensor(3)
# tensor(-0.1068, dtype=torch.float64)
# loss 104.16510820388794
# mean tensor(7.4000, dtype=torch.float64) y is tensor(9)
# tensor(-0.1318, dtype=torch.float64)
# loss 122.72688150405884
# mean tensor(6., dtype=torch.float64) y is tensor(6)
# tensor(-0.1143, dtype=torch.float64)
# loss 119.91148281097412
# mean tensor(8., dtype=torch.float64) y is tensor(4)
# tensor(0.0664, dtype=torch.float64)
# loss 114.85721826553345
# mean tensor(1.9000, dtype=torch.float64) y is tensor(2)
# tensor(-0.0418, dtype=torch.float64)
# loss 93.12647032737732
# mean tensor(0.2500, dtype=torch.float64) y is tensor(0)
# tensor(0.1311, dtype=torch.float64)
# loss 79.44839692115784
# mean tensor(7.1000, dtype=torch.float64) y is tensor(7)
# tensor(0.1326, dtype=torch.float64)
# loss 126.7923173904419
# mean tensor(7., dtype=torch.float64) y is tensor(7)
# tensor(0.1498, dtype=torch.float64)
# loss 114.20496654510498
# mean tensor(8.2500, dtype=torch.float64) y is tensor(9)
# tensor(0.1912, dtype=torch.float64)
# loss 76.94008684158325
# mean tensor(9., dtype=torch.float64) y is tensor(9)
# tensor(0.2404, dtype=torch.float64)
# loss 95.01912260055542
# mean tensor(4.5000, dtype=torch.float64) y is tensor(4)
# tensor(0.1350, dtype=torch.float64)
# loss 79.29232597351074
# mean tensor(6., dtype=torch.float64) y is tensor(6)
# tensor(0.0768, dtype=torch.float64)
# loss 130.39364910125732
# mean tensor(0., dtype=torch.float64) y is tensor(0)
# tensor(0.1514, dtype=torch.float64)
# loss 89.03964805603027
# mean tensor(3.5000, dtype=torch.float64) y is tensor(3)
# tensor(0.0406, dtype=torch.float64)
# loss 107.57815170288086
# mean tensor(4.1500, dtype=torch.float64) y is tensor(4)
# tensor(0.0377, dtype=torch.float64)
# loss 88.33442306518555
# mean tensor(5.3000, dtype=torch.float64) y is tensor(5)
# tensor(0.0131, dtype=torch.float64)
# loss 99.3287992477417
# mean tensor(3., dtype=torch.float64) y is tensor(3)
# tensor(-0.0359, dtype=torch.float64)
# loss 100.23446083068848
# mean tensor(0., dtype=torch.float64) y is tensor(0)
# tensor(-0.1064, dtype=torch.float64)
# loss 110.21305727958679
# mean tensor(8., dtype=torch.float64) y is tensor(8)
# tensor(-0.1770, dtype=torch.float64)
# loss 152.87661755084991
# mean tensor(7.4500, dtype=torch.float64) y is tensor(8)
# tensor(-0.1963, dtype=torch.float64)
# loss 111.4936466217041
# mean tensor(7., dtype=torch.float64) y is tensor(7)
# tensor(-0.0248, dtype=torch.float64)
# loss 102.30778694152832
# mean tensor(3., dtype=torch.float64) y is tensor(3)
# tensor(-0.1135, dtype=torch.float64)
# loss 108.40654826164246
# mean tensor(4.1000, dtype=torch.float64) y is tensor(4)
# tensor(0.0859, dtype=torch.float64)
# loss 100.51602900028229
# mean tensor(7.1000, dtype=torch.float64) y is tensor(7)
# tensor(-0.0852, dtype=torch.float64)
# loss 92.78816604614258
# mean tensor(7.3500, dtype=torch.float64) y is tensor(7)
# tensor(0.1021, dtype=torch.float64)
# loss 100.15044832229614
# mean tensor(8.5000, dtype=torch.float64) y is tensor(9)
# tensor(-0.0568, dtype=torch.float64)
# loss 106.45672988891602
# mean tensor(8.0500, dtype=torch.float64) y is tensor(9)
# tensor(0.0477, dtype=torch.float64)
# loss 84.68652439117432
# mean tensor(6., dtype=torch.float64) y is tensor(6)
# tensor(-0.0574, dtype=torch.float64)
# loss 85.30573463439941
# mean tensor(6., dtype=torch.float64) y is tensor(6)
# tensor(0.0104, dtype=torch.float64)
# loss 115.84637546539307
# mean tensor(7.4000, dtype=torch.float64) y is tensor(7)
# tensor(-0.0271, dtype=torch.float64)
# loss 98.56002473831177
# mean tensor(9., dtype=torch.float64) y is tensor(9)
# tensor(0.0869, dtype=torch.float64)
# loss 141.8257350921631
# mean tensor(4., dtype=torch.float64) y is tensor(4)
# tensor(0.1393, dtype=torch.float64)
# loss 146.7090995311737
# mean tensor(5., dtype=torch.float64) y is tensor(4)
# tensor(0.3143, dtype=torch.float64)
# loss 93.40565967559814
# mean tensor(2., dtype=torch.float64) y is tensor(2)
# tensor(0.1869, dtype=torch.float64)
# loss 163.22571468353271
# mean tensor(5., dtype=torch.float64) y is tensor(5)
# tensor(0.2451, dtype=torch.float64)
# loss 116.36570739746094
# mean tensor(1.5500, dtype=torch.float64) y is tensor(0)
# tensor(-0.1789, dtype=torch.float64)
# loss 135.39495873451233
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# tensor(-0.1494, dtype=torch.float64)
# loss 99.11452007293701
# mean tensor(8., dtype=torch.float64) y is tensor(9)
# tensor(-0.0561, dtype=torch.float64)
# loss 71.2914924621582
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# tensor(0.0143, dtype=torch.float64)
# loss 94.58977127075195
# mean tensor(7., dtype=torch.float64) y is tensor(7)
# tensor(-0.2006, dtype=torch.float64)
# loss 133.71141815185547
# mean tensor(5.3500, dtype=torch.float64) y is tensor(5)
# tensor(-0.2326, dtype=torch.float64)
# loss 100.2219467163086
# mean tensor(0., dtype=torch.float64) y is tensor(0)
# tensor(-0.0359, dtype=torch.float64)
# loss 96.87181681394577
# mean tensor(7.2000, dtype=torch.float64) y is tensor(8)
# tensor(-0.1805, dtype=torch.float64)
# loss 105.25891733169556
# mean tensor(5.4500, dtype=torch.float64) y is tensor(5)
# tensor(-0.1363, dtype=torch.float64)
# loss 109.6452624797821
# mean tensor(4.4000, dtype=torch.float64) y is tensor(4)
# tensor(-0.0490, dtype=torch.float64)
# loss 115.49975752830505
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# tensor(0.1422, dtype=torch.float64)
# loss 102.33287906646729
# mean tensor(3.1000, dtype=torch.float64) y is tensor(3)
# tensor(0.1645, dtype=torch.float64)
# loss 97.25544840097427
# mean tensor(3.1000, dtype=torch.float64) y is tensor(3)
# tensor(0.1451, dtype=torch.float64)
# loss 95.54195404052734
# mean tensor(6.8000, dtype=torch.float64) y is tensor(7)
# tensor(0.1596, dtype=torch.float64)
# loss 128.68020462989807
# mean tensor(7.1000, dtype=torch.float64) y is tensor(7)
# tensor(0.1219, dtype=torch.float64)
# loss 120.6224889755249
# mean tensor(2., dtype=torch.float64) y is tensor(2)
# tensor(0.2207, dtype=torch.float64)
# loss 111.9481029510498
# mean tensor(5.5000, dtype=torch.float64) y is tensor(5)
# tensor(0.1152, dtype=torch.float64)
# loss 87.14888107776642
# mean tensor(7., dtype=torch.float64) y is tensor(7)
# tensor(0.0609, dtype=torch.float64)
# loss 39.428879737854004
# mean tensor(2., dtype=torch.float64) y is tensor(2)
# tensor(-0.0026, dtype=torch.float64)
# loss 102.4837052822113
# mean tensor(7., dtype=torch.float64) y is tensor(7)
# tensor(0.0533, dtype=torch.float64)
# loss 102.0939269065857
# mean tensor(8., dtype=torch.float64) y is tensor(8)
# tensor(-0.0187, dtype=torch.float64)
# loss 109.33548927307129
# mean tensor(4.7000, dtype=torch.float64) y is tensor(8)
# tensor(-0.0848, dtype=torch.float64)
# loss 97.63194370269775
# mean tensor(5.4000, dtype=torch.float64) y is tensor(5)
# tensor(-0.1082, dtype=torch.float64)
# loss 75.74915504455566
# mean tensor(7., dtype=torch.float64) y is tensor(7)
# tensor(-0.0965, dtype=torch.float64)
# loss 99.57666540145874
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# tensor(0.0021, dtype=torch.float64)
# loss 99.18325996398926
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# tensor(-0.1211, dtype=torch.float64)
# loss 99.31632041931152
# mean tensor(4., dtype=torch.float64) y is tensor(4)
# tensor(-0.1389, dtype=torch.float64)
# loss 125.6706895828247
# mean tensor(7.7500, dtype=torch.float64) y is tensor(9)
# tensor(-0.1094, dtype=torch.float64)
# loss 101.72285056114197
# mean tensor(6., dtype=torch.float64) y is tensor(6)
# tensor(-0.0807, dtype=torch.float64)
# loss 98.51953506469727
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# tensor(-0.0324, dtype=torch.float64)
# loss 92.8626561164856
# mean tensor(4.3000, dtype=torch.float64) y is tensor(4)
# tensor(-0.0150, dtype=torch.float64)
# loss 115.58781337738037
# mean tensor(2., dtype=torch.float64) y is tensor(2)
# tensor(-0.0174, dtype=torch.float64)
# loss 110.39564228057861
# mean tensor(7., dtype=torch.float64) y is tensor(7)
# tensor(0.1807, dtype=torch.float64)
# loss 87.44783210754395
# mean tensor(4., dtype=torch.float64) y is tensor(4)
# tensor(0.0885, dtype=torch.float64)
# loss 83.1065263748169
# mean tensor(3., dtype=torch.float64) y is tensor(3)
# tensor(0.1836, dtype=torch.float64)
# loss 85.5220217704773
# mean tensor(7.1000, dtype=torch.float64) y is tensor(7)
# tensor(0.1479, dtype=torch.float64)
# loss 94.40077209472656
# mean tensor(4., dtype=torch.float64) y is tensor(4)
# tensor(0.0494, dtype=torch.float64)
# loss 126.54601383209229
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# tensor(0.0416, dtype=torch.float64)
# loss 89.61613464355469
# mean tensor(9., dtype=torch.float64) y is tensor(9)
# tensor(-0.0596, dtype=torch.float64)
# loss 99.01963710784912
# mean tensor(7.1000, dtype=torch.float64) y is tensor(4)
# tensor(-0.0166, dtype=torch.float64)
# loss 87.92928928136826
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# tensor(-0.1920, dtype=torch.float64)
# loss 93.16504001617432
# mean tensor(2.5000, dtype=torch.float64) y is tensor(2)
# tensor(-0.1529, dtype=torch.float64)
# loss 94.69370651245117
# mean tensor(0., dtype=torch.float64) y is tensor(0)
# tensor(-0.1631, dtype=torch.float64)
# loss 99.24257230758667
# mean tensor(0., dtype=torch.float64) y is tensor(0)
# tensor(-0.0334, dtype=torch.float64)
# loss 101.99619770050049
# mean tensor(3.9500, dtype=torch.float64) y is tensor(9)
# tensor(-0.0682, dtype=torch.float64)
# loss 132.53579783439636
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# tensor(0.0074, dtype=torch.float64)
# loss 96.18832492828369
# mean tensor(1., dtype=torch.float64) y is tensor(0)
# tensor(0.0229, dtype=torch.float64)
# loss 96.02729415893555
# mean tensor(3., dtype=torch.float64) y is tensor(3)
# tensor(0.0057, dtype=torch.float64)
# loss 96.4217176437378
# mean tensor(3., dtype=torch.float64) y is tensor(3)
# tensor(0.0326, dtype=torch.float64)
# loss 63.07287120819092
# mean tensor(8.9000, dtype=torch.float64) y is tensor(9)
# tensor(0.1100, dtype=torch.float64)
# loss 83.29719686508179
# mean tensor(8.1000, dtype=torch.float64) y is tensor(9)
# tensor(0.0797, dtype=torch.float64)
# loss 87.55261707305908
# mean tensor(4.6500, dtype=torch.float64) y is tensor(5)
# tensor(-0.0916, dtype=torch.float64)
# loss 76.21032071113586
# mean tensor(3., dtype=torch.float64) y is tensor(3)
# tensor(0.1189, dtype=torch.float64)
# loss 106.93098545074463
# mean tensor(4.4000, dtype=torch.float64) y is tensor(5)
# tensor(-0.0658, dtype=torch.float64)
# loss 118.73211288452148
# mean tensor(8.9000, dtype=torch.float64) y is tensor(9)
# tensor(-0.0453, dtype=torch.float64)
# loss 100.61408424377441
# mean tensor(4.4000, dtype=torch.float64) y is tensor(2)
# tensor(-0.0246, dtype=torch.float64)
# loss 98.03881645202637
# mean tensor(6., dtype=torch.float64) y is tensor(6)
# tensor(-0.0020, dtype=torch.float64)
# loss 101.28639507293701
# mean tensor(8., dtype=torch.float64) y is tensor(8)
# tensor(0.0182, dtype=torch.float64)
# loss 99.79735517501831
# mean tensor(2.2000, dtype=torch.float64) y is tensor(2)
# tensor(-0.0211, dtype=torch.float64)
# loss 115.74383878707886
# mean tensor(8., dtype=torch.float64) y is tensor(8)
# tensor(0.0695, dtype=torch.float64)
# loss 116.77467322349548
# mean tensor(6.7000, dtype=torch.float64) y is tensor(8)
# tensor(0.0914, dtype=torch.float64)
# loss 112.50702428817749
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# tensor(-0.0646, dtype=torch.float64)
# loss 97.21291637420654
# mean tensor(3.3000, dtype=torch.float64) y is tensor(3)
# tensor(0.0275, dtype=torch.float64)
# loss 138.20530033111572
# mean tensor(3.0500, dtype=torch.float64) y is tensor(3)
# tensor(-1.3878e-17, dtype=torch.float64)
# loss 115.31863021850586
# mean tensor(7.5000, dtype=torch.float64) y is tensor(8)
# tensor(0.1010, dtype=torch.float64)
# loss 108.93046379089355
# mean tensor(8., dtype=torch.float64) y is tensor(8)
# tensor(0.0934, dtype=torch.float64)
# loss 116.87261438369751
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# tensor(0.0172, dtype=torch.float64)
# loss 104.98878002166748
# mean tensor(9., dtype=torch.float64) y is tensor(9)
# tensor(0.0391, dtype=torch.float64)
# loss 117.87769031524658
# mean tensor(6., dtype=torch.float64) y is tensor(6)
# tensor(0.0328, dtype=torch.float64)
# loss 111.45921802520752
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# tensor(0.0574, dtype=torch.float64)
# loss 94.93888998031616
# mean tensor(9., dtype=torch.float64) y is tensor(9)
# tensor(-0.0127, dtype=torch.float64)
# loss 115.1195011138916
# mean tensor(6., dtype=torch.float64) y is tensor(6)
# tensor(-0.1105, dtype=torch.float64)
# loss 112.69956016540527
# mean tensor(2., dtype=torch.float64) y is tensor(2)
# tensor(-0.0092, dtype=torch.float64)
# loss 108.40451431274414
# mean tensor(7.1000, dtype=torch.float64) y is tensor(7)
# tensor(-0.0207, dtype=torch.float64)
# loss 120.09221839904785
# mean tensor(4.1000, dtype=torch.float64) y is tensor(5)
# tensor(-0.0578, dtype=torch.float64)
# loss 106.0954122543335
# mean tensor(7., dtype=torch.float64) y is tensor(7)
# tensor(-0.1184, dtype=torch.float64)
# loss 97.4101185798645
# mean tensor(9., dtype=torch.float64) y is tensor(9)
# tensor(-0.1453, dtype=torch.float64)
# loss 95.63082027435303
# mean tensor(8., dtype=torch.float64) y is tensor(8)
# tensor(-0.0119, dtype=torch.float64)
# loss 106.55313777923584
# mean tensor(2.0500, dtype=torch.float64) y is tensor(2)
# tensor(-0.0688, dtype=torch.float64)
# loss 97.9421854019165
# mean tensor(0.2000, dtype=torch.float64) y is tensor(0)
# tensor(0.0965, dtype=torch.float64)
# loss 89.7940902709961
# mean tensor(7.8500, dtype=torch.float64) y is tensor(8)
# tensor(-0.0293, dtype=torch.float64)
# loss 116.46881294250488
# mean tensor(9., dtype=torch.float64) y is tensor(9)
# tensor(0.0814, dtype=torch.float64)
# loss 100.68982172012329
# mean tensor(7., dtype=torch.float64) y is tensor(7)
# tensor(0.1453, dtype=torch.float64)
# loss 76.76689958572388
# mean tensor(6., dtype=torch.float64) y is tensor(6)
# tensor(0.1055, dtype=torch.float64)
# loss 141.50816822052002
# mean tensor(6., dtype=torch.float64) y is tensor(6)
# tensor(0.1451, dtype=torch.float64)
# loss 162.332124710083
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# tensor(0.2355, dtype=torch.float64)
# loss 93.97992706298828
# mean tensor(4.3000, dtype=torch.float64) y is tensor(4)
# tensor(0.1246, dtype=torch.float64)
# loss 81.6160364151001
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# tensor(0.0568, dtype=torch.float64)
# loss 120.673330783844
# mean tensor(6., dtype=torch.float64) y is tensor(6)
# tensor(0.1414, dtype=torch.float64)
# loss 112.71187686920166
# mean tensor(3.5000, dtype=torch.float64) y is tensor(3)
# tensor(0.0021, dtype=torch.float64)
# loss 93.34348201751709
# mean tensor(6., dtype=torch.float64) y is tensor(6)
# tensor(0., dtype=torch.float64)
# loss 85.67411661148071
# mean tensor(7., dtype=torch.float64) y is tensor(7)
# tensor(-0.0293, dtype=torch.float64)
# loss 122.76509189605713
# mean tensor(7., dtype=torch.float64) y is tensor(7)
# tensor(-0.0840, dtype=torch.float64)
# loss 118.98472356796265
# mean tensor(2., dtype=torch.float64) y is tensor(2)
# tensor(-0.1910, dtype=torch.float64)
# loss 100.12257671356201
# mean tensor(8.2000, dtype=torch.float64) y is tensor(7)
# tensor(0.0662, dtype=torch.float64)
# loss 97.9449815750122
# mean tensor(8.4000, dtype=torch.float64) y is tensor(9)
# tensor(0.1201, dtype=torch.float64)
# loss 95.53037929534912
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# tensor(-0.0678, dtype=torch.float64)
# loss 129.32457542419434
# mean tensor(6., dtype=torch.float64) y is tensor(6)
# tensor(0.0150, dtype=torch.float64)
# loss 108.63228988647461
# mean tensor(8.0500, dtype=torch.float64) y is tensor(8)
# tensor(-0.1146, dtype=torch.float64)
# loss 90.64004898071289
# mean tensor(6., dtype=torch.float64) y is tensor(6)
# tensor(-0.0650, dtype=torch.float64)
# loss 104.99900817871094
# mean tensor(4.6500, dtype=torch.float64) y is tensor(5)
# tensor(-0.0215, dtype=torch.float64)
# loss 110.92168521881104
# mean tensor(8.5500, dtype=torch.float64) y is tensor(4)
# tensor(-0.1205, dtype=torch.float64)
# loss 126.72408866882324
# mean tensor(4.7500, dtype=torch.float64) y is tensor(9)
# tensor(-0.0846, dtype=torch.float64)
# loss 112.2729377746582
# mean tensor(7., dtype=torch.float64) y is tensor(7)
# tensor(0.1332, dtype=torch.float64)
# loss 129.37026023864746
# mean tensor(7., dtype=torch.float64) y is tensor(7)
# tensor(0.0447, dtype=torch.float64)
# loss 87.4558367729187
# mean tensor(4., dtype=torch.float64) y is tensor(4)
# tensor(0.0926, dtype=torch.float64)
# loss 103.32161259651184
# mean tensor(6., dtype=torch.float64) y is tensor(6)
# tensor(0.1697, dtype=torch.float64)
# loss 128.91340827941895
# mean tensor(4., dtype=torch.float64) y is tensor(4)
# tensor(0.2699, dtype=torch.float64)
# loss 105.76455307006836
# mean tensor(6.0500, dtype=torch.float64) y is tensor(8)
# tensor(0.1512, dtype=torch.float64)
# loss 100.28887605667114
# mean tensor(3., dtype=torch.float64) y is tensor(3)
# tensor(0.1830, dtype=torch.float64)
# loss 115.05305790901184
# mean tensor(4., dtype=torch.float64) y is tensor(3)
# tensor(0.1428, dtype=torch.float64)
# loss 76.03677892684937
# mean tensor(6.4500, dtype=torch.float64) y is tensor(4)
# tensor(0.0002, dtype=torch.float64)
# loss 85.75852298736572
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# tensor(0.0742, dtype=torch.float64)
# loss 88.7177906036377
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# tensor(-0.0291, dtype=torch.float64)
# loss 118.93184089660645
# mean tensor(3.7000, dtype=torch.float64) y is tensor(5)
# tensor(-0.0998, dtype=torch.float64)
# loss 108.75412178039551
# mean tensor(0.4500, dtype=torch.float64) y is tensor(0)
# tensor(-0.0508, dtype=torch.float64)
# loss 109.99374532699585
# mean tensor(7., dtype=torch.float64) y is tensor(7)
# tensor(0.0437, dtype=torch.float64)
# loss 171.78320837020874
# mean tensor(3.4500, dtype=torch.float64) y is tensor(2)
# tensor(0.2521, dtype=torch.float64)
# loss 98.99272918701172
# mean tensor(6.9500, dtype=torch.float64) y is tensor(7)
# tensor(-0.0055, dtype=torch.float64)
# loss 113.55296516418457
# mean tensor(3.2500, dtype=torch.float64) y is tensor(3)
# tensor(0.0859, dtype=torch.float64)
# loss 127.32231521606445
# mean tensor(5.3500, dtype=torch.float64) y is tensor(5)
# tensor(-0.0227, dtype=torch.float64)
# loss 85.37384605407715
# mean tensor(0., dtype=torch.float64) y is tensor(0)
# tensor(0.0098, dtype=torch.float64)
# loss 113.53990840911865
# mean tensor(6.5000, dtype=torch.float64) y is tensor(8)
# tensor(-0.0607, dtype=torch.float64)
# loss 86.18600559234619
# mean tensor(2., dtype=torch.float64) y is tensor(2)
# tensor(0.0010, dtype=torch.float64)
# loss 120.78549289703369
# mean tensor(7., dtype=torch.float64) y is tensor(7)
# tensor(-0.1061, dtype=torch.float64)
# loss 84.71610927581787
# mean tensor(5.7000, dtype=torch.float64) y is tensor(6)
# tensor(-0.0051, dtype=torch.float64)
# loss 82.91279458999634
# mean tensor(7.7000, dtype=torch.float64) y is tensor(8)
# tensor(-0.0162, dtype=torch.float64)
# loss 117.4890604019165
# mean tensor(7., dtype=torch.float64) y is tensor(7)
# tensor(-0.0500, dtype=torch.float64)
# loss 98.30393886566162
# mean tensor(0., dtype=torch.float64) y is tensor(0)
# tensor(-0.0354, dtype=torch.float64)
# loss 112.16401863098145
# mean tensor(0., dtype=torch.float64) y is tensor(0)
# tensor(-0.1467, dtype=torch.float64)
# loss 109.1724214553833
# mean tensor(4., dtype=torch.float64) y is tensor(4)
# tensor(-0.0072, dtype=torch.float64)
# loss 93.24445819854736
# mean tensor(1.3500, dtype=torch.float64) y is tensor(1)
# tensor(-0.0842, dtype=torch.float64)
# loss 120.02631092071533
# mean tensor(4.4000, dtype=torch.float64) y is tensor(0)
# tensor(0.1699, dtype=torch.float64)
# loss 88.60687732696533
# mean tensor(0., dtype=torch.float64) y is tensor(0)
# tensor(0.1266, dtype=torch.float64)
# loss 75.8862886428833
# mean tensor(7.7000, dtype=torch.float64) y is tensor(8)
# tensor(0.1152, dtype=torch.float64)
# loss 112.74690532684326
# mean tensor(1.1000, dtype=torch.float64) y is tensor(0)
# tensor(-0.0305, dtype=torch.float64)
# loss 102.32780265808105
# mean tensor(9., dtype=torch.float64) y is tensor(9)
# tensor(0.0549, dtype=torch.float64)
# loss 81.79668617248535
# mean tensor(6.5000, dtype=torch.float64) y is tensor(9)
# tensor(0.1434, dtype=torch.float64)
# loss 113.51294684410095
# mean tensor(0., dtype=torch.float64) y is tensor(0)
# tensor(0.0006, dtype=torch.float64)
# loss 83.47374439239502
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# tensor(0.1473, dtype=torch.float64)
# loss 102.47955465316772
# mean tensor(8., dtype=torch.float64) y is tensor(8)
# tensor(-0.1109, dtype=torch.float64)
# loss 74.59835433959961
# mean tensor(2., dtype=torch.float64) y is tensor(2)
# tensor(0.0029, dtype=torch.float64)
# loss 77.44760656356812
# mean tensor(6., dtype=torch.float64) y is tensor(6)
# tensor(-0.0951, dtype=torch.float64)
# loss 117.5381498336792
# mean tensor(7., dtype=torch.float64) y is tensor(5)
# tensor(-0.0070, dtype=torch.float64)
# loss 121.272531747818
# mean tensor(0.5500, dtype=torch.float64) y is tensor(0)
# tensor(-0.0672, dtype=torch.float64)
# loss 97.10739612579346
# mean tensor(6., dtype=torch.float64) y is tensor(6)
# tensor(-0.2037, dtype=torch.float64)
# loss 123.08952617645264
# mean tensor(2.6500, dtype=torch.float64) y is tensor(8)
# tensor(-0.1795, dtype=torch.float64)
# loss 108.73819160461426
# mean tensor(2., dtype=torch.float64) y is tensor(2)
# tensor(-0.1572, dtype=torch.float64)
# loss 84.09272718429565
# mean tensor(6.1500, dtype=torch.float64) y is tensor(8)
# tensor(0.0672, dtype=torch.float64)
# loss 85.6529483795166
# mean tensor(7.5000, dtype=torch.float64) y is tensor(8)
# tensor(0.0842, dtype=torch.float64)
# loss 92.2231216430664
# mean tensor(1.1000, dtype=torch.float64) y is tensor(1)
# tensor(-0.0498, dtype=torch.float64)
# loss 79.70802974700928
# mean tensor(8., dtype=torch.float64) y is tensor(8)
# tensor(0.1354, dtype=torch.float64)
# loss 70.49874114990234
# mean tensor(5.3000, dtype=torch.float64) y is tensor(5)
# tensor(0.0977, dtype=torch.float64)
# loss 104.86023473739624
# mean tensor(2., dtype=torch.float64) y is tensor(2)
# tensor(0.2609, dtype=torch.float64)
# loss 130.48406410217285
# mean tensor(7.3000, dtype=torch.float64) y is tensor(7)
# tensor(0.1385, dtype=torch.float64)
# loss 124.89528369903564
# mean tensor(5.1500, dtype=torch.float64) y is tensor(5)
# tensor(-0.0605, dtype=torch.float64)
# loss 136.1039843559265
# mean tensor(4., dtype=torch.float64) y is tensor(4)
# tensor(0.1953, dtype=torch.float64)
# loss 95.52602767944336
# mean tensor(1.5500, dtype=torch.float64) y is tensor(5)
# tensor(0.1592, dtype=torch.float64)
# loss 73.71762084960938
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# tensor(0.0037, dtype=torch.float64)
# loss 103.48076057434082
# mean tensor(1.1500, dtype=torch.float64) y is tensor(2)
# tensor(-0.0615, dtype=torch.float64)
# loss 125.11636352539062
# mean tensor(0.1000, dtype=torch.float64) y is tensor(0)
# tensor(-0.1475, dtype=torch.float64)
# loss 88.93697166442871
# mean tensor(4.1500, dtype=torch.float64) y is tensor(8)
# tensor(0.0553, dtype=torch.float64)
# loss 111.25652074813843
# mean tensor(2.0500, dtype=torch.float64) y is tensor(2)
# tensor(-0.1914, dtype=torch.float64)
# loss 100.06105041503906
# mean tensor(0., dtype=torch.float64) y is tensor(0)
# tensor(0.1111, dtype=torch.float64)
# loss 127.11767435073853
# mean tensor(7., dtype=torch.float64) y is tensor(7)
# tensor(-0.0111, dtype=torch.float64)
# loss 103.07769680023193
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# tensor(0.1590, dtype=torch.float64)
# loss 94.39480876922607
# mean tensor(3., dtype=torch.float64) y is tensor(3)
# tensor(-0.0244, dtype=torch.float64)
# loss 120.13622951507568
# mean tensor(0., dtype=torch.float64) y is tensor(0)
# tensor(0.1982, dtype=torch.float64)
# loss 105.82191467285156
# mean tensor(4.9500, dtype=torch.float64) y is tensor(8)
# tensor(-0.0416, dtype=torch.float64)
# loss 108.3533034324646
# mean tensor(3., dtype=torch.float64) y is tensor(3)
# tensor(-0.0830, dtype=torch.float64)
# loss 82.66717052459717
# mean tensor(9., dtype=torch.float64) y is tensor(9)
# tensor(0.0621, dtype=torch.float64)
# loss 90.89503955841064
# mean tensor(4.2000, dtype=torch.float64) y is tensor(2)
# tensor(0.1691, dtype=torch.float64)
# loss 102.53872680664062
# mean tensor(8., dtype=torch.float64) y is tensor(8)
# tensor(0.0916, dtype=torch.float64)
# loss 86.33650970458984
# mean tensor(7.8500, dtype=torch.float64) y is tensor(9)
# tensor(0.0488, dtype=torch.float64)
# loss 107.28565788269043
# mean tensor(5., dtype=torch.float64) y is tensor(5)
# tensor(-0.0783, dtype=torch.float64)
# loss 120.61113452911377
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# tensor(-0.1586, dtype=torch.float64)
# loss 77.01705360412598
# mean tensor(4.2500, dtype=torch.float64) y is tensor(4)
# tensor(-0.0723, dtype=torch.float64)
# loss 97.32555103302002
# mean tensor(4., dtype=torch.float64) y is tensor(4)
# tensor(-0.0361, dtype=torch.float64)
# loss 89.3013858795166
# mean tensor(7., dtype=torch.float64) y is tensor(7)
# tensor(0.0270, dtype=torch.float64)
# loss 102.17099332809448
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# tensor(-0.0969, dtype=torch.float64)
# loss 79.44826716184616
# mean tensor(4., dtype=torch.float64) y is tensor(4)
# tensor(-0.0119, dtype=torch.float64)
# loss 81.87425518035889
# mean tensor(4., dtype=torch.float64) y is tensor(4)
# tensor(0.0770, dtype=torch.float64)
# loss 100.34398365020752
# mean tensor(4.8000, dtype=torch.float64) y is tensor(5)
# tensor(-0.0258, dtype=torch.float64)
# loss 92.92541599273682
# mean tensor(4., dtype=torch.float64) y is tensor(4)
# tensor(-0.2117, dtype=torch.float64)
# loss 89.01400089263916
# mean tensor(2., dtype=torch.float64) y is tensor(2)
# tensor(-0.0662, dtype=torch.float64)
# loss 111.64556217193604
# mean tensor(4.6000, dtype=torch.float64) y is tensor(4)
# tensor(-0.0447, dtype=torch.float64)
# loss 94.28902578353882
# mean tensor(5.8000, dtype=torch.float64) y is tensor(6)
# tensor(-0.0961, dtype=torch.float64)
# loss 129.65955543518066
# mean tensor(8.6500, dtype=torch.float64) y is tensor(9)
# tensor(-0.0467, dtype=torch.float64)
# loss 95.77010583877563
# mean tensor(3., dtype=torch.float64) y is tensor(3)
# tensor(0.0258, dtype=torch.float64)
# loss 72.51539468765259
# mean tensor(8.7500, dtype=torch.float64) y is tensor(9)
# tensor(0.1123, dtype=torch.float64)
# loss 101.03796577453613
# mean tensor(4.2500, dtype=torch.float64) y is tensor(4)
# tensor(-0.1842, dtype=torch.float64)
# loss 91.20447874069214
# mean tensor(3.4000, dtype=torch.float64) y is tensor(6)
# tensor(-0.0066, dtype=torch.float64)
# loss 118.69394588470459
# mean tensor(5., dtype=torch.float64) y is tensor(3)
# tensor(-0.0615, dtype=torch.float64)
# loss 147.43233442306519
# mean tensor(4.7500, dtype=torch.float64) y is tensor(5)
# tensor(-0.1402, dtype=torch.float64)
# loss 118.02958297729492
# mean tensor(0., dtype=torch.float64) y is tensor(0)
# tensor(0.1291, dtype=torch.float64)
# loss 83.0953221321106
# mean tensor(5., dtype=torch.float64) y is tensor(4)
# tensor(0.0666, dtype=torch.float64)
# loss 115.0775580406189
# mean tensor(2., dtype=torch.float64) y is tensor(2)
# tensor(-0.0924, dtype=torch.float64)
# loss 100.6096363067627
# mean tensor(6., dtype=torch.float64) y is tensor(6)
# tensor(-0.0004, dtype=torch.float64)
# loss 88.75327634811401
# mean tensor(2., dtype=torch.float64) y is tensor(2)
# tensor(-0.0400, dtype=torch.float64)
# loss 112.38811111450195
# mean tensor(0., dtype=torch.float64) y is tensor(0)
# tensor(-0.0303, dtype=torch.float64)
# loss 87.36959171295166
# mean tensor(6.5000, dtype=torch.float64) y is tensor(3)
# tensor(-0.0551, dtype=torch.float64)
# loss 89.82320499420166
# mean tensor(4., dtype=torch.float64) y is tensor(4)
# tensor(0.0994, dtype=torch.float64)
# loss 88.37380886077881
# mean tensor(4.5500, dtype=torch.float64) y is tensor(6)
# tensor(0.0422, dtype=torch.float64)
# loss 114.94107723236084
# mean tensor(7.9500, dtype=torch.float64) y is tensor(8)
# tensor(-0.0932, dtype=torch.float64)
# loss 69.47379970550537
# ...
# loss 82.36676979064941
# mean tensor(7., dtype=torch.float64) y is tensor(7)
# tensor(-0.0922, dtype=torch.float64)
# loss 75.36786413192749
# mean tensor(3.1500, dtype=torch.float64) y is tensor(3)
# tensor(-0.0217, dtype=torch.float64)
# loss 67.90523338317871
# mean tensor(6.8500, dtype=torch.float64) y is tensor(8)
# tensor(-0.0855, dtype=torch.float64)
# loss 67.99691772460938
# mean tensor(0., dtype=torch.float64) y is tensor(0)
# tensor(-0.0592, dtype=torch.float64)
# loss 86.08366775512695
# mean tensor(4., dtype=torch.float64) y is tensor(4)
# tensor(-0.0568, dtype=torch.float64)
# loss 68.04201793670654
# mean tensor(5.1500, dtype=torch.float64) y is tensor(5)
# tensor(0.0352, dtype=torch.float64)
# loss 84.57716464996338
# mean tensor(0., dtype=torch.float64) y is tensor(0)
# tensor(-0.0461, dtype=torch.float64)
# loss 76.43940162658691
# mean tensor(6.4500, dtype=torch.float64) y is tensor(7)
# tensor(-0.0334, dtype=torch.float64)
# loss 96.54141616821289
# mean tensor(8.5500, dtype=torch.float64) y is tensor(9)
# tensor(-0.0055, dtype=torch.float64)
# loss 88.74312591552734
# mean tensor(5.1500, dtype=torch.float64) y is tensor(6)
# tensor(0.0152, dtype=torch.float64)
# loss 79.99245548248291
# mean tensor(3.6000, dtype=torch.float64) y is tensor(5)
# tensor(0.0314, dtype=torch.float64)
# loss 76.75339794158936
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# tensor(0.0771, dtype=torch.float64)
# loss 91.38395690917969
# mean tensor(5.3500, dtype=torch.float64) y is tensor(5)
# tensor(-0.0477, dtype=torch.float64)
# loss 82.56477165222168
# mean tensor(6., dtype=torch.float64) y is tensor(6)
# tensor(0.0811, dtype=torch.float64)
# loss 80.61592102050781
# mean tensor(4.9000, dtype=torch.float64) y is tensor(5)
# tensor(-0.0461, dtype=torch.float64)
# loss 70.54484272003174
# mean tensor(3., dtype=torch.float64) y is tensor(3)
# tensor(0.0240, dtype=torch.float64)
# loss 90.7983169555664
# mean tensor(9., dtype=torch.float64) y is tensor(9)
# tensor(-0.0752, dtype=torch.float64)
# loss 101.89088726043701
# mean tensor(3., dtype=torch.float64) y is tensor(3)
# tensor(-0.0883, dtype=torch.float64)
# loss 94.54752254486084
# mean tensor(8.5000, dtype=torch.float64) y is tensor(9)
# tensor(-0.1447, dtype=torch.float64)
# loss 77.4220323562622
# mean tensor(7., dtype=torch.float64) y is tensor(7)
# tensor(-0.0021, dtype=torch.float64)
# loss 67.26461791992188
# mean tensor(3.2000, dtype=torch.float64) y is tensor(3)
# tensor(-0.0461, dtype=torch.float64)
# loss 102.07641506195068
# mean tensor(5.9500, dtype=torch.float64) y is tensor(5)
# tensor(-0.1398, dtype=torch.float64)
# loss 128.3881778717041
# mean tensor(3., dtype=torch.float64) y is tensor(2)
# tensor(-0.0479, dtype=torch.float64)
# loss 61.25432014465332
# mean tensor(6., dtype=torch.float64) y is tensor(6)
# tensor(-0.0771, dtype=torch.float64)
# loss 83.74493312835693
# mean tensor(5.1000, dtype=torch.float64) y is tensor(4)
# tensor(0.1633, dtype=torch.float64)
# loss 82.74364185333252
# mean tensor(0., dtype=torch.float64) y is tensor(0)
# tensor(0.0383, dtype=torch.float64)
# loss 112.94364356994629
# mean tensor(6., dtype=torch.float64) y is tensor(6)
# tensor(-0.0727, dtype=torch.float64)
# loss 100.2755994796753
# mean tensor(4., dtype=torch.float64) y is tensor(5)
# tensor(-0.0008, dtype=torch.float64)
# loss 73.24922275543213
# mean tensor(9., dtype=torch.float64) y is tensor(9)
# tensor(0.1023, dtype=torch.float64)
# loss 104.8372163772583
# mean tensor(2., dtype=torch.float64) y is tensor(2)
# tensor(-0.0512, dtype=torch.float64)
# loss 73.7866792678833
# mean tensor(4.5000, dtype=torch.float64) y is tensor(5)
# tensor(-0.0670, dtype=torch.float64)
# loss 91.16590023040771
# mean tensor(2.1500, dtype=torch.float64) y is tensor(2)
# tensor(0.0199, dtype=torch.float64)
# loss 79.22311401367188
# mean tensor(1.3000, dtype=torch.float64) y is tensor(1)
# tensor(0.0516, dtype=torch.float64)
# loss 61.3176965713501
# mean tensor(5., dtype=torch.float64) y is tensor(5)
# tensor(0.0520, dtype=torch.float64)
# loss 91.22953701019287
# mean tensor(0., dtype=torch.float64) y is tensor(0)
# tensor(-0.0168, dtype=torch.float64)
# loss 114.41332626342773
# mean tensor(2.0500, dtype=torch.float64) y is tensor(2)
# tensor(0.0781, dtype=torch.float64)
# loss 60.58092403411865
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# tensor(-0.0590, dtype=torch.float64)
# loss 68.74568367004395
# mean tensor(6.1500, dtype=torch.float64) y is tensor(5)
# tensor(-0.0131, dtype=torch.float64)
# loss 129.1493158340454
# mean tensor(6., dtype=torch.float64) y is tensor(6)
# tensor(-0.0928, dtype=torch.float64)
# loss 81.70695400238037
# mean tensor(2.2500, dtype=torch.float64) y is tensor(2)
# tensor(-0.0684, dtype=torch.float64)
# loss 71.09101438522339
# mean tensor(8., dtype=torch.float64) y is tensor(8)
# tensor(0.0043, dtype=torch.float64)
# loss 112.0705213546753
# mean tensor(6.6000, dtype=torch.float64) y is tensor(9)
# tensor(-0.0611, dtype=torch.float64)
# loss 64.01380348205566
# mean tensor(5., dtype=torch.float64) y is tensor(5)
# tensor(-0.0646, dtype=torch.float64)
# loss 52.226088523864746
# mean tensor(8.6500, dtype=torch.float64) y is tensor(9)
# tensor(-0.1199, dtype=torch.float64)
# loss 91.36323738098145
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# tensor(-0.1674, dtype=torch.float64)
# loss 112.58311939239502
# mean tensor(3.2000, dtype=torch.float64) y is tensor(3)
# tensor(-0.1945, dtype=torch.float64)
# loss 72.65793704986572
# mean tensor(7.3000, dtype=torch.float64) y is tensor(7)
# tensor(-0.2418, dtype=torch.float64)
# loss 82.95596408843994
# mean tensor(4.4000, dtype=torch.float64) y is tensor(4)
# tensor(-0.0430, dtype=torch.float64)
# loss 63.57206439971924
# mean tensor(5.1500, dtype=torch.float64) y is tensor(5)
# tensor(-0.1057, dtype=torch.float64)
# loss 82.60124683380127
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# tensor(-0.0273, dtype=torch.float64)
# loss 73.06116104125977
# mean tensor(7., dtype=torch.float64) y is tensor(7)
# tensor(-0.0453, dtype=torch.float64)
# loss 111.3290205001831
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# tensor(-0.0340, dtype=torch.float64)
# loss 87.60732841491699
# mean tensor(7.3000, dtype=torch.float64) y is tensor(8)
# tensor(0.0404, dtype=torch.float64)
# loss 63.0777702331543
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# tensor(-0.0418, dtype=torch.float64)
# loss 90.05249404907227
# mean tensor(4.7000, dtype=torch.float64) y is tensor(6)
# tensor(0.0314, dtype=torch.float64)
# loss 66.24837875366211
# mean tensor(4.2000, dtype=torch.float64) y is tensor(4)
# tensor(0.0465, dtype=torch.float64)
# loss 83.16994380950928
# mean tensor(6.5500, dtype=torch.float64) y is tensor(9)
# tensor(0.0576, dtype=torch.float64)
# loss 75.20649147033691
# mean tensor(0., dtype=torch.float64) y is tensor(0)
# tensor(-0.0008, dtype=torch.float64)
# loss 82.40993595123291
# mean tensor(7.8500, dtype=torch.float64) y is tensor(8)
# tensor(0.1145, dtype=torch.float64)
# loss 84.72658157348633
# mean tensor(0.6000, dtype=torch.float64) y is tensor(0)
# tensor(-0.1162, dtype=torch.float64)
# loss 93.71436595916748
# mean tensor(8., dtype=torch.float64) y is tensor(8)
# tensor(-0.0414, dtype=torch.float64)
# loss 97.33233594894409
# mean tensor(2., dtype=torch.float64) y is tensor(2)
# tensor(0.0633, dtype=torch.float64)
# loss 101.77581214904785
# mean tensor(7.2000, dtype=torch.float64) y is tensor(7)
# tensor(0.2996, dtype=torch.float64)
# loss 76.46334838867188
# mean tensor(5.2500, dtype=torch.float64) y is tensor(6)
# tensor(0.2027, dtype=torch.float64)
# loss 62.56785488128662
# mean tensor(8., dtype=torch.float64) y is tensor(8)
# tensor(0.1818, dtype=torch.float64)
# loss 105.23874473571777
# mean tensor(0., dtype=torch.float64) y is tensor(0)
# tensor(0.0344, dtype=torch.float64)
# loss 61.282392501831055
# mean tensor(9., dtype=torch.float64) y is tensor(9)
# tensor(0.1059, dtype=torch.float64)
# loss 71.30694103240967
# mean tensor(5., dtype=torch.float64) y is tensor(5)
# tensor(0.0207, dtype=torch.float64)
# loss 92.90653228759766
# mean tensor(5., dtype=torch.float64) y is tensor(5)
# tensor(0.0611, dtype=torch.float64)
# loss 80.9532585144043
# mean tensor(9., dtype=torch.float64) y is tensor(9)
# tensor(-0.0910, dtype=torch.float64)
# loss 90.22877025604248
# mean tensor(3., dtype=torch.float64) y is tensor(9)
# tensor(0.0275, dtype=torch.float64)
# loss 69.94841384887695
# mean tensor(7., dtype=torch.float64) y is tensor(1)
# tensor(0.0816, dtype=torch.float64)
# loss 70.73832988739014
# mean tensor(3.1000, dtype=torch.float64) y is tensor(3)
# tensor(-0.0725, dtype=torch.float64)
# loss 81.4617280960083
# mean tensor(6., dtype=torch.float64) y is tensor(6)
# tensor(-0.0191, dtype=torch.float64)
# loss 77.6117115020752
# mean tensor(4.7500, dtype=torch.float64) y is tensor(5)
# tensor(-0.2191, dtype=torch.float64)
# loss 79.60945987701416
# mean tensor(4.7500, dtype=torch.float64) y is tensor(5)
# tensor(-0.1225, dtype=torch.float64)
# loss 70.95444011688232
# mean tensor(8.1500, dtype=torch.float64) y is tensor(9)
# tensor(-0.1457, dtype=torch.float64)
# loss 75.4791145324707
# mean tensor(7.1000, dtype=torch.float64) y is tensor(7)
# tensor(0.0184, dtype=torch.float64)
# loss 81.09073829650879
# mean tensor(6., dtype=torch.float64) y is tensor(6)
# tensor(0.1309, dtype=torch.float64)
# loss 143.75625896453857
# mean tensor(3., dtype=torch.float64) y is tensor(3)
# tensor(0.0559, dtype=torch.float64)
# loss 95.5834093093872
# mean tensor(6., dtype=torch.float64) y is tensor(6)
# tensor(0.0105, dtype=torch.float64)
# loss 63.22825813293457
# mean tensor(5., dtype=torch.float64) y is tensor(5)
# tensor(0.0646, dtype=torch.float64)
# loss 80.29442405700684
# mean tensor(4.8000, dtype=torch.float64) y is tensor(8)
# tensor(0.0371, dtype=torch.float64)
# loss 102.95365333557129
# mean tensor(6., dtype=torch.float64) y is tensor(6)
# tensor(0.0631, dtype=torch.float64)
# loss 78.93314266204834
# mean tensor(3., dtype=torch.float64) y is tensor(3)
# tensor(-0.0068, dtype=torch.float64)
# loss 75.29283142089844
# mean tensor(2.9500, dtype=torch.float64) y is tensor(2)
# tensor(0.0453, dtype=torch.float64)
# loss 74.79930210113525
# mean tensor(4., dtype=torch.float64) y is tensor(4)
# tensor(-0.0463, dtype=torch.float64)
# loss 90.11193084716797
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# tensor(-0.0391, dtype=torch.float64)
# loss 122.5660285949707
# mean tensor(8.8000, dtype=torch.float64) y is tensor(9)
# tensor(0.0604, dtype=torch.float64)
# loss 67.34672260284424
# mean tensor(4.9000, dtype=torch.float64) y is tensor(5)
# tensor(-0.0408, dtype=torch.float64)
# loss 78.22080087661743
# mean tensor(3.1000, dtype=torch.float64) y is tensor(3)
# tensor(-0.0285, dtype=torch.float64)
# loss 86.33378028869629
# mean tensor(7., dtype=torch.float64) y is tensor(7)
# tensor(-0.1035, dtype=torch.float64)
# loss 98.0729398727417
# mean tensor(2., dtype=torch.float64) y is tensor(2)
# tensor(0.0352, dtype=torch.float64)
# loss 72.0453553199768
# mean tensor(3., dtype=torch.float64) y is tensor(3)
# tensor(0.0221, dtype=torch.float64)
# loss 109.9691915512085
# mean tensor(6.7500, dtype=torch.float64) y is tensor(4)
# tensor(0.0109, dtype=torch.float64)
# loss 62.52059268951416
# mean tensor(0., dtype=torch.float64) y is tensor(0)
# tensor(-0.1258, dtype=torch.float64)
# loss 92.10189628601074
# mean tensor(4.7500, dtype=torch.float64) y is tensor(4)
# tensor(0.0059, dtype=torch.float64)
# loss 60.08220672607422
# mean tensor(3.3500, dtype=torch.float64) y is tensor(0)
# tensor(-0.0373, dtype=torch.float64)
# loss 94.92903518676758
# mean tensor(6., dtype=torch.float64) y is tensor(6)
# tensor(-0.0004, dtype=torch.float64)
# loss 94.83857154846191
# mean tensor(4., dtype=torch.float64) y is tensor(4)
# tensor(-0.0494, dtype=torch.float64)
# loss 105.73217868804932
# mean tensor(3., dtype=torch.float64) y is tensor(3)
# tensor(-0.0416, dtype=torch.float64)
# loss 107.91916942596436
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# tensor(0.0066, dtype=torch.float64)
# loss 76.07247734069824
# mean tensor(9., dtype=torch.float64) y is tensor(9)
# tensor(0.0004, dtype=torch.float64)
# loss 73.67990779876709
# mean tensor(0., dtype=torch.float64) y is tensor(0)
# tensor(0.0758, dtype=torch.float64)
# loss 100.63812351226807
# mean tensor(4.1000, dtype=torch.float64) y is tensor(2)
# tensor(0.0316, dtype=torch.float64)
# loss 98.8148136138916
# mean tensor(7., dtype=torch.float64) y is tensor(7)
# tensor(0.0859, dtype=torch.float64)
# loss 121.1339955329895
# mean tensor(6., dtype=torch.float64) y is tensor(6)
# tensor(0.0953, dtype=torch.float64)
# loss 65.40341567993164
# mean tensor(9., dtype=torch.float64) y is tensor(9)
# tensor(-0.0010, dtype=torch.float64)
# loss 77.96284008026123
# mean tensor(7., dtype=torch.float64) y is tensor(7)
# tensor(0.1588, dtype=torch.float64)
# loss 104.87568759918213
# mean tensor(6.8000, dtype=torch.float64) y is tensor(9)
# tensor(-0.0438, dtype=torch.float64)
# loss 60.07589912414551
# mean tensor(7.5000, dtype=torch.float64) y is tensor(9)
# tensor(0.0387, dtype=torch.float64)
# loss 94.22988224029541
# mean tensor(3., dtype=torch.float64) y is tensor(0)
# tensor(-0.0361, dtype=torch.float64)
# loss 84.88540172576904
# mean tensor(5., dtype=torch.float64) y is tensor(5)
# tensor(-0.0242, dtype=torch.float64)
# loss 95.79334449768066
# mean tensor(0.4000, dtype=torch.float64) y is tensor(0)
# tensor(-0.0785, dtype=torch.float64)
# loss 94.60133361816406
# mean tensor(4.7500, dtype=torch.float64) y is tensor(5)
# tensor(-0.0047, dtype=torch.float64)
# loss 72.88113355636597
# mean tensor(6., dtype=torch.float64) y is tensor(6)
# tensor(-0.0016, dtype=torch.float64)
# loss 77.04953289031982
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# tensor(0.0715, dtype=torch.float64)
# loss 103.48580551147461
# mean tensor(1.0500, dtype=torch.float64) y is tensor(7)
# tensor(-0.1408, dtype=torch.float64)
# loss 76.91513442993164
# mean tensor(6., dtype=torch.float64) y is tensor(6)
# tensor(-0.1051, dtype=torch.float64)
# loss 97.30901050567627
# mean tensor(7.7500, dtype=torch.float64) y is tensor(8)
# tensor(-0.0432, dtype=torch.float64)
# loss 74.33122968673706
# mean tensor(0.5000, dtype=torch.float64) y is tensor(3)
# tensor(-0.0865, dtype=torch.float64)
# loss 95.58289909362793
# mean tensor(3., dtype=torch.float64) y is tensor(3)
# tensor(-0.0857, dtype=torch.float64)
# loss 108.60843276977539
# mean tensor(2., dtype=torch.float64) y is tensor(2)
# tensor(-0.1064, dtype=torch.float64)
# loss 94.53077983856201
# mean tensor(3., dtype=torch.float64) y is tensor(3)
# tensor(0.0264, dtype=torch.float64)
# loss 72.83513832092285
# mean tensor(8., dtype=torch.float64) y is tensor(8)
# tensor(0.0566, dtype=torch.float64)
# loss 91.50893497467041
# mean tensor(6., dtype=torch.float64) y is tensor(6)
# tensor(0.0645, dtype=torch.float64)
# loss 70.81021308898926
# mean tensor(9., dtype=torch.float64) y is tensor(9)
# tensor(0.2359, dtype=torch.float64)
# loss 71.83693027496338
# mean tensor(9., dtype=torch.float64) y is tensor(9)
# tensor(0.1600, dtype=torch.float64)
# loss 86.55606460571289
# mean tensor(7.6000, dtype=torch.float64) y is tensor(7)
# tensor(0.1201, dtype=torch.float64)
# loss 129.88648986816406
# mean tensor(5.7500, dtype=torch.float64) y is tensor(5)
# tensor(0.1869, dtype=torch.float64)
# loss 99.25891780853271
# mean tensor(7., dtype=torch.float64) y is tensor(4)
# tensor(0.0156, dtype=torch.float64)
# loss 83.75932312011719
# mean tensor(5., dtype=torch.float64) y is tensor(7)
# tensor(-0.0486, dtype=torch.float64)
# loss 93.48582363128662
# mean tensor(1.4000, dtype=torch.float64) y is tensor(1)
# tensor(0.0768, dtype=torch.float64)
# loss 65.9617567062378
# mean tensor(9., dtype=torch.float64) y is tensor(9)
# tensor(0.0270, dtype=torch.float64)
# loss 105.48515224456787
# mean tensor(3., dtype=torch.float64) y is tensor(3)
# tensor(0.0463, dtype=torch.float64)
# loss 82.40696716308594
# mean tensor(4.7000, dtype=torch.float64) y is tensor(5)
# tensor(-0.0275, dtype=torch.float64)
# loss 75.88813781738281
# mean tensor(6., dtype=torch.float64) y is tensor(6)
# tensor(-0.0873, dtype=torch.float64)
# loss 73.89022541046143
# mean tensor(4.5000, dtype=torch.float64) y is tensor(4)
# tensor(-0.0826, dtype=torch.float64)
# loss 69.9620132446289
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# tensor(-0.0750, dtype=torch.float64)
# loss 102.07757377624512
# mean tensor(0., dtype=torch.float64) y is tensor(0)
# tensor(-0.0170, dtype=torch.float64)
# loss 30.311156272888184
# mean tensor(8., dtype=torch.float64) y is tensor(8)
# tensor(-0.0229, dtype=torch.float64)

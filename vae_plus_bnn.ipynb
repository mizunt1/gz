# %%
import os

import numpy as np
import torch
import torchvision.datasets as dset
import torch.nn as nn
import torchvision.transforms as transforms

import pyro
import pyro.distributions as dist
import pyro.contrib.examples.util  # patches torchvision
from pyro.infer import SVI, Trace_ELBO
from pyro.optim import Adam

# %%
#assert pyro.__version__.startswith('1.3.0')
pyro.enable_validation(True)
pyro.distributions.enable_validation(False)
pyro.set_rng_seed(0)
# Enable smoke test - run the notebook cells on CI.
#smoke_test = 'CI' in os.environ

# %%
def setup_data_loaders(batch_size=128, use_cuda=False):
    root = './data'
    download = True
    trans = transforms.ToTensor()
    train_set = dset.MNIST(root=root, train=True, transform=trans,
                           download=download)
    test_set = dset.MNIST(root=root, train=False, transform=trans)

    kwargs = {'num_workers': 1, 'pin_memory': use_cuda}
    train_loader = torch.utils.data.DataLoader(dataset=train_set,
        batch_size=batch_size, shuffle=True, **kwargs)
    test_loader = torch.utils.data.DataLoader(dataset=test_set,
        batch_size=batch_size, shuffle=False, **kwargs)
    return train_loader, test_loader

# %%
class Decoder(nn.Module):
    def __init__(self, z_dim, hidden_dim):
        super().__init__()
        # setup the two linear transformations used
        self.fc1 = nn.Linear(z_dim, hidden_dim)
        self.fc21 = nn.Linear(hidden_dim, 784)
        # setup the non-linearities
        self.softplus = nn.Softplus()
        self.sigmoid = nn.Sigmoid()

    def forward(self, z):
        # define the forward computation on the latent z
        # first compute the hidden units
        hidden = self.softplus(self.fc1(z))
        # return the parameter for the output Bernoulli
        # each is of size batch_size x 784
        loc_img = self.sigmoid(self.fc21(hidden))
        return loc_img

# %%
class Encoder(nn.Module):
    def __init__(self, z_dim, hidden_dim):
        super().__init__()
        # setup the three linear transformations used
        self.fc1 = nn.Linear(784, hidden_dim)
        self.fc21 = nn.Linear(hidden_dim, z_dim)
        self.fc22 = nn.Linear(hidden_dim, z_dim)
        # setup the non-linearities
        self.softplus = nn.Softplus()

    def forward(self, x):
        # define the forward computation on the image x
        # first shape the mini-batch to have pixels in the rightmost dimension
        x = x.reshape(-1, 784)
        # then compute the hidden units
        hidden = self.softplus(self.fc1(x))
        # then return a mean vector and a (positive) square root covariance
        # each of size batch_size x z_dim
        z_loc = self.fc21(hidden)
        z_scale = torch.exp(self.fc22(hidden))
        return z_loc, z_scale

# %%
# define the model p(x|z)p(z)
def model(self, x):
    # register PyTorch module `decoder` with Pyro
    pyro.module("decoder", self.decoder)
    with pyro.plate("data", x.shape[0]):
        # setup hyperparameters for prior p(z)
        z_loc = x.new_zeros(torch.Size((x.shape[0], self.z_dim)))
        # z loc torch.Size([256, 50])
        z_scale = x.new_ones(torch.Size((x.shape[0], self.z_dim)))
        # sample from prior (value will be sampled by guide when computing the ELBO)
        z = pyro.sample("latent", dist.Normal(z_loc, z_scale).to_event(1))
        # we sample a Z from a (0, I) normal distribution
        # then we pass it though a nn
        # mu = nn(z)
        # then this mu is used in another dist
        # p(x|z) where z is samples
        # then we sample an x from this
        # the idea is, this nn function learns a distribution
        # that is, what would it be like to sample z from P(z|X)
        # 
        # z shape torch.Size([256, 50])
        # decode the latent code z
        loc_img = self.decoder.forward(z)
        #loc img torch.Size([256, 784])
        # score against actual images
        # bern shape Independent(Bernoulli(probs: torch.Size([256, 784])), 1)
        # 784 is the batch size
        # 256 is the image size
        pyro.sample("obs", dist.Bernoulli(loc_img).to_event(1), obs=x.reshape(-1, 784))

# %%
# define the guide (i.e. variational distribution) q(z|x)
def guide(self, x):
    # register PyTorch module `encoder` with Pyro
    pyro.module("encoder", self.encoder)
    with pyro.plate("data", x.shape[0]):
        # use the encoder to get the parameters used to define q(z|x)
        z_loc, z_scale = self.encoder.forward(x)
        # p(z,b) = q(b)mult(i=1 to i=N)q(zi|f(xi))
        
        # given an image, we output a distribution for z
        # then we sample a z. because the guide always gives the
        # approximate posterior, the variational inference
        # sample the latent code z
        pyro.sample("latent", dist.Normal(z_loc, z_scale).to_event(1))

# %%
class VAE(nn.Module):
    # by default our latent space is 50-dimensional
    # and we use 400 hidden units
    def __init__(self, z_dim=50, hidden_dim=400, use_cuda=False):
        super().__init__()
        # create the encoder and decoder networks
        self.encoder = Encoder(z_dim, hidden_dim)
        self.decoder = Decoder(z_dim, hidden_dim)

        if use_cuda:
            # calling cuda() here will put all the parameters of
            # the encoder and decoder networks into gpu memory
            self.cuda()
        self.use_cuda = use_cuda
        self.z_dim = z_dim

    # define the model p(x|z)p(z)
    
    
    def model(self, x):
        # register PyTorch module `decoder` with Pyro
        pyro.module("decoder", self.decoder)
        with pyro.plate("data", x.shape[0]):
            # setup hyperparameters for prior p(z)
            z_loc = x.new_zeros(torch.Size((x.shape[0], self.z_dim)))
            z_scale = x.new_ones(torch.Size((x.shape[0], self.z_dim)))
            # sample from prior (value will be sampled by guide when computing the ELBO)
            z = pyro.sample("latent", dist.Normal(z_loc, z_scale).to_event(1))
            # decode the latent code z
            loc_img = self.decoder.forward(z)
            # score against actual images
            # decoder is where the image goes 
            pyro.sample("obs", dist.Bernoulli(loc_img).to_event(1), obs=x.reshape(-1, 784))

    # define the guide (i.e. variational distribution) q(z|x)
    def guide(self, x):
        # register PyTorch module `encoder` with Pyro
        pyro.module("encoder", self.encoder)
        with pyro.plate("data", x.shape[0]):
            # use the encoder to get the parameters used to define q(z|x)
            z_loc, z_scale = self.encoder.forward(x)
            # sample the latent code z
            pyro.sample("latent", dist.Normal(z_loc, z_scale).to_event(1))

    # define a helper function for reconstructing images
    def reconstruct_img(self, x):
        # encode image x
        z_loc, z_scale = self.encoder(x)
        # sample in latent space
        z = dist.Normal(z_loc, z_scale).sample()
        # decode the image (note we don't sample in image space)
        loc_img = self.decoder(z)
        return loc_img

# %%
vae = VAE()

optimizer = Adam({"lr": 1.0e-3})

svi = SVI(vae.model, vae.guide, optimizer, loss=Trace_ELBO())

def train(svi, train_loader, use_cuda=False):
    # initialize loss accumulator
    epoch_loss = 0.
    # do a training epoch over each mini-batch x returned
    # by the data loader
    for x, _ in train_loader:
        # if on GPU put mini-batch into CUDA memory
        if use_cuda:
            x = x.cuda()
        # do ELBO gradient and accumulate loss
        epoch_loss += svi.step(x)

    # return epoch loss
    normalizer_train = len(train_loader.dataset)
    total_epoch_loss_train = epoch_loss / normalizer_train
    return total_epoch_loss_train

def evaluate(svi, test_loader, use_cuda=False):
    # initialize loss accumulator
    test_loss = 0.
    # compute the loss over the entire test set
    for x, _ in test_loader:
        # if on GPU put mini-batch into CUDA memory
        if use_cuda:
            x = x.cuda()
        # compute ELBO estimate and accumulate loss
        test_loss += svi.evaluate_loss(x)
    normalizer_test = len(test_loader.dataset)
    total_epoch_loss_test = test_loss / normalizer_test
    return total_epoch_loss_test

# %%
LEARNING_RATE = 1.0e-3
USE_CUDA = False
smoke_test = False

# Run only for a single iteration for testing
NUM_EPOCHS = 250 if smoke_test else 250
TEST_FREQUENCY = 5
train_loader, test_loader = setup_data_loaders(batch_size=256, use_cuda=USE_CUDA)
print(len(test_loader))

# clear param store
pyro.clear_param_store()

# setup the VAE
vae = VAE(use_cuda=USE_CUDA)

# setup the optimizer
adam_args = {"lr": LEARNING_RATE}
optimizer = Adam(adam_args)

# setup the inference algorithm
svi = SVI(vae.model, vae.guide, optimizer, loss=Trace_ELBO())

train_elbo = []
test_elbo = []
# training loop
for epoch in range(NUM_EPOCHS):
    total_epoch_loss_train = train(svi, train_loader, use_cuda=USE_CUDA)
    train_elbo.append(-total_epoch_loss_train)
    print("[epoch %03d]  average training loss: %.4f" % (epoch, total_epoch_loss_train))

    if epoch % TEST_FREQUENCY == 0:
        # report test diagnostics
        total_epoch_loss_test = evaluate(svi, test_loader, use_cuda=USE_CUDA)
        test_elbo.append(-total_epoch_loss_test)
        print("[epoch %03d] average test loss: %.4f" % (epoch, total_epoch_loss_test))
# Out:
# 40
# [epoch 000]  average training loss: 191.0216
# [epoch 000] average test loss: 156.0872
# [epoch 001]  average training loss: 146.8141
# [epoch 002]  average training loss: 133.2540
# [epoch 003]  average training loss: 124.6775
# [epoch 004]  average training loss: 119.5152
# [epoch 005]  average training loss: 116.1240
# [epoch 005] average test loss: 113.7908
# [epoch 006]  average training loss: 113.7285
# [epoch 007]  average training loss: 112.0445
# [epoch 008]  average training loss: 110.7292
# [epoch 009]  average training loss: 109.7455
# [epoch 010]  average training loss: 108.9070
# [epoch 010] average test loss: 107.7720
# [epoch 011]  average training loss: 108.2513
# [epoch 012]  average training loss: 107.6953
# [epoch 013]  average training loss: 107.2849
# [epoch 014]  average training loss: 106.8870
# [epoch 015]  average training loss: 106.4983
# [epoch 015] average test loss: 105.9786
# [epoch 016]  average training loss: 106.1872
# [epoch 017]  average training loss: 105.9363
# [epoch 018]  average training loss: 105.7087
# [epoch 019]  average training loss: 105.4600
# [epoch 020]  average training loss: 105.2648
# [epoch 020] average test loss: 104.7753
# [epoch 021]  average training loss: 105.0442
# [epoch 022]  average training loss: 104.9031
# [epoch 023]  average training loss: 104.7304
# [epoch 024]  average training loss: 104.6027
# [epoch 025]  average training loss: 104.4586
# [epoch 025] average test loss: 104.2971
# [epoch 026]  average training loss: 104.3756
# [epoch 027]  average training loss: 104.2278
# [epoch 028]  average training loss: 104.1049
# [epoch 029]  average training loss: 104.0565
# [epoch 030]  average training loss: 103.8851
# [epoch 030] average test loss: 103.5858
# [epoch 031]  average training loss: 103.7705
# [epoch 032]  average training loss: 103.7331
# [epoch 033]  average training loss: 103.6272
# [epoch 034]  average training loss: 103.5645
# [epoch 035]  average training loss: 103.4693
# [epoch 035] average test loss: 103.1316
# [epoch 036]  average training loss: 103.3898
# [epoch 037]  average training loss: 103.3199
# [epoch 038]  average training loss: 103.2840
# [epoch 039]  average training loss: 103.1866
# [epoch 040]  average training loss: 103.1108
# [epoch 040] average test loss: 103.0911
# [epoch 041]  average training loss: 103.0730
# [epoch 042]  average training loss: 103.0086
# [epoch 043]  average training loss: 102.9338
# [epoch 044]  average training loss: 102.8886
# [epoch 045]  average training loss: 102.8416
# [epoch 045] average test loss: 102.8022
# [epoch 046]  average training loss: 102.7832
# [epoch 047]  average training loss: 102.7389
# [epoch 048]  average training loss: 102.6800
# [epoch 049]  average training loss: 102.6738
# [epoch 050]  average training loss: 102.5855
# [epoch 050] average test loss: 102.5790
# [epoch 051]  average training loss: 102.5615
# [epoch 052]  average training loss: 102.4934
# [epoch 053]  average training loss: 102.4610
# [epoch 054]  average training loss: 102.4274
# [epoch 055]  average training loss: 102.3712
# [epoch 055] average test loss: 102.3923
# [epoch 056]  average training loss: 102.3328
# [epoch 057]  average training loss: 102.2912
# [epoch 058]  average training loss: 102.1891
# [epoch 059]  average training loss: 102.2194
# [epoch 060]  average training loss: 102.1762
# [epoch 060] average test loss: 102.1223
# [epoch 061]  average training loss: 102.1585
# [epoch 062]  average training loss: 102.0887
# [epoch 063]  average training loss: 102.0703
# [epoch 064]  average training loss: 102.0091
# [epoch 065]  average training loss: 101.9924
# [epoch 065] average test loss: 102.0361
# [epoch 066]  average training loss: 101.9461
# [epoch 067]  average training loss: 101.8985
# [epoch 068]  average training loss: 101.8809
# [epoch 069]  average training loss: 101.8587
# [epoch 070]  average training loss: 101.8102
# [epoch 070] average test loss: 102.1124
# [epoch 071]  average training loss: 101.7739
# [epoch 072]  average training loss: 101.7548
# [epoch 073]  average training loss: 101.7252
# [epoch 074]  average training loss: 101.7424
# [epoch 075]  average training loss: 101.6693
# [epoch 075] average test loss: 101.8703
# [epoch 076]  average training loss: 101.6238
# [epoch 077]  average training loss: 101.5941
# [epoch 078]  average training loss: 101.5562
# [epoch 079]  average training loss: 101.5380
# [epoch 080]  average training loss: 101.4967
# [epoch 080] average test loss: 101.6312
# [epoch 081]  average training loss: 101.4572
# [epoch 082]  average training loss: 101.4549
# [epoch 083]  average training loss: 101.3729
# [epoch 084]  average training loss: 101.3880
# [epoch 085]  average training loss: 101.3953
# [epoch 085] average test loss: 101.5520
# [epoch 086]  average training loss: 101.3212
# [epoch 087]  average training loss: 101.3289
# [epoch 088]  average training loss: 101.3108
# [epoch 089]  average training loss: 101.2534
# [epoch 090]  average training loss: 101.2607
# [epoch 090] average test loss: 101.2997
# [epoch 091]  average training loss: 101.2435
# [epoch 092]  average training loss: 101.1965
# [epoch 093]  average training loss: 101.1350
# [epoch 094]  average training loss: 101.1215
# [epoch 095]  average training loss: 101.0969
# [epoch 095] average test loss: 101.2543
# [epoch 096]  average training loss: 101.1045
# [epoch 097]  average training loss: 101.0621
# [epoch 098]  average training loss: 101.0410
# [epoch 099]  average training loss: 101.0019
# [epoch 100]  average training loss: 100.9802
# [epoch 100] average test loss: 101.3701
# [epoch 101]  average training loss: 100.9786
# [epoch 102]  average training loss: 100.9259
# [epoch 103]  average training loss: 100.9376
# [epoch 104]  average training loss: 100.8711
# [epoch 105]  average training loss: 100.8692
# [epoch 105] average test loss: 101.3290
# [epoch 106]  average training loss: 100.8619
# [epoch 107]  average training loss: 100.8832
# [epoch 108]  average training loss: 100.8150
# [epoch 109]  average training loss: 100.7756
# [epoch 110]  average training loss: 100.7716
# [epoch 110] average test loss: 100.9640
# [epoch 111]  average training loss: 100.7511
# [epoch 112]  average training loss: 100.7197
# [epoch 113]  average training loss: 100.6999
# [epoch 114]  average training loss: 100.6821
# [epoch 115]  average training loss: 100.6824
# [epoch 115] average test loss: 100.9381
# [epoch 116]  average training loss: 100.6296
# [epoch 117]  average training loss: 100.5856
# [epoch 118]  average training loss: 100.5982
# [epoch 119]  average training loss: 100.5800
# [epoch 120]  average training loss: 100.5418
# [epoch 120] average test loss: 100.9218
# [epoch 121]  average training loss: 100.5369
# [epoch 122]  average training loss: 100.5262
# [epoch 123]  average training loss: 100.4544
# [epoch 124]  average training loss: 100.4614
# [epoch 125]  average training loss: 100.4573
# [epoch 125] average test loss: 100.6780
# [epoch 126]  average training loss: 100.4579
# [epoch 127]  average training loss: 100.4206
# [epoch 128]  average training loss: 100.3880
# [epoch 129]  average training loss: 100.3709
# [epoch 130]  average training loss: 100.3466
# [epoch 130] average test loss: 100.7927
# [epoch 131]  average training loss: 100.3604
# [epoch 132]  average training loss: 100.2920
# [epoch 133]  average training loss: 100.3335
# [epoch 134]  average training loss: 100.2753
# [epoch 135]  average training loss: 100.2773
# [epoch 135] average test loss: 100.5662
# [epoch 136]  average training loss: 100.2460
# [epoch 137]  average training loss: 100.2437
# [epoch 138]  average training loss: 100.2190
# [epoch 139]  average training loss: 100.1864
# [epoch 140]  average training loss: 100.1878
# [epoch 140] average test loss: 100.5511
# [epoch 141]  average training loss: 100.1991
# [epoch 142]  average training loss: 100.1339
# [epoch 143]  average training loss: 100.1372
# [epoch 144]  average training loss: 100.1182
# [epoch 145]  average training loss: 100.1026
# [epoch 145] average test loss: 100.4379
# [epoch 146]  average training loss: 100.0676
# [epoch 147]  average training loss: 100.0869
# [epoch 148]  average training loss: 100.0255
# [epoch 149]  average training loss: 100.0386
# [epoch 150]  average training loss: 100.0031
# [epoch 150] average test loss: 100.3763
# [epoch 151]  average training loss: 99.9833
# [epoch 152]  average training loss: 99.9919
# [epoch 153]  average training loss: 99.9837
# [epoch 154]  average training loss: 99.9739
# [epoch 155]  average training loss: 99.9329
# [epoch 155] average test loss: 100.3317
# [epoch 156]  average training loss: 99.9232
# [epoch 157]  average training loss: 99.8928
# [epoch 158]  average training loss: 99.8881
# [epoch 159]  average training loss: 99.8582
# [epoch 160]  average training loss: 99.8505
# [epoch 160] average test loss: 100.2576
# [epoch 161]  average training loss: 99.8534
# [epoch 162]  average training loss: 99.8147
# [epoch 163]  average training loss: 99.8133
# [epoch 164]  average training loss: 99.7991
# [epoch 165]  average training loss: 99.7704
# [epoch 165] average test loss: 100.5118
# [epoch 166]  average training loss: 99.7751
# [epoch 167]  average training loss: 99.7759
# [epoch 168]  average training loss: 99.7354
# [epoch 169]  average training loss: 99.7310
# [epoch 170]  average training loss: 99.7082
# [epoch 170] average test loss: 100.2337
# [epoch 171]  average training loss: 99.6867
# [epoch 172]  average training loss: 99.6605
# [epoch 173]  average training loss: 99.6814
# [epoch 174]  average training loss: 99.6773
# [epoch 175]  average training loss: 99.6529
# [epoch 175] average test loss: 100.1241
# [epoch 176]  average training loss: 99.6591
# [epoch 177]  average training loss: 99.6231
# [epoch 178]  average training loss: 99.5969
# [epoch 179]  average training loss: 99.5970
# [epoch 180]  average training loss: 99.5910
# [epoch 180] average test loss: 100.0774
# [epoch 181]  average training loss: 99.5568
# [epoch 182]  average training loss: 99.5284
# [epoch 183]  average training loss: 99.5470
# [epoch 184]  average training loss: 99.5722
# [epoch 185]  average training loss: 99.5009
# [epoch 185] average test loss: 100.0042
# [epoch 186]  average training loss: 99.5154
# [epoch 187]  average training loss: 99.4607
# [epoch 188]  average training loss: 99.4983
# [epoch 189]  average training loss: 99.4446
# [epoch 190]  average training loss: 99.4725
# [epoch 190] average test loss: 99.9124
# [epoch 191]  average training loss: 99.4374
# [epoch 192]  average training loss: 99.4337
# [epoch 193]  average training loss: 99.4214
# [epoch 194]  average training loss: 99.3854
# [epoch 195]  average training loss: 99.3928
# [epoch 195] average test loss: 99.9716
# [epoch 196]  average training loss: 99.3700
# [epoch 197]  average training loss: 99.3928
# [epoch 198]  average training loss: 99.3260
# [epoch 199]  average training loss: 99.3492
# [epoch 200]  average training loss: 99.3464
# [epoch 200] average test loss: 99.6944
# [epoch 201]  average training loss: 99.3378
# [epoch 202]  average training loss: 99.3188
# [epoch 203]  average training loss: 99.2901
# [epoch 204]  average training loss: 99.2732
# [epoch 205]  average training loss: 99.3065
# [epoch 205] average test loss: 99.7587
# [epoch 206]  average training loss: 99.2539
# [epoch 207]  average training loss: 99.2697
# [epoch 208]  average training loss: 99.2354
# [epoch 209]  average training loss: 99.2458
# [epoch 210]  average training loss: 99.2006
# [epoch 210] average test loss: 99.8483
# [epoch 211]  average training loss: 99.1854
# [epoch 212]  average training loss: 99.1829
# [epoch 213]  average training loss: 99.2115
# [epoch 214]  average training loss: 99.2002
# [epoch 215]  average training loss: 99.1465
# [epoch 215] average test loss: 99.7998
# [epoch 216]  average training loss: 99.1800
# [epoch 217]  average training loss: 99.1218
# [epoch 218]  average training loss: 99.1497
# [epoch 219]  average training loss: 99.1207
# [epoch 220]  average training loss: 99.0950
# [epoch 220] average test loss: 99.5686
# [epoch 221]  average training loss: 99.0997
# [epoch 222]  average training loss: 99.1184
# [epoch 223]  average training loss: 99.0759
# [epoch 224]  average training loss: 99.0950
# [epoch 225]  average training loss: 99.0598
# [epoch 225] average test loss: 99.6380
# [epoch 226]  average training loss: 99.0391
# [epoch 227]  average training loss: 99.0637
# [epoch 228]  average training loss: 99.0490
# [epoch 229]  average training loss: 99.0405
# [epoch 230]  average training loss: 98.9973
# [epoch 230] average test loss: 99.4147
# [epoch 231]  average training loss: 98.9783
# [epoch 232]  average training loss: 98.9807
# [epoch 233]  average training loss: 98.9829
# [epoch 234]  average training loss: 98.9789
# [epoch 235]  average training loss: 98.9821
# [epoch 235] average test loss: 99.4802
# [epoch 236]  average training loss: 98.9485
# [epoch 237]  average training loss: 98.9464
# [epoch 238]  average training loss: 98.9540
# [epoch 239]  average training loss: 98.9301
# [epoch 240]  average training loss: 98.9232
# [epoch 240] average test loss: 99.3989
# [epoch 241]  average training loss: 98.8906
# [epoch 242]  average training loss: 98.8865
# [epoch 243]  average training loss: 98.8905
# [epoch 244]  average training loss: 98.8795
# [epoch 245]  average training loss: 98.9017
# [epoch 245] average test loss: 99.3678
# [epoch 246]  average training loss: 98.8552
# [epoch 247]  average training loss: 98.8748
# [epoch 248]  average training loss: 98.8438
# [epoch 249]  average training loss: 98.8359

# %%
from pyro.nn import PyroSample, PyroModule
from pyro.distributions import Normal, Categorical

class ClassifierBnn(PyroModule):
    
    def __init__(self, num_in = 100, num_hidden = 200, num_out = 10, prior_std = 1.):
        
        # call to father constructor
        super().__init__()
        
        # define prior
        prior = Normal(0, prior_std)
        
        # Define layers
        
        # linear layer 1
        self.linear_layer = PyroModule[torch.nn.Linear](num_in, num_hidden)
        
        # linear alyer parameters as random variables
        self.linear_layer.weights = PyroSample(prior.expand([num_hidden, num_in]).to_event(2))
        self.linear_layer.bias = PyroSample(prior.expand([num_hidden]).to_event(1))
        
        # linear layer 2
        # output dimension is 3 because of the number of classes
        self.output_layer = PyroModule[torch.nn.Linear](num_hidden, num_out)
        
        # linear alyer parameters as random variables****
        self.output_layer.weights = PyroSample(prior.expand([num_out, num_hidden]).to_event(2))
        self.output_layer.bias = PyroSample(prior.expand([num_out]).to_event(1))
        
        # activation function
        #self.activation = torch.nn.functional.softmax()
        
    def forward(self, x, y = None):
            
        # latent variable
        z = self.linear_layer(x)
        z = self.output_layer(z)
        z = torch.nn.functional.log_softmax(z, dim=1)
        # likelihood
        with pyro.plate("data",size = x.shape[0], dim = -1):
            # I think this means each batch is independent            
            # z is the input to the distribution (categorical)
            obs = pyro.sample("obs", Categorical(logits = z), obs=y)
        # return latent variable
        return z

# %%
# validate NN

pyro.enable_validation(True)

model = ClassifierBnn()
x, y = next(iter(train_loader))
z_loc, z_scale = vae.encoder(x)
combined_z = torch.cat((z_loc, z_scale), 1)


print(pyro.poutine.trace(model).get_trace(combined_z, y).format_shapes())
# Out:
#          Trace Shapes:
#           Param Sites:
#    linear_layer.weight 200 100
#    output_layer.weight  10 200
#          Sample Sites:
# linear_layer.bias dist       | 200
#                  value       | 200
# output_layer.bias dist       |  10
#                  value       |  10
#              data dist       |
#                  value 256   |
#               obs dist 256   |
#                  value 256   |

# %%
pyro.enable_validation(True)
pyro.clear_param_store()
model = ClassifierBnn(num_hidden = 10, prior_std = 1.)

# define guide
from pyro.infer.autoguide import AutoDiagonalNormal
guide = AutoDiagonalNormal(model, init_scale=1e-1)

# define SVI (model for training)
svi = pyro.infer.SVI(model,
                    guide,
                    optim=pyro.optim.ClippedAdam({'lr':1e-3}),
                    # Define conventional ELBO
                     loss=pyro.infer.Trace_ELBO())

# %%
from pyro.infer import Predictive
predictive = Predictive(model, guide=guide, num_samples=20)

def predict(x):
    # for a single image, output a mean and sd for category
    yhats = predictive(x)["obs"].double()
    # yhats[0] seems to be integers 0 to 9, len 256
    # prediction for one model, for all items in batch
    # 20, 256
    mean = torch.mean(yhats, axis=0)
    std = torch.std(yhats.float(), 0).numpy()
    # yhats outputs a batch size number of predictions for 20 models
    # yhats seem to be a dictionary of weights
    return mean, std

# %%
def evaluate_test(test_loader, encoder):
    accuracy = 0
    for x, y in test_loader:
        z_loc, z_scale = encoder(x)
        combined_z = torch.cat((z_loc, z_scale), 1)
        mean, std = predict(combined_z)
        num_correct_in_batch = torch.sum(torch.eq(mean.int(),y))
        accuracy += num_correct_in_batch.numpy()/len(y)
    return accuracy / (len(test_loader))

# %%
# Training

num_epochs = 1000

# Define number of epochs
epoch_loss = np.zeros(shape=(num_epochs,))

test_freq = 10
# training
for epoch in range(25):
    i = 0
    for x, y in train_loader:
        i +=1
        # batches of size 256 are being fed in 
        z_loc, z_scale = vae.encoder(x)
        combined_z = torch.cat((z_loc, z_scale), 1)
        loss = svi.step(combined_z, y)
        if i % test_freq == 0:
            test_acc = evaluate_test(test_loader, vae.encoder)
            print("test acc", test_acc)
            print("loss", loss)
            print("mean", mean[0], "y is", y[0])
            print("train acc", accuracy_per_batch)
        mean, std = predict(combined_z)
        accuracy_per_batch = torch.sum(torch.eq(mean.int(),y)).numpy()/len(y)
# Out:
# ../torch/csrc/utils/python_arg_parser.cpp:756: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha)
# test acc 0.09609375
# loss 632.3417816162109
# mean tensor(5., dtype=torch.float64) y is tensor(8)
# train acc 0.1015625
# test acc 0.10517578125
# loss 616.0413837432861
# mean tensor(3.6500, dtype=torch.float64) y is tensor(5)
# train acc 0.09375
# test acc 0.10478515625
# loss 608.466549873352
# mean tensor(4.5000, dtype=torch.float64) y is tensor(9)
# train acc 0.09375
# test acc 0.10087890625
# loss 592.7398691177368
# mean tensor(5.5000, dtype=torch.float64) y is tensor(3)
# train acc 0.11328125
# test acc 0.10458984375
# loss 588.482907295227
# mean tensor(4.4500, dtype=torch.float64) y is tensor(1)
# train acc 0.11328125
# test acc 0.103515625
# loss 577.2355165481567
# mean tensor(5.0500, dtype=torch.float64) y is tensor(6)
# train acc 0.09765625
# test acc 0.1078125
# loss 556.0070905685425
# mean tensor(5.0500, dtype=torch.float64) y is tensor(1)
# train acc 0.109375
# test acc 0.1126953125
# loss 552.1666259765625
# mean tensor(4.0500, dtype=torch.float64) y is tensor(4)
# train acc 0.12890625
# test acc 0.1126953125
# loss 541.1621026992798
# mean tensor(4.8500, dtype=torch.float64) y is tensor(4)
# train acc 0.08984375
# test acc 0.11640625
# loss 520.8471212387085
# mean tensor(3.3500, dtype=torch.float64) y is tensor(4)
# train acc 0.15234375
# test acc 0.12001953125
# loss 507.3559846878052
# mean tensor(3.8500, dtype=torch.float64) y is tensor(7)
# train acc 0.1171875
# test acc 0.1220703125
# loss 485.38402557373047
# mean tensor(4.2500, dtype=torch.float64) y is tensor(9)
# train acc 0.1171875
# test acc 0.12275390625
# loss 469.16778469085693
# mean tensor(4.4000, dtype=torch.float64) y is tensor(1)
# train acc 0.1171875
# test acc 0.12587890625
# loss 457.8091506958008
# mean tensor(5.2000, dtype=torch.float64) y is tensor(9)
# train acc 0.14453125
# test acc 0.13330078125
# loss 453.9954090118408
# mean tensor(4.8500, dtype=torch.float64) y is tensor(7)
# train acc 0.09375
# test acc 0.13310546875
# loss 421.94317531585693
# mean tensor(4.9500, dtype=torch.float64) y is tensor(5)
# train acc 0.12109375
# test acc 0.13603515625
# loss 405.71980571746826
# mean tensor(5.1500, dtype=torch.float64) y is tensor(3)
# train acc 0.15234375
# test acc 0.14775390625
# loss 403.73028564453125
# mean tensor(4., dtype=torch.float64) y is tensor(8)
# train acc 0.1328125
# test acc 0.16171875
# loss 375.57270431518555
# mean tensor(5.5500, dtype=torch.float64) y is tensor(1)
# train acc 0.203125
# test acc 0.16455078125
# loss 353.56499099731445
# mean tensor(4.6000, dtype=torch.float64) y is tensor(3)
# train acc 0.15625
# test acc 0.163671875
# loss 356.20621395111084
# mean tensor(3.8500, dtype=torch.float64) y is tensor(5)
# train acc 0.1640625
# test acc 0.17685546875
# loss 333.67167472839355
# mean tensor(2.9000, dtype=torch.float64) y is tensor(7)
# train acc 0.140625
# test acc 0.174609375
# loss 326.59530544281006
# mean tensor(6.4000, dtype=torch.float64) y is tensor(3)
# train acc 0.17578125
# test acc 0.2025390625
# loss 318.6510238647461
# mean tensor(4.5500, dtype=torch.float64) y is tensor(9)
# train acc 0.1875
# test acc 0.2150390625
# loss 277.0305938720703
# mean tensor(7.9000, dtype=torch.float64) y is tensor(6)
# train acc 0.19140625
# test acc 0.2154296875
# loss 276.2395839691162
# mean tensor(4.6000, dtype=torch.float64) y is tensor(5)
# train acc 0.17578125
# test acc 0.21806640625
# loss 279.7028760910034
# mean tensor(5.7000, dtype=torch.float64) y is tensor(8)
# train acc 0.1640625
# test acc 0.238671875
# loss 255.380877494812
# mean tensor(6.2500, dtype=torch.float64) y is tensor(0)
# train acc 0.265625
# test acc 0.25380859375
# loss 248.7078094482422
# mean tensor(1.7000, dtype=torch.float64) y is tensor(2)
# train acc 0.23046875
# test acc 0.248046875
# loss 244.99986743927002
# mean tensor(4.4500, dtype=torch.float64) y is tensor(6)
# train acc 0.2421875
# test acc 0.2625
# loss 226.1561460494995
# mean tensor(5.8000, dtype=torch.float64) y is tensor(7)
# train acc 0.2890625
# test acc 0.27626953125
# loss 232.22786617279053
# mean tensor(5.3000, dtype=torch.float64) y is tensor(8)
# train acc 0.26953125
# test acc 0.28125
# loss 214.73785400390625
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# train acc 0.30859375
# test acc 0.3083984375
# loss 200.78737258911133
# mean tensor(2.6000, dtype=torch.float64) y is tensor(2)
# train acc 0.30859375
# test acc 0.3107421875
# loss 182.1021385192871
# mean tensor(5., dtype=torch.float64) y is tensor(6)
# train acc 0.31640625
# test acc 0.32626953125
# loss 202.77310848236084
# mean tensor(6.5500, dtype=torch.float64) y is tensor(8)
# train acc 0.3125
# test acc 0.330859375
# loss 187.86337566375732
# mean tensor(6.5500, dtype=torch.float64) y is tensor(0)
# train acc 0.3359375
# test acc 0.34462890625
# loss 202.1107406616211
# mean tensor(5.7000, dtype=torch.float64) y is tensor(6)
# train acc 0.32421875
# test acc 0.3572265625
# loss 190.1903314590454
# mean tensor(2.5000, dtype=torch.float64) y is tensor(7)
# train acc 0.30859375
# test acc 0.370703125
# loss 187.04582118988037
# mean tensor(2.5000, dtype=torch.float64) y is tensor(8)
# train acc 0.37890625
# test acc 0.376171875
# loss 189.88609313964844
# mean tensor(4.0500, dtype=torch.float64) y is tensor(5)
# train acc 0.35546875
# test acc 0.38623046875
# loss 173.56855583190918
# mean tensor(0.3000, dtype=torch.float64) y is tensor(1)
# train acc 0.40625
# test acc 0.38896484375
# loss 166.62592124938965
# mean tensor(5.2500, dtype=torch.float64) y is tensor(6)
# train acc 0.3984375
# test acc 0.40419921875
# loss 139.3931703567505
# mean tensor(1., dtype=torch.float64) y is tensor(4)
# train acc 0.3984375
# test acc 0.40771484375
# loss 161.90213680267334
# mean tensor(3.9500, dtype=torch.float64) y is tensor(9)
# train acc 0.4140625
# test acc 0.42138671875
# loss 156.01846981048584
# mean tensor(8.1500, dtype=torch.float64) y is tensor(1)
# train acc 0.39453125
# test acc 0.434375
# loss 174.368332862854
# mean tensor(4.3500, dtype=torch.float64) y is tensor(5)
# train acc 0.40234375
# test acc 0.4466796875
# loss 150.79919624328613
# mean tensor(4.7500, dtype=torch.float64) y is tensor(4)
# train acc 0.4296875
# test acc 0.4498046875
# loss 158.7842788696289
# mean tensor(5.5500, dtype=torch.float64) y is tensor(7)
# train acc 0.421875
# test acc 0.45439453125
# loss 146.8723440170288
# mean tensor(4.3000, dtype=torch.float64) y is tensor(0)
# train acc 0.453125
# test acc 0.45625
# loss 165.7289638519287
# mean tensor(5.8500, dtype=torch.float64) y is tensor(7)
# train acc 0.50390625
# test acc 0.46279296875
# loss 127.43615913391113
# mean tensor(6.8500, dtype=torch.float64) y is tensor(5)
# train acc 0.4296875
# test acc 0.4666015625
# loss 146.23637676239014
# mean tensor(7.6000, dtype=torch.float64) y is tensor(0)
# train acc 0.51953125
# test acc 0.4857421875
# loss 145.11835765838623
# mean tensor(6., dtype=torch.float64) y is tensor(8)
# train acc 0.4765625
# test acc 0.48876953125
# loss 141.9013910293579
# mean tensor(5.1500, dtype=torch.float64) y is tensor(4)
# train acc 0.4765625
# test acc 0.4923828125
# loss 144.96727561950684
# mean tensor(6.7500, dtype=torch.float64) y is tensor(0)
# train acc 0.43359375
# test acc 0.49755859375
# loss 129.8220329284668
# mean tensor(3.4000, dtype=torch.float64) y is tensor(0)
# train acc 0.51171875
# test acc 0.50263671875
# loss 143.98261737823486
# mean tensor(0.8000, dtype=torch.float64) y is tensor(7)
# train acc 0.53125
# test acc 0.51181640625
# loss 126.24504041671753
# mean tensor(4.3000, dtype=torch.float64) y is tensor(4)
# train acc 0.46484375
# test acc 0.5150390625
# loss 130.54944515228271
# mean tensor(3.7500, dtype=torch.float64) y is tensor(2)
# train acc 0.47265625
# test acc 0.51962890625
# loss 124.71663761138916
# mean tensor(6.5000, dtype=torch.float64) y is tensor(9)
# train acc 0.51171875
# test acc 0.52509765625
# loss 120.87115955352783
# mean tensor(5.8000, dtype=torch.float64) y is tensor(6)
# train acc 0.51171875
# test acc 0.52783203125
# loss 146.630042552948
# mean tensor(1., dtype=torch.float64) y is tensor(5)
# train acc 0.52734375
# test acc 0.534375
# loss 131.89641189575195
# mean tensor(9., dtype=torch.float64) y is tensor(1)
# train acc 0.53515625
# test acc 0.53251953125
# loss 127.03611469268799
# mean tensor(3.8500, dtype=torch.float64) y is tensor(7)
# train acc 0.51953125
# test acc 0.5400390625
# loss 115.25541496276855
# mean tensor(8.1000, dtype=torch.float64) y is tensor(0)
# train acc 0.5390625
# test acc 0.549609375
# loss 115.02465152740479
# mean tensor(2., dtype=torch.float64) y is tensor(6)
# train acc 0.53125
# test acc 0.55341796875
# loss 115.37043190002441
# mean tensor(0.2500, dtype=torch.float64) y is tensor(7)
# train acc 0.53125
# test acc 0.55751953125
# loss 119.4060320854187
# mean tensor(7.0500, dtype=torch.float64) y is tensor(4)
# train acc 0.53515625
# test acc 0.55263671875
# loss 110.86316311359406
# mean tensor(4.6000, dtype=torch.float64) y is tensor(4)
# train acc 0.55859375
# test acc 0.553515625
# loss 109.69799137115479
# mean tensor(3.9500, dtype=torch.float64) y is tensor(3)
# train acc 0.55859375
# test acc 0.5560546875
# loss 122.8629379272461
# mean tensor(4.6500, dtype=torch.float64) y is tensor(3)
# train acc 0.57421875
# test acc 0.5701171875
# loss 112.3459005355835
# mean tensor(2.9500, dtype=torch.float64) y is tensor(4)
# train acc 0.53125
# test acc 0.5716796875
# loss 112.2608585357666
# mean tensor(2., dtype=torch.float64) y is tensor(6)
# train acc 0.5390625
# test acc 0.58505859375
# loss 108.30894565582275
# mean tensor(0.9000, dtype=torch.float64) y is tensor(0)
# train acc 0.58203125
# test acc 0.5818359375
# loss 111.4146671295166
# mean tensor(5.2500, dtype=torch.float64) y is tensor(2)
# train acc 0.61328125
# test acc 0.580078125
# loss 123.49525260925293
# mean tensor(3.1500, dtype=torch.float64) y is tensor(9)
# train acc 0.5859375
# test acc 0.5837890625
# loss 115.97339725494385
# mean tensor(8.9500, dtype=torch.float64) y is tensor(6)
# train acc 0.55078125
# test acc 0.5890625
# loss 119.20921230316162
# mean tensor(9., dtype=torch.float64) y is tensor(8)
# train acc 0.49609375
# test acc 0.59248046875
# loss 88.82785177230835
# mean tensor(7.8000, dtype=torch.float64) y is tensor(0)
# train acc 0.55078125
# test acc 0.59287109375
# loss 127.18908500671387
# mean tensor(2.2500, dtype=torch.float64) y is tensor(0)
# train acc 0.60546875
# test acc 0.594921875
# loss 114.96343684196472
# mean tensor(7.1000, dtype=torch.float64) y is tensor(4)
# train acc 0.6328125
# test acc 0.60390625
# loss 104.47836494445801
# mean tensor(5.1500, dtype=torch.float64) y is tensor(9)
# train acc 0.55859375
# test acc 0.5970703125
# loss 109.35576367378235
# mean tensor(8.9000, dtype=torch.float64) y is tensor(4)
# train acc 0.55859375
# test acc 0.59736328125
# loss 112.24575519561768
# mean tensor(8.1500, dtype=torch.float64) y is tensor(0)
# train acc 0.58203125
# test acc 0.6068359375
# loss 129.37339973449707
# mean tensor(4.8500, dtype=torch.float64) y is tensor(9)
# train acc 0.5625
# test acc 0.603515625
# loss 110.89264917373657
# mean tensor(2.2000, dtype=torch.float64) y is tensor(8)
# train acc 0.55859375
# test acc 0.6119140625
# loss 97.24653673171997
# mean tensor(6.8000, dtype=torch.float64) y is tensor(2)
# train acc 0.59375
# test acc 0.60927734375
# loss 103.53198385238647
# mean tensor(7.8500, dtype=torch.float64) y is tensor(8)
# train acc 0.578125
# test acc 0.60966796875
# loss 127.63867282867432
# mean tensor(7., dtype=torch.float64) y is tensor(3)
# train acc 0.59765625
# test acc 0.616015625
# loss 118.52846240997314
# mean tensor(7.3000, dtype=torch.float64) y is tensor(6)
# train acc 0.59765625
# test acc 0.62138671875
# loss 110.45048403739929
# mean tensor(3., dtype=torch.float64) y is tensor(2)
# train acc 0.6484375
# test acc 0.62900390625
# loss 104.62579488754272
# mean tensor(8., dtype=torch.float64) y is tensor(1)
# train acc 0.6171875
# test acc 0.62744140625
# loss 110.53246879577637
# mean tensor(1., dtype=torch.float64) y is tensor(4)
# train acc 0.609375
# test acc 0.62451171875
# loss 113.20590114593506
# mean tensor(8.2500, dtype=torch.float64) y is tensor(2)
# train acc 0.62109375
# test acc 0.62265625
# loss 138.4630832672119
# mean tensor(4.2500, dtype=torch.float64) y is tensor(0)
# train acc 0.6640625
# test acc 0.62919921875
# loss 120.8328971862793
# mean tensor(5.8500, dtype=torch.float64) y is tensor(1)
# train acc 0.58984375
# test acc 0.62509765625
# loss 77.6610426902771
# mean tensor(4.5000, dtype=torch.float64) y is tensor(1)
# train acc 0.65625
# test acc 0.62490234375
# loss 101.35205030441284
# mean tensor(7.2500, dtype=torch.float64) y is tensor(3)
# train acc 0.58984375
# test acc 0.6265625
# loss 98.17499160766602
# mean tensor(9., dtype=torch.float64) y is tensor(0)
# train acc 0.6015625
# test acc 0.63642578125
# loss 129.02930450439453
# mean tensor(1., dtype=torch.float64) y is tensor(2)
# train acc 0.6015625
# test acc 0.63701171875
# loss 89.92587566375732
# mean tensor(5.7500, dtype=torch.float64) y is tensor(4)
# train acc 0.625
# test acc 0.628515625
# loss 124.85166120529175
# mean tensor(8.9000, dtype=torch.float64) y is tensor(5)
# train acc 0.6640625
# test acc 0.6349609375
# loss 95.18276119232178
# mean tensor(7.5000, dtype=torch.float64) y is tensor(8)
# train acc 0.65625
# test acc 0.6357421875
# loss 119.82234919071198
# mean tensor(5.3000, dtype=torch.float64) y is tensor(8)
# train acc 0.6171875
# test acc 0.64521484375
# loss 92.48678815364838
# mean tensor(2.8500, dtype=torch.float64) y is tensor(3)
# train acc 0.609375
# test acc 0.6396484375
# loss 98.47212266921997
# mean tensor(2.3000, dtype=torch.float64) y is tensor(1)
# train acc 0.60546875
# test acc 0.64296875
# loss 98.50977659225464
# mean tensor(6., dtype=torch.float64) y is tensor(4)
# train acc 0.65625
# test acc 0.6470703125
# loss 92.16985988616943
# mean tensor(4., dtype=torch.float64) y is tensor(1)
# train acc 0.64453125
# test acc 0.64365234375
# loss 132.28221559524536
# mean tensor(8., dtype=torch.float64) y is tensor(7)
# train acc 0.65234375
# test acc 0.6431640625
# loss 103.73125982284546
# mean tensor(2., dtype=torch.float64) y is tensor(9)
# train acc 0.64453125
# test acc 0.65146484375
# loss 99.4237790107727
# mean tensor(2., dtype=torch.float64) y is tensor(0)
# train acc 0.609375
# test acc 0.655859375
# loss 124.80516386032104
# mean tensor(0.1000, dtype=torch.float64) y is tensor(8)
# train acc 0.65234375
# test acc 0.65009765625
# loss 113.98496341705322
# mean tensor(7.5000, dtype=torch.float64) y is tensor(8)
# train acc 0.609375
# test acc 0.63818359375
# loss 101.49340629577637
# mean tensor(0., dtype=torch.float64) y is tensor(5)
# train acc 0.66796875
# test acc 0.6474609375
# loss 103.90182304382324
# mean tensor(7., dtype=torch.float64) y is tensor(9)
# train acc 0.6484375
# test acc 0.6572265625
# loss 123.71654319763184
# mean tensor(4.2000, dtype=torch.float64) y is tensor(9)
# train acc 0.609375
# test acc 0.659375
# loss 115.751957654953
# mean tensor(7.2000, dtype=torch.float64) y is tensor(3)
# train acc 0.64453125
# test acc 0.6625
# loss 102.18133020401001
# mean tensor(4., dtype=torch.float64) y is tensor(3)
# train acc 0.66015625
# test acc 0.6671875
# loss 96.45686984062195
# mean tensor(1., dtype=torch.float64) y is tensor(0)
# train acc 0.65234375
# test acc 0.65791015625
# loss 92.61892318725586
# mean tensor(7.9500, dtype=torch.float64) y is tensor(7)
# train acc 0.6328125
# test acc 0.66455078125
# loss 76.04696369171143
# mean tensor(3.0500, dtype=torch.float64) y is tensor(1)
# train acc 0.66015625
# test acc 0.65166015625
# loss 82.06018614768982
# mean tensor(4.6500, dtype=torch.float64) y is tensor(6)
# train acc 0.609375
# test acc 0.6564453125
# loss 106.1261796951294
# mean tensor(0.3000, dtype=torch.float64) y is tensor(5)
# train acc 0.69140625
# test acc 0.65673828125
# loss 85.64728212356567
# mean tensor(3., dtype=torch.float64) y is tensor(0)
# train acc 0.62109375
# test acc 0.6599609375
# loss 99.43088680505753
# mean tensor(3., dtype=torch.float64) y is tensor(1)
# train acc 0.6640625
# test acc 0.65615234375
# loss 132.59837806224823
# mean tensor(8.5000, dtype=torch.float64) y is tensor(5)
# train acc 0.65234375
# test acc 0.6578125
# loss 127.66846668720245
# mean tensor(5.1000, dtype=torch.float64) y is tensor(5)
# train acc 0.66796875
# test acc 0.66572265625
# loss 97.81633567810059
# mean tensor(0., dtype=torch.float64) y is tensor(6)
# train acc 0.6953125
# test acc 0.664453125
# loss 92.64278930425644
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# train acc 0.66796875
# test acc 0.65517578125
# loss 77.93970775604248
# mean tensor(6.7500, dtype=torch.float64) y is tensor(8)
# train acc 0.65234375
# test acc 0.66728515625
# loss 104.12871408462524
# mean tensor(1., dtype=torch.float64) y is tensor(2)
# train acc 0.671875
# test acc 0.6609375
# loss 104.71060466766357
# mean tensor(7.7500, dtype=torch.float64) y is tensor(0)
# train acc 0.6484375
# test acc 0.6697265625
# loss 102.11380815505981
# mean tensor(1., dtype=torch.float64) y is tensor(4)
# train acc 0.703125
# test acc 0.66806640625
# loss 95.52097511291504
# mean tensor(2.9000, dtype=torch.float64) y is tensor(2)
# train acc 0.69921875
# test acc 0.6646484375
# loss 90.07014632225037
# mean tensor(6.8500, dtype=torch.float64) y is tensor(9)
# train acc 0.70703125
# test acc 0.6625
# loss 85.68359613418579
# mean tensor(3., dtype=torch.float64) y is tensor(1)
# train acc 0.60546875
# test acc 0.6755859375
# loss 96.33040523529053
# mean tensor(0., dtype=torch.float64) y is tensor(7)
# train acc 0.6640625
# test acc 0.67294921875
# loss 84.93203067779541
# mean tensor(2.5000, dtype=torch.float64) y is tensor(6)
# train acc 0.60546875
# test acc 0.67314453125
# loss 91.83746993541718
# mean tensor(4., dtype=torch.float64) y is tensor(8)
# train acc 0.64453125
# test acc 0.66845703125
# loss 103.55753606557846
# mean tensor(2., dtype=torch.float64) y is tensor(8)
# train acc 0.671875
# test acc 0.67294921875
# loss 72.43836784362793
# mean tensor(8., dtype=torch.float64) y is tensor(3)
# train acc 0.6484375
# test acc 0.67548828125
# loss 97.56249523162842
# mean tensor(1., dtype=torch.float64) y is tensor(5)
# train acc 0.67578125
# test acc 0.67724609375
# loss 76.6351466178894
# mean tensor(3.1000, dtype=torch.float64) y is tensor(1)
# train acc 0.63671875
# test acc 0.67666015625
# loss 94.24039816856384
# mean tensor(6.8000, dtype=torch.float64) y is tensor(7)
# train acc 0.609375
# test acc 0.679296875
# loss 83.81433773040771
# mean tensor(0.9500, dtype=torch.float64) y is tensor(1)
# train acc 0.63671875
# test acc 0.682421875
# loss 111.1563811302185
# mean tensor(7.9000, dtype=torch.float64) y is tensor(7)
# train acc 0.66796875
# test acc 0.681640625
# loss 92.76963728666306
# mean tensor(6., dtype=torch.float64) y is tensor(9)
# train acc 0.6640625
# test acc 0.67958984375
# loss 100.11927032470703
# mean tensor(1., dtype=torch.float64) y is tensor(3)
# train acc 0.6484375
# test acc 0.67705078125
# loss 97.01315999031067
# mean tensor(1., dtype=torch.float64) y is tensor(6)
# train acc 0.6328125
# test acc 0.6736328125
# loss 100.24688041210175
# mean tensor(7.1500, dtype=torch.float64) y is tensor(7)
# train acc 0.671875
# test acc 0.66826171875
# loss 108.26784473657608
# mean tensor(3.4500, dtype=torch.float64) y is tensor(4)
# train acc 0.6875
# test acc 0.676953125
# loss 82.11009454727173
# mean tensor(6.7000, dtype=torch.float64) y is tensor(7)
# train acc 0.67578125
# test acc 0.6845703125
# loss 94.95762407779694
# mean tensor(6.5500, dtype=torch.float64) y is tensor(2)
# train acc 0.65234375
# test acc 0.68486328125
# loss 82.89207172393799
# mean tensor(5.7500, dtype=torch.float64) y is tensor(9)
# train acc 0.6796875
# test acc 0.69052734375
# loss 86.23511224985123
# mean tensor(6., dtype=torch.float64) y is tensor(4)
# train acc 0.625
# test acc 0.6890625
# loss 95.04269242286682
# mean tensor(4., dtype=torch.float64) y is tensor(7)
# train acc 0.6796875
# test acc 0.69111328125
# loss 103.25297355651855
# mean tensor(0.7000, dtype=torch.float64) y is tensor(5)
# train acc 0.671875
# test acc 0.7015625
# loss 97.40157270431519
# mean tensor(6.8000, dtype=torch.float64) y is tensor(4)
# train acc 0.671875
# test acc 0.687109375
# loss 91.24819201231003
# mean tensor(1., dtype=torch.float64) y is tensor(7)
# train acc 0.6796875
# test acc 0.69208984375
# loss 96.80338633060455
# mean tensor(1., dtype=torch.float64) y is tensor(6)
# train acc 0.6484375
# test acc 0.68583984375
# loss 115.33920240402222
# mean tensor(3.8000, dtype=torch.float64) y is tensor(7)
# train acc 0.6875
# test acc 0.68095703125
# loss 107.65271949768066
# mean tensor(6., dtype=torch.float64) y is tensor(7)
# train acc 0.671875
# test acc 0.6830078125
# loss 86.76311731338501
# mean tensor(1.7000, dtype=torch.float64) y is tensor(7)
# train acc 0.65625
# test acc 0.6787109375
# loss 106.89359951019287
# mean tensor(7., dtype=torch.float64) y is tensor(2)
# train acc 0.69921875
# test acc 0.6876953125
# loss 100.08333253860474
# mean tensor(6.5500, dtype=torch.float64) y is tensor(6)
# train acc 0.66015625
# test acc 0.6974609375
# loss 80.22543525695801
# mean tensor(1.9000, dtype=torch.float64) y is tensor(1)
# train acc 0.6640625
# test acc 0.696875
# loss 88.67718458175659
# mean tensor(8., dtype=torch.float64) y is tensor(8)
# train acc 0.6953125
# test acc 0.6880859375
# loss 82.86471033096313
# mean tensor(0., dtype=torch.float64) y is tensor(5)
# train acc 0.66015625
# test acc 0.68916015625
# loss 97.09507089853287
# mean tensor(0., dtype=torch.float64) y is tensor(2)
# train acc 0.7109375
# test acc 0.68505859375
# loss 65.16812062263489
# mean tensor(6., dtype=torch.float64) y is tensor(2)
# train acc 0.6953125
# test acc 0.6869140625
# loss 97.50912523269653
# mean tensor(7.6000, dtype=torch.float64) y is tensor(7)
# train acc 0.66796875
# test acc 0.6919921875
# loss 78.67331600189209
# mean tensor(1., dtype=torch.float64) y is tensor(6)
# train acc 0.6328125
# test acc 0.69599609375
# loss 99.1987316608429
# mean tensor(4.1500, dtype=torch.float64) y is tensor(8)
# train acc 0.6875
# test acc 0.698046875
# loss 96.55030059814453
# mean tensor(4., dtype=torch.float64) y is tensor(7)
# train acc 0.64453125
# test acc 0.698046875
# loss 96.42561614513397
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# train acc 0.703125
# test acc 0.6947265625
# loss 105.15147042274475
# mean tensor(1., dtype=torch.float64) y is tensor(6)
# train acc 0.703125
# test acc 0.69423828125
# loss 107.39259052276611
# mean tensor(2., dtype=torch.float64) y is tensor(7)
# train acc 0.6875
# test acc 0.6830078125
# loss 92.69367504119873
# mean tensor(3., dtype=torch.float64) y is tensor(4)
# train acc 0.6171875
# test acc 0.7001953125
# loss 80.09558117389679
# mean tensor(5., dtype=torch.float64) y is tensor(2)
# train acc 0.6796875
# test acc 0.696484375
# loss 92.05447709560394
# mean tensor(7., dtype=torch.float64) y is tensor(1)
# train acc 0.69921875
# test acc 0.69326171875
# loss 80.72631359100342
# mean tensor(2., dtype=torch.float64) y is tensor(0)
# train acc 0.62890625
# test acc 0.68837890625
# loss 86.20553684234619
# mean tensor(2.0500, dtype=torch.float64) y is tensor(6)
# train acc 0.609375
# test acc 0.68701171875
# loss 90.09523147344589
# mean tensor(1.1000, dtype=torch.float64) y is tensor(1)
# train acc 0.703125
# test acc 0.69404296875
# loss 87.64572858810425
# mean tensor(3., dtype=torch.float64) y is tensor(4)
# train acc 0.6640625
# test acc 0.698046875
# loss 101.08025360107422
# mean tensor(7., dtype=torch.float64) y is tensor(1)
# train acc 0.65625
# test acc 0.700390625
# loss 83.29736423492432
# mean tensor(1., dtype=torch.float64) y is tensor(4)
# train acc 0.69921875
# test acc 0.69697265625
# loss 92.48614263534546
# mean tensor(3.1000, dtype=torch.float64) y is tensor(2)
# train acc 0.625
# test acc 0.69091796875
# loss 107.42504847049713
# mean tensor(6., dtype=torch.float64) y is tensor(5)
# train acc 0.671875
# test acc 0.70361328125
# loss 101.60657024383545
# mean tensor(5., dtype=torch.float64) y is tensor(7)
# train acc 0.67578125
# test acc 0.70126953125
# loss 81.7763295173645
# mean tensor(1., dtype=torch.float64) y is tensor(8)
# train acc 0.6953125
# test acc 0.7060546875
# loss 94.11620330810547
# mean tensor(2., dtype=torch.float64) y is tensor(9)
# train acc 0.65625
# test acc 0.6951171875
# loss 81.23937225341797
# mean tensor(3., dtype=torch.float64) y is tensor(7)
# train acc 0.68359375
# test acc 0.69287109375
# loss 91.0001106262207
# mean tensor(2., dtype=torch.float64) y is tensor(1)
# train acc 0.703125
# test acc 0.69765625
# loss 100.16587448120117
# mean tensor(2., dtype=torch.float64) y is tensor(2)
# train acc 0.60546875
# test acc 0.698046875
# loss 100.21976602077484
# mean tensor(2., dtype=torch.float64) y is tensor(6)
# train acc 0.6484375
# test acc 0.69326171875
# loss 81.42332553863525
# mean tensor(1.5000, dtype=torch.float64) y is tensor(3)
# train acc 0.6640625
# test acc 0.700390625
# loss 105.77633374929428
# mean tensor(7.0500, dtype=torch.float64) y is tensor(3)
# train acc 0.671875
# test acc 0.6984375
# loss 96.14677906036377
# mean tensor(3., dtype=torch.float64) y is tensor(1)
# train acc 0.67578125
# test acc 0.70615234375
# loss 81.7755559682846
# mean tensor(3.0500, dtype=torch.float64) y is tensor(9)
# train acc 0.66796875
# test acc 0.69892578125
# loss 96.04203033447266
# mean tensor(7.7500, dtype=torch.float64) y is tensor(6)
# train acc 0.7109375
# test acc 0.69951171875
# loss 69.48355150222778
# mean tensor(5., dtype=torch.float64) y is tensor(8)
# train acc 0.734375
# test acc 0.69208984375
# loss 109.9129581451416
# mean tensor(3.3500, dtype=torch.float64) y is tensor(6)
# train acc 0.6640625
# test acc 0.69873046875
# loss 61.400243520736694
# mean tensor(1., dtype=torch.float64) y is tensor(7)
# train acc 0.640625
# test acc 0.6927734375
# loss 93.02662897109985
# mean tensor(1.5000, dtype=torch.float64) y is tensor(4)
# train acc 0.71484375
# test acc 0.69560546875
# loss 91.51455783843994
# mean tensor(1., dtype=torch.float64) y is tensor(5)
# train acc 0.6875
# test acc 0.69482421875
# loss 116.93595099449158
# mean tensor(4.1000, dtype=torch.float64) y is tensor(9)
# train acc 0.7265625
# test acc 0.7041015625
# loss 69.08839797973633
# mean tensor(0.8500, dtype=torch.float64) y is tensor(1)
# train acc 0.671875
# test acc 0.705078125
# loss 95.87399673461914
# mean tensor(4., dtype=torch.float64) y is tensor(7)
# train acc 0.6328125
# test acc 0.70859375
# loss 93.88260054588318
# mean tensor(1., dtype=torch.float64) y is tensor(8)
# train acc 0.6484375
# test acc 0.7025390625
# loss 78.99757766723633
# mean tensor(7., dtype=torch.float64) y is tensor(1)
# train acc 0.69140625
# test acc 0.70439453125
# loss 68.32080459594727
# mean tensor(7.6000, dtype=torch.float64) y is tensor(0)
# train acc 0.73046875
# test acc 0.7169921875
# loss 90.9014139175415
# mean tensor(4., dtype=torch.float64) y is tensor(3)
# train acc 0.7578125
# test acc 0.7078125
# loss 116.1570143699646
# mean tensor(0.5000, dtype=torch.float64) y is tensor(3)
# train acc 0.67578125
# test acc 0.70107421875
# loss 86.52250814437866
# mean tensor(9., dtype=torch.float64) y is tensor(1)
# train acc 0.7578125
# test acc 0.70556640625
# loss 63.75248336791992
# mean tensor(2.9500, dtype=torch.float64) y is tensor(7)
# train acc 0.70703125
# test acc 0.701953125
# loss 83.22698974609375
# mean tensor(3., dtype=torch.float64) y is tensor(8)
# train acc 0.68359375
# test acc 0.7046875
# loss 84.95536708831787
# mean tensor(1., dtype=torch.float64) y is tensor(9)
# train acc 0.67578125
# test acc 0.7103515625
# loss 105.70156192779541
# mean tensor(6.5000, dtype=torch.float64) y is tensor(3)
# train acc 0.7265625
# test acc 0.70830078125
# loss 70.74961471557617
# mean tensor(2.2000, dtype=torch.float64) y is tensor(1)
# train acc 0.671875
# test acc 0.7078125
# loss 78.51686525344849
# mean tensor(5.3000, dtype=torch.float64) y is tensor(7)
# train acc 0.6640625
# test acc 0.70634765625
# loss 75.14422059059143
# mean tensor(5.8500, dtype=torch.float64) y is tensor(4)
# train acc 0.69921875
# test acc 0.71337890625
# loss 84.1518030166626
# mean tensor(2.2500, dtype=torch.float64) y is tensor(3)
# train acc 0.69140625
# test acc 0.70654296875
# loss 92.81124782562256
# mean tensor(3.1000, dtype=torch.float64) y is tensor(1)
# train acc 0.71875
# test acc 0.71669921875
# loss 69.46582555770874
# mean tensor(5., dtype=torch.float64) y is tensor(6)
# train acc 0.70703125
# test acc 0.6919921875
# loss 104.96319127082825
# mean tensor(7.3500, dtype=torch.float64) y is tensor(3)
# train acc 0.67578125
# test acc 0.6931640625
# loss 97.24494403600693
# mean tensor(3.5000, dtype=torch.float64) y is tensor(8)
# train acc 0.71484375
# test acc 0.70419921875
# loss 87.36227256059647
# mean tensor(8., dtype=torch.float64) y is tensor(0)
# train acc 0.72265625
# test acc 0.71025390625
# loss 111.48294925689697
# mean tensor(7., dtype=torch.float64) y is tensor(5)
# train acc 0.73828125
# test acc 0.72060546875
# loss 113.7002592086792
# mean tensor(6.1500, dtype=torch.float64) y is tensor(5)
# train acc 0.71484375
# test acc 0.71689453125
# loss 86.64804148674011
# mean tensor(8., dtype=torch.float64) y is tensor(2)
# train acc 0.7265625
# test acc 0.71376953125
# loss 87.43718957901001
# mean tensor(8.7500, dtype=torch.float64) y is tensor(6)
# train acc 0.7265625
# test acc 0.70625
# loss 86.75391292572021
# mean tensor(0., dtype=torch.float64) y is tensor(4)
# train acc 0.6796875
# test acc 0.71083984375
# loss 76.53107988834381
# mean tensor(3., dtype=torch.float64) y is tensor(1)
# train acc 0.7265625
# test acc 0.70830078125
# loss 114.15439128875732
# mean tensor(1.9000, dtype=torch.float64) y is tensor(5)
# train acc 0.6953125
# test acc 0.70703125
# loss 97.13810777664185
# mean tensor(7.7000, dtype=torch.float64) y is tensor(3)
# train acc 0.7421875
# test acc 0.71474609375
# loss 80.16721498966217
# mean tensor(3.0500, dtype=torch.float64) y is tensor(6)
# train acc 0.6953125
# test acc 0.72177734375
# loss 107.51381301879883
# mean tensor(6., dtype=torch.float64) y is tensor(5)
# train acc 0.6796875
# test acc 0.71318359375
# loss 85.32608842849731
# mean tensor(7., dtype=torch.float64) y is tensor(2)
# train acc 0.72265625
# test acc 0.71162109375
# loss 74.20510184764862
# mean tensor(4.4000, dtype=torch.float64) y is tensor(9)
# train acc 0.67578125
# test acc 0.71044921875
# loss 89.77868032455444
# mean tensor(9., dtype=torch.float64) y is tensor(6)
# train acc 0.66015625
# test acc 0.70439453125
# loss 82.59456014633179
# mean tensor(0., dtype=torch.float64) y is tensor(7)
# train acc 0.74609375
# test acc 0.71103515625
# loss 67.00880432128906
# mean tensor(1.3000, dtype=torch.float64) y is tensor(4)
# train acc 0.67578125
# test acc 0.70732421875
# loss 85.1275246143341
# mean tensor(7., dtype=torch.float64) y is tensor(0)
# train acc 0.65625
# test acc 0.712109375
# loss 92.05313396453857
# mean tensor(2., dtype=torch.float64) y is tensor(7)
# train acc 0.7265625
# test acc 0.7037109375
# loss 81.25839185714722
# mean tensor(0., dtype=torch.float64) y is tensor(1)
# train acc 0.6875
# test acc 0.71015625
# loss 96.8087968826294
# mean tensor(4.2000, dtype=torch.float64) y is tensor(2)
# train acc 0.6875
# test acc 0.69853515625
# loss 73.5484836101532
# mean tensor(3., dtype=torch.float64) y is tensor(2)
# train acc 0.734375
# test acc 0.70556640625
# loss 85.07485818862915
# mean tensor(0., dtype=torch.float64) y is tensor(0)
# train acc 0.70703125
# test acc 0.71396484375
# loss 104.73567700386047
# mean tensor(5.1000, dtype=torch.float64) y is tensor(8)
# train acc 0.7421875
# test acc 0.71845703125
# loss 65.8356065750122
# mean tensor(1., dtype=torch.float64) y is tensor(7)
# train acc 0.71484375
# test acc 0.7052734375
# loss 101.69319915771484
# mean tensor(7.6000, dtype=torch.float64) y is tensor(6)
# train acc 0.68359375
# test acc 0.70146484375
# loss 68.54005682468414
# mean tensor(4.9500, dtype=torch.float64) y is tensor(7)
# train acc 0.734375
# test acc 0.717578125
# loss 123.38282775878906
# mean tensor(4., dtype=torch.float64) y is tensor(1)
# train acc 0.72265625
# test acc 0.71005859375
# loss 90.84472942352295
# mean tensor(3., dtype=torch.float64) y is tensor(4)
# train acc 0.69921875
# test acc 0.71923828125
# loss 92.49277305603027
# mean tensor(6., dtype=torch.float64) y is tensor(4)
# train acc 0.71484375
# test acc 0.70576171875
# loss 83.21467208862305
# mean tensor(6.9500, dtype=torch.float64) y is tensor(0)
# train acc 0.6796875
# test acc 0.71240234375
# loss 90.1379759311676
# mean tensor(4., dtype=torch.float64) y is tensor(5)
# train acc 0.71484375
# test acc 0.70859375
# loss 80.36669540405273
# mean tensor(4., dtype=torch.float64) y is tensor(3)
# train acc 0.72265625
# test acc 0.71337890625
# loss 76.0591688156128
# mean tensor(6., dtype=torch.float64) y is tensor(7)
# train acc 0.6484375
# test acc 0.71357421875
# loss 100.89303016662598
# mean tensor(6.6500, dtype=torch.float64) y is tensor(2)
# train acc 0.76171875
# test acc 0.7232421875
# loss 71.56566667556763
# mean tensor(7.1000, dtype=torch.float64) y is tensor(5)
# train acc 0.703125
# test acc 0.71015625
# loss 84.55574655532837
# mean tensor(1., dtype=torch.float64) y is tensor(3)
# train acc 0.7109375
# test acc 0.70927734375
# loss 98.10094738006592
# mean tensor(2.0500, dtype=torch.float64) y is tensor(4)
# train acc 0.6875
# test acc 0.70419921875
# loss 59.63608169555664
# mean tensor(7.6000, dtype=torch.float64) y is tensor(2)
# train acc 0.7109375
# test acc 0.71572265625
# loss 70.84345626831055
# mean tensor(1., dtype=torch.float64) y is tensor(7)
# train acc 0.71484375
# test acc 0.72333984375
# loss 81.51425170898438
# mean tensor(1.1000, dtype=torch.float64) y is tensor(9)
# train acc 0.74609375
# test acc 0.708984375
# loss 93.64724922180176
# mean tensor(0., dtype=torch.float64) y is tensor(0)
# train acc 0.6875
# test acc 0.7123046875
# loss 92.39842939376831
# mean tensor(4.1500, dtype=torch.float64) y is tensor(9)
# train acc 0.6953125
# test acc 0.71669921875
# loss 69.27036428451538
# mean tensor(4.1500, dtype=torch.float64) y is tensor(5)
# train acc 0.7109375
# test acc 0.72783203125
# loss 87.74990725517273
# mean tensor(4.8500, dtype=torch.float64) y is tensor(6)
# train acc 0.71484375
# test acc 0.7271484375
# loss 84.24394798278809
# mean tensor(4., dtype=torch.float64) y is tensor(2)
# train acc 0.71875
# test acc 0.71806640625
# loss 124.1590666770935
# mean tensor(6.1000, dtype=torch.float64) y is tensor(2)
# train acc 0.671875
# test acc 0.7115234375
# loss 111.8311014175415
# mean tensor(3., dtype=torch.float64) y is tensor(2)
# train acc 0.703125
# test acc 0.7162109375
# loss 86.15070796012878
# mean tensor(6., dtype=torch.float64) y is tensor(2)
# train acc 0.6953125
# test acc 0.71669921875
# loss 102.66257333755493
# mean tensor(4.6000, dtype=torch.float64) y is tensor(4)
# train acc 0.7109375
# test acc 0.702734375
# loss 100.08395195007324
# mean tensor(1., dtype=torch.float64) y is tensor(6)
# train acc 0.67578125
# test acc 0.70849609375
# loss 73.46789455413818
# mean tensor(2.4000, dtype=torch.float64) y is tensor(9)
# train acc 0.65625
# test acc 0.71259765625
# loss 90.9276533126831
# mean tensor(7.1000, dtype=torch.float64) y is tensor(7)
# train acc 0.65234375
# test acc 0.716015625
# loss 84.08003234863281
# mean tensor(8.2500, dtype=torch.float64) y is tensor(5)
# train acc 0.67578125
# test acc 0.72275390625
# loss 75.26463508605957
# mean tensor(4.2500, dtype=torch.float64) y is tensor(9)
# train acc 0.67578125
# test acc 0.72275390625
# loss 71.55908346176147
# mean tensor(2., dtype=torch.float64) y is tensor(3)
# train acc 0.69140625
# test acc 0.71015625
# loss 97.07212162017822
# mean tensor(2., dtype=torch.float64) y is tensor(1)
# train acc 0.72265625
# test acc 0.713671875
# loss 98.61316108703613
# mean tensor(3.4500, dtype=torch.float64) y is tensor(1)
# train acc 0.71875
# test acc 0.71396484375
# loss 89.68874168395996
# mean tensor(3., dtype=torch.float64) y is tensor(7)
# train acc 0.73828125
# test acc 0.71689453125
# loss 74.50313425064087
# mean tensor(7.4000, dtype=torch.float64) y is tensor(5)
# train acc 0.6953125
# test acc 0.71591796875
# loss 130.70100784301758
# mean tensor(5.2000, dtype=torch.float64) y is tensor(3)
# train acc 0.7265625
# test acc 0.72373046875
# loss 77.16826057434082
# mean tensor(6., dtype=torch.float64) y is tensor(9)
# train acc 0.70703125
# test acc 0.72578125
# loss 87.8815336227417
# mean tensor(8., dtype=torch.float64) y is tensor(8)
# train acc 0.75
# test acc 0.71796875
# loss 87.71741104125977
# mean tensor(8., dtype=torch.float64) y is tensor(7)
# train acc 0.71484375
# test acc 0.71337890625
# loss 78.63318729400635
# mean tensor(7., dtype=torch.float64) y is tensor(0)
# train acc 0.67578125
# test acc 0.71142578125
# loss 85.17907238006592
# mean tensor(2.8500, dtype=torch.float64) y is tensor(9)
# train acc 0.7265625
# test acc 0.7142578125
# loss 100.75522661209106
# mean tensor(3.5000, dtype=torch.float64) y is tensor(3)
# train acc 0.67578125
# test acc 0.721484375
# loss 90.36124515533447
# mean tensor(6.5000, dtype=torch.float64) y is tensor(8)
# train acc 0.71875
# test acc 0.71201171875
# loss 94.80124759674072
# mean tensor(6.2500, dtype=torch.float64) y is tensor(2)
# train acc 0.6875
# test acc 0.7208984375
# loss 86.50706005096436
# mean tensor(5.1500, dtype=torch.float64) y is tensor(2)
# train acc 0.75
# test acc 0.73017578125
# loss 91.61522674560547
# mean tensor(5., dtype=torch.float64) y is tensor(9)
# train acc 0.69921875
# test acc 0.71982421875
# loss 97.67687058448792
# mean tensor(1.3000, dtype=torch.float64) y is tensor(6)
# train acc 0.71875
# test acc 0.70986328125
# loss 100.46906471252441
# mean tensor(4.7000, dtype=torch.float64) y is tensor(3)
# train acc 0.71875
# test acc 0.71572265625
# loss 74.80522727966309
# mean tensor(6., dtype=torch.float64) y is tensor(3)
# train acc 0.71875
# test acc 0.71728515625
# loss 76.3315200805664
# mean tensor(7.6000, dtype=torch.float64) y is tensor(8)
# train acc 0.7265625
# test acc 0.72109375
# loss 92.30751943588257
# mean tensor(5., dtype=torch.float64) y is tensor(3)
# train acc 0.7421875
# test acc 0.71826171875
# loss 88.62910604476929
# mean tensor(7.9500, dtype=torch.float64) y is tensor(4)
# train acc 0.75390625
# test acc 0.72236328125
# loss 86.95112609863281
# mean tensor(2.9500, dtype=torch.float64) y is tensor(6)
# train acc 0.73046875
# test acc 0.71669921875
# loss 65.68595790863037
# mean tensor(3.3000, dtype=torch.float64) y is tensor(8)
# train acc 0.66796875
# test acc 0.72197265625
# loss 76.99511909484863
# mean tensor(1.8500, dtype=torch.float64) y is tensor(4)
# train acc 0.7578125
# test acc 0.71923828125
# loss 83.93579387664795
# mean tensor(0., dtype=torch.float64) y is tensor(1)
# train acc 0.7265625
# test acc 0.7224609375
# loss 79.20591831207275
# mean tensor(5.5000, dtype=torch.float64) y is tensor(7)
# train acc 0.69921875
# test acc 0.7216796875
# loss 91.80554580688477
# mean tensor(2.2000, dtype=torch.float64) y is tensor(1)
# train acc 0.68359375
# test acc 0.7201171875
# loss 105.67567682266235
# mean tensor(6., dtype=torch.float64) y is tensor(4)
# train acc 0.71484375
# test acc 0.72646484375
# loss 85.4054651260376
# mean tensor(5.9000, dtype=torch.float64) y is tensor(7)
# train acc 0.6953125
# test acc 0.71943359375
# loss 74.7518720626831
# mean tensor(1., dtype=torch.float64) y is tensor(9)
# train acc 0.75
# test acc 0.7162109375
# loss 72.10939025878906
# mean tensor(4., dtype=torch.float64) y is tensor(3)
# train acc 0.7109375
# test acc 0.725390625
# loss 104.63497924804688
# mean tensor(3.1000, dtype=torch.float64) y is tensor(1)
# train acc 0.7578125
# test acc 0.72255859375
# loss 104.75669765472412
# mean tensor(3.2000, dtype=torch.float64) y is tensor(9)
# train acc 0.75
# test acc 0.7251953125
# loss 88.74767732620239
# mean tensor(8., dtype=torch.float64) y is tensor(6)
# train acc 0.703125
# test acc 0.7154296875
# loss 98.4668710231781
# mean tensor(0., dtype=torch.float64) y is tensor(9)
# train acc 0.7265625
# test acc 0.72568359375
# loss 79.50810289382935
# mean tensor(2.2500, dtype=torch.float64) y is tensor(5)
# train acc 0.73046875
# test acc 0.71669921875
# loss 98.3711462020874
# mean tensor(3.2000, dtype=torch.float64) y is tensor(3)
# train acc 0.7109375
# test acc 0.716015625
# loss 76.6506838798523
# mean tensor(7.5000, dtype=torch.float64) y is tensor(0)
# train acc 0.69921875
# test acc 0.71611328125
# loss 80.58478832244873
# mean tensor(5.3000, dtype=torch.float64) y is tensor(6)
# train acc 0.71875
# test acc 0.7205078125
# loss 96.11729860305786
# mean tensor(2.6000, dtype=torch.float64) y is tensor(4)
# train acc 0.7421875
# test acc 0.73173828125
# loss 84.02227592468262
# mean tensor(5., dtype=torch.float64) y is tensor(5)
# train acc 0.65625
# test acc 0.72763671875
# loss 100.85301160812378
# mean tensor(7.1000, dtype=torch.float64) y is tensor(1)
# train acc 0.7734375
# test acc 0.7234375
# loss 68.50941944122314
# mean tensor(2., dtype=torch.float64) y is tensor(0)
# train acc 0.74609375
# test acc 0.72177734375
# loss 84.44171142578125
# mean tensor(2., dtype=torch.float64) y is tensor(1)
# train acc 0.75
# test acc 0.72099609375
# loss 104.69304037094116
# mean tensor(5., dtype=torch.float64) y is tensor(3)
# train acc 0.69921875
# test acc 0.71650390625
# loss 84.37478160858154
# mean tensor(6., dtype=torch.float64) y is tensor(1)
# train acc 0.76171875
# test acc 0.71591796875
# loss 72.02863693237305
# mean tensor(3.5000, dtype=torch.float64) y is tensor(7)
# train acc 0.66796875
# test acc 0.7265625
# loss 68.02188539505005
# mean tensor(5.8500, dtype=torch.float64) y is tensor(0)
# train acc 0.71484375
# test acc 0.72841796875
# loss 63.59671878814697
# mean tensor(4., dtype=torch.float64) y is tensor(1)
# train acc 0.72265625
# test acc 0.73125
# loss 95.37604236602783
# mean tensor(4.5000, dtype=torch.float64) y is tensor(0)
# train acc 0.67578125
# test acc 0.72255859375
# loss 94.03895473480225
# mean tensor(5.6000, dtype=torch.float64) y is tensor(8)
# train acc 0.7421875
# test acc 0.72138671875
# loss 74.71424007415771
# mean tensor(3.9000, dtype=torch.float64) y is tensor(5)
# train acc 0.7890625
# test acc 0.71796875
# loss 71.10080862045288
# mean tensor(3.3000, dtype=torch.float64) y is tensor(2)
# train acc 0.69140625
# test acc 0.7181640625
# loss 88.40802192687988
# mean tensor(3., dtype=torch.float64) y is tensor(7)
# train acc 0.74609375
# test acc 0.71923828125
# loss 64.06290626525879
# mean tensor(1., dtype=torch.float64) y is tensor(4)
# train acc 0.734375
# test acc 0.71806640625
# loss 72.60217761993408
# mean tensor(3., dtype=torch.float64) y is tensor(9)
# train acc 0.69140625
# test acc 0.722265625
# loss 100.39942264556885
# mean tensor(1., dtype=torch.float64) y is tensor(9)
# train acc 0.7265625
# test acc 0.72275390625
# loss 87.79768466949463
# mean tensor(7., dtype=torch.float64) y is tensor(1)
# train acc 0.703125
# test acc 0.7248046875
# loss 86.82240581512451
# mean tensor(4.5000, dtype=torch.float64) y is tensor(2)
# train acc 0.75390625
# test acc 0.729296875
# loss 74.30982303619385
# mean tensor(9., dtype=torch.float64) y is tensor(3)
# train acc 0.703125
# test acc 0.72451171875
# loss 88.94159364700317
# mean tensor(2., dtype=torch.float64) y is tensor(4)
# train acc 0.71875
# test acc 0.72294921875
# loss 82.04438304901123
# mean tensor(4., dtype=torch.float64) y is tensor(4)
# train acc 0.703125
# test acc 0.7193359375
# loss 95.48909282684326
# mean tensor(2., dtype=torch.float64) y is tensor(1)
# train acc 0.703125
# test acc 0.7181640625
# loss 83.18731927871704
# mean tensor(4., dtype=torch.float64) y is tensor(1)
# train acc 0.6953125
# test acc 0.723828125
# loss 79.00269031524658
# mean tensor(2., dtype=torch.float64) y is tensor(1)
# train acc 0.75
# test acc 0.73291015625
# loss 70.18265056610107
# mean tensor(7.5000, dtype=torch.float64) y is tensor(7)
# train acc 0.703125
# test acc 0.73193359375
# loss 79.4325532913208
# mean tensor(0., dtype=torch.float64) y is tensor(8)
# train acc 0.7109375
# test acc 0.73173828125
# loss 71.27159690856934
# mean tensor(0., dtype=torch.float64) y is tensor(9)
# train acc 0.75390625
# test acc 0.72509765625
# loss 83.1881217956543
# mean tensor(7.9000, dtype=torch.float64) y is tensor(1)
# train acc 0.703125
# test acc 0.72509765625
# loss 62.61549186706543
# mean tensor(7., dtype=torch.float64) y is tensor(4)
# train acc 0.70703125
# test acc 0.7193359375
# loss 75.17232465744019
# mean tensor(8.7500, dtype=torch.float64) y is tensor(0)
# train acc 0.69921875
# test acc 0.71943359375
# loss 97.43040943145752
# mean tensor(7.5500, dtype=torch.float64) y is tensor(2)
# train acc 0.70703125
# test acc 0.7240234375
# loss 87.2443962097168
# mean tensor(2., dtype=torch.float64) y is tensor(4)
# train acc 0.6953125
# test acc 0.734375
# loss 108.4785099029541
# mean tensor(4.1000, dtype=torch.float64) y is tensor(5)
# train acc 0.76171875
# test acc 0.72763671875
# loss 71.45242118835449
# mean tensor(0., dtype=torch.float64) y is tensor(8)
# train acc 0.71875
# test acc 0.71962890625
# loss 91.70008182525635
# mean tensor(7.7000, dtype=torch.float64) y is tensor(9)
# train acc 0.69921875
# test acc 0.72685546875
# loss 76.77596044540405
# mean tensor(1.3500, dtype=torch.float64) y is tensor(5)
# train acc 0.74609375
# test acc 0.7283203125
# loss 102.547372341156
# mean tensor(6., dtype=torch.float64) y is tensor(8)
# train acc 0.69140625
# test acc 0.72939453125
# loss 82.51368808746338
# mean tensor(7.1000, dtype=torch.float64) y is tensor(3)
# train acc 0.73046875
# test acc 0.7265625
# loss 87.40417909622192
# mean tensor(5., dtype=torch.float64) y is tensor(6)
# train acc 0.73046875
# test acc 0.7275390625
# loss 71.24969625473022
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# train acc 0.7265625
# test acc 0.72353515625
# loss 115.0405855178833
# mean tensor(1., dtype=torch.float64) y is tensor(2)
# train acc 0.71875
# test acc 0.719921875
# loss 63.25085258483887
# mean tensor(7.1000, dtype=torch.float64) y is tensor(1)
# train acc 0.70703125
# test acc 0.714453125
# loss 80.73837566375732
# mean tensor(2., dtype=torch.float64) y is tensor(2)
# train acc 0.75
# test acc 0.7240234375
# loss 83.49884033203125
# mean tensor(8., dtype=torch.float64) y is tensor(9)
# train acc 0.7265625
# test acc 0.72421875
# loss 77.39681148529053
# mean tensor(5., dtype=torch.float64) y is tensor(4)
# train acc 0.6640625
# test acc 0.73046875
# loss 79.64784622192383
# mean tensor(3.1000, dtype=torch.float64) y is tensor(8)
# train acc 0.7421875
# test acc 0.72919921875
# loss 58.51654863357544
# mean tensor(7., dtype=torch.float64) y is tensor(2)
# train acc 0.67578125
# test acc 0.7265625
# loss 108.46797752380371
# mean tensor(1.4500, dtype=torch.float64) y is tensor(1)
# train acc 0.73046875
# test acc 0.72177734375
# loss 80.25401878356934
# mean tensor(1., dtype=torch.float64) y is tensor(9)
# train acc 0.7578125
# test acc 0.71865234375
# loss 81.70833492279053
# mean tensor(0., dtype=torch.float64) y is tensor(7)
# train acc 0.75
# test acc 0.731640625
# loss 81.64112567901611
# mean tensor(5.8000, dtype=torch.float64) y is tensor(0)
# train acc 0.70703125
# test acc 0.731640625
# loss 64.07007789611816
# mean tensor(5.3000, dtype=torch.float64) y is tensor(0)
# train acc 0.73046875
# test acc 0.72724609375
# loss 93.3306245803833
# mean tensor(2.3000, dtype=torch.float64) y is tensor(0)
# train acc 0.76953125
# test acc 0.73115234375
# loss 56.09282112121582
# mean tensor(1., dtype=torch.float64) y is tensor(2)
# train acc 0.7578125
# test acc 0.72529296875
# loss 89.9900255203247
# mean tensor(8.8500, dtype=torch.float64) y is tensor(7)
# train acc 0.69921875
# test acc 0.72529296875
# loss 83.34113788604736
# mean tensor(4.9000, dtype=torch.float64) y is tensor(7)
# train acc 0.67578125
# test acc 0.73046875
# loss 122.19061660766602
# mean tensor(7., dtype=torch.float64) y is tensor(3)
# train acc 0.7421875
# test acc 0.72802734375
# loss 91.249436378479
# mean tensor(6.3000, dtype=torch.float64) y is tensor(7)
# train acc 0.7421875
# test acc 0.72744140625
# loss 77.97607612609863
# mean tensor(1., dtype=torch.float64) y is tensor(9)
# train acc 0.71484375
# test acc 0.73076171875
# loss 70.25520896911621
# mean tensor(1., dtype=torch.float64) y is tensor(6)
# train acc 0.7109375
# test acc 0.73212890625
# loss 79.54927110671997
# mean tensor(5.8000, dtype=torch.float64) y is tensor(4)
# train acc 0.70703125
# test acc 0.71806640625
# loss 74.61171531677246
# mean tensor(3.2500, dtype=torch.float64) y is tensor(8)
# train acc 0.7265625
# test acc 0.71552734375
# loss 89.3123140335083
# mean tensor(3.1000, dtype=torch.float64) y is tensor(3)
# train acc 0.703125
# test acc 0.7158203125
# loss 92.2549614906311
# mean tensor(3., dtype=torch.float64) y is tensor(1)
# train acc 0.68359375
# test acc 0.73193359375
# loss 86.33766460418701
# mean tensor(2., dtype=torch.float64) y is tensor(2)
# train acc 0.7265625
# test acc 0.7318359375
# loss 94.78651142120361
# mean tensor(6., dtype=torch.float64) y is tensor(0)
# train acc 0.73828125
# test acc 0.73564453125
# loss 55.55028533935547
# mean tensor(3.5000, dtype=torch.float64) y is tensor(8)
# train acc 0.703125
# test acc 0.72578125
# loss 96.19003486633301
# mean tensor(4.7000, dtype=torch.float64) y is tensor(2)
# train acc 0.71875
# test acc 0.7259765625
# loss 113.15075969696045
# mean tensor(0., dtype=torch.float64) y is tensor(2)
# train acc 0.6875
# test acc 0.73017578125
# loss 81.64257431030273
# mean tensor(8.4000, dtype=torch.float64) y is tensor(3)
# train acc 0.73828125
# test acc 0.73203125
# loss 98.69298267364502
# mean tensor(6., dtype=torch.float64) y is tensor(9)
# train acc 0.75390625
# test acc 0.72734375
# loss 78.53079891204834
# mean tensor(0.2500, dtype=torch.float64) y is tensor(5)
# train acc 0.72265625
# test acc 0.71962890625
# loss 118.27052211761475
# mean tensor(0., dtype=torch.float64) y is tensor(3)
# train acc 0.72265625
# test acc 0.7177734375
# loss 74.7431697845459
# mean tensor(9., dtype=torch.float64) y is tensor(7)
# train acc 0.73828125
# test acc 0.7298828125
# loss 88.66948795318604
# mean tensor(7., dtype=torch.float64) y is tensor(1)
# train acc 0.7265625
# test acc 0.72080078125
# loss 76.9246711730957
# mean tensor(0., dtype=torch.float64) y is tensor(7)
# train acc 0.72265625
# test acc 0.72216796875
# loss 71.69034004211426
# mean tensor(3.2500, dtype=torch.float64) y is tensor(4)
# ...
# mean tensor(7., dtype=torch.float64) y is tensor(3)
# train acc 0.68359375
# test acc 0.73046875
# loss 101.15065813064575
# mean tensor(6.0500, dtype=torch.float64) y is tensor(2)
# train acc 0.703125
# test acc 0.72421875
# loss 97.14716529846191
# mean tensor(6.1500, dtype=torch.float64) y is tensor(8)
# train acc 0.7421875
# test acc 0.73515625
# loss 55.515024185180664
# mean tensor(1.4500, dtype=torch.float64) y is tensor(2)
# train acc 0.6953125
# test acc 0.73369140625
# loss 89.88565492630005
# mean tensor(6., dtype=torch.float64) y is tensor(1)
# train acc 0.7578125
# test acc 0.7375
# loss 103.62609767913818
# mean tensor(4., dtype=torch.float64) y is tensor(1)
# train acc 0.68359375
# test acc 0.74140625
# loss 69.60468101501465
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# train acc 0.73046875
# test acc 0.74248046875
# loss 56.590599060058594
# mean tensor(8.9500, dtype=torch.float64) y is tensor(9)
# train acc 0.73828125
# test acc 0.73447265625
# loss 88.40414714813232
# mean tensor(9., dtype=torch.float64) y is tensor(5)
# train acc 0.70703125
# test acc 0.7318359375
# loss 74.29449844360352
# mean tensor(5., dtype=torch.float64) y is tensor(7)
# train acc 0.7109375
# test acc 0.73623046875
# loss 70.89682245254517
# mean tensor(5., dtype=torch.float64) y is tensor(3)
# train acc 0.74609375
# test acc 0.73740234375
# loss 93.24056816101074
# mean tensor(4., dtype=torch.float64) y is tensor(7)
# train acc 0.6484375
# test acc 0.737890625
# loss 81.32934284210205
# mean tensor(0., dtype=torch.float64) y is tensor(8)
# train acc 0.7578125
# test acc 0.73017578125
# loss 89.95893955230713
# mean tensor(7., dtype=torch.float64) y is tensor(3)
# train acc 0.7578125
# test acc 0.73056640625
# loss 95.50491762161255
# mean tensor(7.6000, dtype=torch.float64) y is tensor(1)
# train acc 0.7265625
# test acc 0.7365234375
# loss 69.40794658660889
# mean tensor(0., dtype=torch.float64) y is tensor(2)
# train acc 0.7109375
# test acc 0.73447265625
# loss 72.99842596054077
# mean tensor(0., dtype=torch.float64) y is tensor(3)
# train acc 0.6875
# test acc 0.7287109375
# loss 88.4368953704834
# mean tensor(2.9500, dtype=torch.float64) y is tensor(4)
# train acc 0.74609375
# test acc 0.7271484375
# loss 84.9044680595398
# mean tensor(1., dtype=torch.float64) y is tensor(2)
# train acc 0.67578125
# test acc 0.7283203125
# loss 118.1069188117981
# mean tensor(1., dtype=torch.float64) y is tensor(3)
# train acc 0.72265625
# test acc 0.73134765625
# loss 106.7281928062439
# mean tensor(7., dtype=torch.float64) y is tensor(8)
# train acc 0.73046875
# test acc 0.7333984375
# loss 68.16552352905273
# mean tensor(5., dtype=torch.float64) y is tensor(9)
# train acc 0.734375
# test acc 0.726171875
# loss 81.35460090637207
# mean tensor(3.2500, dtype=torch.float64) y is tensor(5)
# train acc 0.734375
# test acc 0.72841796875
# loss 69.61272048950195
# mean tensor(8.5500, dtype=torch.float64) y is tensor(2)
# train acc 0.69140625
# test acc 0.7263671875
# loss 67.364426612854
# mean tensor(1., dtype=torch.float64) y is tensor(6)
# train acc 0.6953125
# test acc 0.73134765625
# loss 87.18336868286133
# mean tensor(8., dtype=torch.float64) y is tensor(2)
# train acc 0.73828125
# test acc 0.73271484375
# loss 105.31757926940918
# mean tensor(4.0500, dtype=torch.float64) y is tensor(9)
# train acc 0.7265625
# test acc 0.734765625
# loss 56.4500150680542
# mean tensor(4., dtype=torch.float64) y is tensor(2)
# train acc 0.70703125
# test acc 0.740234375
# loss 105.06861066818237
# mean tensor(1.7500, dtype=torch.float64) y is tensor(5)
# train acc 0.71875
# test acc 0.73681640625
# loss 92.86666107177734
# mean tensor(7.7500, dtype=torch.float64) y is tensor(2)
# train acc 0.69140625
# test acc 0.738671875
# loss 83.13910293579102
# mean tensor(1., dtype=torch.float64) y is tensor(8)
# train acc 0.7109375
# test acc 0.73916015625
# loss 78.59988975524902
# mean tensor(7., dtype=torch.float64) y is tensor(2)
# train acc 0.73828125
# test acc 0.73544921875
# loss 105.00614356994629
# mean tensor(3., dtype=torch.float64) y is tensor(2)
# train acc 0.703125
# test acc 0.73583984375
# loss 111.06413078308105
# mean tensor(1., dtype=torch.float64) y is tensor(7)
# train acc 0.71875
# test acc 0.7404296875
# loss 87.7074842453003
# mean tensor(4., dtype=torch.float64) y is tensor(3)
# train acc 0.71875
# test acc 0.74296875
# loss 93.40714645385742
# mean tensor(3.1000, dtype=torch.float64) y is tensor(7)
# train acc 0.703125
# test acc 0.73515625
# loss 56.65735912322998
# mean tensor(3., dtype=torch.float64) y is tensor(2)
# train acc 0.68359375
# test acc 0.72685546875
# loss 88.6177749633789
# mean tensor(4., dtype=torch.float64) y is tensor(5)
# train acc 0.72265625
# test acc 0.72880859375
# loss 88.19978046417236
# mean tensor(2.9500, dtype=torch.float64) y is tensor(0)
# train acc 0.69140625
# test acc 0.72861328125
# loss 97.51552295684814
# mean tensor(8.5000, dtype=torch.float64) y is tensor(7)
# train acc 0.65625
# test acc 0.7314453125
# loss 80.57471942901611
# mean tensor(3.6000, dtype=torch.float64) y is tensor(1)
# train acc 0.71484375
# test acc 0.73359375
# loss 67.8478193283081
# mean tensor(4.7000, dtype=torch.float64) y is tensor(7)
# train acc 0.71875
# test acc 0.7345703125
# loss 52.01704978942871
# mean tensor(4., dtype=torch.float64) y is tensor(9)
# train acc 0.68359375
# test acc 0.73701171875
# loss 94.8015251159668
# mean tensor(1.7000, dtype=torch.float64) y is tensor(3)
# train acc 0.7265625
# test acc 0.73251953125
# loss 87.78659152984619
# mean tensor(6., dtype=torch.float64) y is tensor(9)
# train acc 0.7109375
# test acc 0.73212890625
# loss 68.95630073547363
# mean tensor(4.7500, dtype=torch.float64) y is tensor(0)
# train acc 0.7265625
# test acc 0.73271484375
# loss 84.07904434204102
# mean tensor(7., dtype=torch.float64) y is tensor(3)
# train acc 0.734375
# test acc 0.73515625
# loss 73.63449287414551
# mean tensor(2., dtype=torch.float64) y is tensor(0)
# train acc 0.73828125
# test acc 0.74072265625
# loss 96.68097114562988
# mean tensor(6.6500, dtype=torch.float64) y is tensor(9)
# train acc 0.7265625
# test acc 0.72724609375
# loss 70.44693756103516
# mean tensor(7.7000, dtype=torch.float64) y is tensor(8)
# train acc 0.71875
# test acc 0.73095703125
# loss 73.69923830032349
# mean tensor(5.0500, dtype=torch.float64) y is tensor(6)
# train acc 0.75
# test acc 0.73994140625
# loss 86.64864611625671
# mean tensor(0., dtype=torch.float64) y is tensor(5)
# train acc 0.71484375
# test acc 0.73662109375
# loss 79.24667167663574
# mean tensor(5.6000, dtype=torch.float64) y is tensor(1)
# train acc 0.73046875
# test acc 0.72451171875
# loss 71.87768268585205
# mean tensor(7.6500, dtype=torch.float64) y is tensor(1)
# train acc 0.71484375
# test acc 0.72802734375
# loss 92.59207916259766
# mean tensor(2., dtype=torch.float64) y is tensor(5)
# train acc 0.73046875
# test acc 0.7314453125
# loss 89.53067970275879
# mean tensor(4.4500, dtype=torch.float64) y is tensor(6)
# train acc 0.73828125
# test acc 0.7341796875
# loss 93.76343250274658
# mean tensor(9., dtype=torch.float64) y is tensor(1)
# train acc 0.73046875
# test acc 0.740625
# loss 84.47940921783447
# mean tensor(9., dtype=torch.float64) y is tensor(3)
# train acc 0.73046875
# test acc 0.7388671875
# loss 85.52541923522949
# mean tensor(9., dtype=torch.float64) y is tensor(1)
# train acc 0.73046875
# test acc 0.73662109375
# loss 80.63687801361084
# mean tensor(6.1000, dtype=torch.float64) y is tensor(5)
# train acc 0.76171875
# test acc 0.73154296875
# loss 84.48722553253174
# mean tensor(7., dtype=torch.float64) y is tensor(7)
# train acc 0.73828125
# test acc 0.72939453125
# loss 84.23325061798096
# mean tensor(7.8500, dtype=torch.float64) y is tensor(4)
# train acc 0.7109375
# test acc 0.72412109375
# loss 91.25913143157959
# mean tensor(5.1500, dtype=torch.float64) y is tensor(4)
# train acc 0.703125
# test acc 0.72529296875
# loss 69.88946723937988
# mean tensor(8., dtype=torch.float64) y is tensor(1)
# train acc 0.72265625
# test acc 0.73759765625
# loss 90.65547561645508
# mean tensor(7.1000, dtype=torch.float64) y is tensor(1)
# train acc 0.76171875
# test acc 0.74140625
# loss 66.56533432006836
# mean tensor(2.5000, dtype=torch.float64) y is tensor(2)
# train acc 0.75
# test acc 0.74365234375
# loss 109.32892656326294
# mean tensor(8., dtype=torch.float64) y is tensor(0)
# train acc 0.73828125
# test acc 0.736328125
# loss 80.36761379241943
# mean tensor(2.9500, dtype=torch.float64) y is tensor(6)
# train acc 0.68359375
# test acc 0.72763671875
# loss 92.2801628112793
# mean tensor(8.3500, dtype=torch.float64) y is tensor(6)
# train acc 0.734375
# test acc 0.72880859375
# loss 101.64030742645264
# mean tensor(6., dtype=torch.float64) y is tensor(6)
# train acc 0.7109375
# test acc 0.7328125
# loss 101.56916999816895
# mean tensor(0., dtype=torch.float64) y is tensor(9)
# train acc 0.72265625
# test acc 0.74130859375
# loss 78.60732078552246
# mean tensor(1., dtype=torch.float64) y is tensor(1)
# train acc 0.69140625
# test acc 0.73896484375
# loss 71.06571674346924
# mean tensor(1., dtype=torch.float64) y is tensor(9)
# train acc 0.734375
# test acc 0.73623046875
# loss 110.18045854568481
# mean tensor(3.3000, dtype=torch.float64) y is tensor(0)
# train acc 0.7421875
# test acc 0.73984375
# loss 106.72923755645752
# mean tensor(5., dtype=torch.float64) y is tensor(7)
# train acc 0.71484375
# test acc 0.740234375
# loss 97.73548603057861
# mean tensor(7.4500, dtype=torch.float64) y is tensor(4)
# train acc 0.71484375
# test acc 0.73955078125
# loss 89.88027000427246
# mean tensor(2.9500, dtype=torch.float64) y is tensor(7)
# train acc 0.734375
# test acc 0.737109375
# loss 75.23409748077393
# mean tensor(2., dtype=torch.float64) y is tensor(8)
# train acc 0.71875
# test acc 0.738671875
# loss 61.06847810745239
# mean tensor(8.6500, dtype=torch.float64) y is tensor(0)
# train acc 0.74609375
# test acc 0.7388671875
# loss 73.85014152526855
# mean tensor(5.1500, dtype=torch.float64) y is tensor(3)
# train acc 0.765625
# test acc 0.74580078125
# loss 90.8021650314331
# mean tensor(1., dtype=torch.float64) y is tensor(3)
# train acc 0.71875
# test acc 0.736328125
# loss 93.71712923049927
# mean tensor(7.1000, dtype=torch.float64) y is tensor(1)
# train acc 0.76171875
# test acc 0.73505859375
# loss 71.76805591583252
# mean tensor(0., dtype=torch.float64) y is tensor(3)
# train acc 0.703125
# test acc 0.730859375
# loss 103.31796455383301
# mean tensor(4., dtype=torch.float64) y is tensor(4)
# train acc 0.76171875
# test acc 0.73701171875
# loss 62.37067699432373
# mean tensor(4.6000, dtype=torch.float64) y is tensor(0)
# train acc 0.71484375
# test acc 0.734375
# loss 88.05103969573975
# mean tensor(7., dtype=torch.float64) y is tensor(4)
# train acc 0.7421875
# test acc 0.72666015625
# loss 107.62590789794922
# mean tensor(5., dtype=torch.float64) y is tensor(6)
# train acc 0.7265625
# test acc 0.72626953125
# loss 78.15393304824829
# mean tensor(4., dtype=torch.float64) y is tensor(7)
# train acc 0.71875
# test acc 0.7251953125
# loss 98.53714752197266
# mean tensor(6., dtype=torch.float64) y is tensor(4)
# train acc 0.6796875
# test acc 0.7447265625
# loss 91.3276596069336
# mean tensor(3.7500, dtype=torch.float64) y is tensor(6)
# train acc 0.7421875
# test acc 0.74794921875
# loss 105.74833297729492
# mean tensor(6.3000, dtype=torch.float64) y is tensor(0)
# train acc 0.69921875
# test acc 0.7419921875
# loss 88.1775131225586
# mean tensor(2.2000, dtype=torch.float64) y is tensor(0)
# train acc 0.71875
# test acc 0.73955078125
# loss 71.5527458190918
# mean tensor(2.9500, dtype=torch.float64) y is tensor(3)
# train acc 0.78515625
# test acc 0.73447265625
# loss 78.59770679473877
# mean tensor(0., dtype=torch.float64) y is tensor(0)
# train acc 0.72265625
# test acc 0.7337890625
# loss 96.54961490631104
# mean tensor(3.1500, dtype=torch.float64) y is tensor(6)
# train acc 0.70703125
# test acc 0.73427734375
# loss 80.7137279510498
# mean tensor(2.5000, dtype=torch.float64) y is tensor(9)
# train acc 0.74609375
# test acc 0.73203125
# loss 54.78174877166748
# mean tensor(3., dtype=torch.float64) y is tensor(7)
# train acc 0.73828125
# test acc 0.73212890625
# loss 75.60969161987305
# mean tensor(7.5000, dtype=torch.float64) y is tensor(6)
# train acc 0.75
# test acc 0.73564453125
# loss 84.83767557144165
# mean tensor(0., dtype=torch.float64) y is tensor(7)
# train acc 0.71484375
# test acc 0.7357421875
# loss 59.225043296813965
# mean tensor(0., dtype=torch.float64) y is tensor(1)
# train acc 0.72265625
# test acc 0.73515625
# loss 73.10360145568848
# mean tensor(9., dtype=torch.float64) y is tensor(2)
# train acc 0.69921875
# test acc 0.73447265625
# loss 71.17648363113403
# mean tensor(5., dtype=torch.float64) y is tensor(6)
# train acc 0.71484375
# test acc 0.730859375
# loss 81.05857706069946
# mean tensor(6., dtype=torch.float64) y is tensor(5)
# train acc 0.74609375
# test acc 0.73076171875
# loss 88.85830593109131
# mean tensor(6., dtype=torch.float64) y is tensor(0)
# train acc 0.73828125
# test acc 0.7298828125
# loss 85.14040756225586
# mean tensor(8.2500, dtype=torch.float64) y is tensor(1)
# train acc 0.703125
# test acc 0.7408203125
# loss 83.54809761047363
# mean tensor(5.4000, dtype=torch.float64) y is tensor(4)
# train acc 0.75
# test acc 0.73896484375
# loss 66.1782808303833
# mean tensor(2., dtype=torch.float64) y is tensor(6)
# train acc 0.73828125
# test acc 0.73515625
# loss 72.59681224822998
# mean tensor(7.7500, dtype=torch.float64) y is tensor(4)
# train acc 0.7734375
# test acc 0.732421875
# loss 96.95211982727051
# mean tensor(0., dtype=torch.float64) y is tensor(1)
# train acc 0.7890625
# test acc 0.73037109375
# loss 61.88979530334473
# mean tensor(8., dtype=torch.float64) y is tensor(7)
# train acc 0.703125
# test acc 0.74296875
# loss 93.3235855102539
# mean tensor(3.3000, dtype=torch.float64) y is tensor(4)
# train acc 0.765625
# test acc 0.7365234375
# loss 140.45333194732666
# mean tensor(8.2000, dtype=torch.float64) y is tensor(8)
# train acc 0.68359375
# test acc 0.737890625
# loss 82.6157431602478
# mean tensor(7., dtype=torch.float64) y is tensor(5)
# train acc 0.70703125
# test acc 0.74091796875
# loss 75.21649265289307
# mean tensor(3., dtype=torch.float64) y is tensor(8)
# train acc 0.7578125
# test acc 0.7408203125
# loss 69.76453304290771
# mean tensor(8., dtype=torch.float64) y is tensor(7)
# train acc 0.71875
# test acc 0.741015625
# loss 71.40305137634277
# mean tensor(3.1500, dtype=torch.float64) y is tensor(6)
# train acc 0.7265625
# test acc 0.73544921875
# loss 84.42366743087769
# mean tensor(7.7000, dtype=torch.float64) y is tensor(1)
# train acc 0.7109375
# test acc 0.74345703125
# loss 73.76571083068848
# mean tensor(0., dtype=torch.float64) y is tensor(3)
# train acc 0.71875
# test acc 0.74599609375
# loss 69.79293918609619
# mean tensor(7.6500, dtype=torch.float64) y is tensor(4)
# train acc 0.76953125
# test acc 0.729296875
# loss 83.04655456542969
# mean tensor(8.7000, dtype=torch.float64) y is tensor(1)
# train acc 0.7109375
# test acc 0.73779296875
# loss 87.88827610015869
# mean tensor(6., dtype=torch.float64) y is tensor(5)
# train acc 0.71484375
# test acc 0.7357421875
# loss 58.933932304382324
# mean tensor(2., dtype=torch.float64) y is tensor(3)
# train acc 0.7265625
# test acc 0.73095703125
# loss 82.6318769454956
# mean tensor(2.3000, dtype=torch.float64) y is tensor(4)
# train acc 0.75390625
# test acc 0.73857421875
# loss 77.96026253700256
# mean tensor(8., dtype=torch.float64) y is tensor(7)
# train acc 0.796875
# test acc 0.739453125
# loss 76.90517234802246
# mean tensor(0., dtype=torch.float64) y is tensor(1)
# train acc 0.765625
# test acc 0.7373046875
# loss 64.34144306182861
# mean tensor(6.4500, dtype=torch.float64) y is tensor(8)
# train acc 0.765625
# test acc 0.74970703125
# loss 101.52754783630371
# mean tensor(3.0500, dtype=torch.float64) y is tensor(8)
# train acc 0.71484375
# test acc 0.73974609375
# loss 87.7945146560669
# mean tensor(7., dtype=torch.float64) y is tensor(1)
# train acc 0.76953125
# test acc 0.7443359375
# loss 85.71876811981201
# mean tensor(2.6000, dtype=torch.float64) y is tensor(6)
# train acc 0.72265625
# test acc 0.74130859375
# loss 89.25960731506348
# mean tensor(2., dtype=torch.float64) y is tensor(5)
# train acc 0.75
# test acc 0.7376953125
# loss 91.39154624938965
# mean tensor(3., dtype=torch.float64) y is tensor(0)
# train acc 0.734375
# test acc 0.73740234375
# loss 72.10043716430664
# mean tensor(4.6500, dtype=torch.float64) y is tensor(1)
# train acc 0.7578125
# test acc 0.741796875
# loss 80.28674983978271
# mean tensor(0., dtype=torch.float64) y is tensor(0)
# train acc 0.71875
# test acc 0.73466796875
# loss 80.49983501434326
# mean tensor(7.7000, dtype=torch.float64) y is tensor(6)
# train acc 0.6640625
# test acc 0.7349609375
# loss 98.07198905944824
# mean tensor(0., dtype=torch.float64) y is tensor(6)
# train acc 0.75390625
